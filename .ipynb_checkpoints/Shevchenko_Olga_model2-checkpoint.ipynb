# %%
import pandas as pd
import lightgbm as ltb
import numpy as np
import re


from scipy.stats import linregress
import scipy.linalg

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, ElasticNet
from lightgbm import LGBMClassifier, LGBMRegressor
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler, Normalizer, OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.kernel_ridge import KernelRidge

from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score, roc_auc_score

from sklearn import preprocessing

import joblib

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')


# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'


import warnings
warnings.simplefilter('ignore')

from pylab import rcParams
rcParams['figure.figsize'] = 10, 5

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_seq_items', 1000)

# %%
# dir_path = 'C:/Users/Edward/Documents/Appleolga/Final_pro/model2/'
dir_path = 'C:/Users/Пользователь/Desktop/BDL/Final_projects/model2/'

# %%
# # # WRITING MERGED TRAIN AND TEST DATA TO PARQUET
# # data_train.to_parquet((dir_path + 'train/data_train.parquet.gzip'),compression='gzip')
# # data_test.to_parquet((dir_path + 'test/data_test.parquet.gzip'),compression='gzip')

# # # READING INITIAL MERGED TRAIN AND TEST DATA FROM PARQUET
# data_train = pd.read_parquet(dir_path + 'train/data_train.parquet.gzip')
# data_test = pd.read_parquet(dir_path + 'test/data_test.parquet.gzip')

# # WRITING TRAIN AND TEST DATA WITH VARIANCE, QUANTILES AND SLOPE TO PARQUET

# data_train.to_parquet((dir_path + 'train/data_train_with_var.parquet.gzip'),compression='gzip')
# data_test.to_parquet((dir_path + 'test/data_test_with_var.parquet.gzip'),compression='gzip')

# data_train.to_parquet((dir_path + 'train/data_train_with_var_slope_sts.parquet.gzip'),compression='gzip')
# data_test.to_parquet((dir_path + 'test/data_test_with_var_slope_stat.parquet.gzip'),compression='gzip')


# # READING TRAIN AND TEST DATA WITH VARIANCE QUANTILES AND SLOPE FROM PARQUET

# data_train = pd.read_parquet(dir_path + 'train/data_train_with_var.parquet.gzip')
# data_test = pd.read_parquet(dir_path + 'test/data_test_with_var.parquet.gzip')

data_train = pd.read_parquet(dir_path + 'train/data_train_with_var_slope_sts.parquet.gzip')
data_test = pd.read_parquet(dir_path + 'test/data_test_with_var_slope_stat.parquet.gzip')

# %%
#READING INITIAL TRAIN DATA
data_traff_train = pd.read_sas(dir_path +'train/hash_school_dpi_model_traff.sas7bdat')
data_train = pd.read_sas(dir_path + 'train/hash_school_dpi_model_fe.sas7bdat')

#READING INITIAL TEST DATA
data_traff_test = pd.read_sas(dir_path + 'test/hash_school_dpi_model_traff_test.sas7bdat')
data_test = pd.read_sas(dir_path + 'test/hash_school_dpi_model_fe_test.sas7bdat')
data_test2 = pd.read_sas(dir_path + 'test/hash_school_dpi_model_test.sas7bdat')

# %% [markdown]
# ### 1. DATA PREPROCESSING

# %% [markdown]
# #### 1.1 Combining data sources and data cleaning

# %%
#COMPLETE DUPLICATES CLEANING AND MERGING INITIAL DATA FILES

print(data_train.shape)
print(data_traff_train.shape)
data_traff_train = data_traff_train.drop_duplicates()
data_train = data_train.drop_duplicates()
print(data_train.shape)
print(data_traff_train.shape)

data_train = data_train.merge(data_traff_train, on = 'abon_id')
del data_traff_train

print(data_test.shape)
print(data_test2.shape)
print(data_traff_test.shape)
data_test = data_test.drop_duplicates()
data_test2 = data_test2.drop_duplicates()
data_traff_test = data_traff_test.drop_duplicates()
print(data_test.shape)
print(data_test2.shape)
print(data_traff_test.shape)

data_test = data_test.merge(data_test2, on = 'abon_id').merge(data_traff_test, on = 'abon_id')
del data_test2
del data_traff_test

data_train = data_train.astype('float32')
data_test = data_test.astype('float32')

# %%
#PARTIAL DUPLICATES CLEANING

duplicates = list(data_train['abon_id'].value_counts().where(lambda x: x > 1).dropna().index)
data_train_duplicates = data_train.loc[data_train['abon_id'].isin(duplicates), :]
data_train_duplicates_f = data_train_duplicates[data_train_duplicates.duplicated(subset='abon_id', 
                                                                                 keep='first')].set_index('abon_id')
data_train_duplicates_l = data_train_duplicates[data_train_duplicates.duplicated(subset='abon_id', 
                                                                                 keep='last')].set_index('abon_id')
print(data_train_duplicates_f.compare(data_train_duplicates_l, align_axis = 1))

print(data_train.shape)
data_train = data_train.drop(set(data_train_duplicates.index))
print(data_train.shape)

del duplicates, data_train_duplicates, data_train_duplicates_f,data_train_duplicates_l
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# (249892, 916)
# (249892, 916)

# %%
duplicates = list(data_test['abon_id'].value_counts().where(lambda x: x > 1).dropna().index)
data_test_duplicates = data_test.loc[data_test['abon_id'].isin(duplicates), :]
data_test_duplicates_f = data_test_duplicates[data_test_duplicates.duplicated(subset='abon_id',
                                                                              keep='first')].set_index('abon_id')
data_test_duplicates_l = data_test_duplicates[data_test_duplicates.duplicated(subset='abon_id',
                                                                              keep='last')].set_index('abon_id')
print(data_test_duplicates_f.compare(data_test_duplicates_l, align_axis = 1))

print(data_test.shape)
data_test = data_test.drop(set(data_test_duplicates.index))
print(data_test.shape)

del duplicates, data_test_duplicates, data_test_duplicates_f,data_test_duplicates_l
# Out:
#           bs_delte_ppd_change_tp
#                             self  other
# abon_id
# 1735181.0                  0.027  0.125
# 1735206.0                  0.000  0.008
# 1735228.0                  0.000  0.008
# 1735237.0                  0.000  0.008
# 1735256.0                  0.027  0.125
# 1735316.0                  0.027  0.125
# 1735517.0                  0.027  0.125
# 1735560.0                  0.027  0.125
# 1735685.0                  0.027  0.125
# 1735701.0                  0.000  0.008
# 1735837.0                  0.027  0.125
# 1735847.0                  0.027  0.125
# 1735860.0                  0.027  0.125
# 1736228.0                  0.000  0.008
# 1748322.0                  0.027  0.125
# 1756719.0                  0.125  0.027
# 1762270.0                  0.027  0.125
# 1762306.0                  0.000  0.008
# 1762483.0                  0.027  0.125
# 1762510.0                  0.000  0.008
# 1767512.0                  0.027  0.125
# 1767638.0                  0.027  0.125
# 1785376.0                  0.027  0.125
# 1791468.0                  0.027  0.125
# 1791538.0                  0.000  0.008
# 1794098.0                  0.027  0.125
# 1796304.0                  0.027  0.125
# 1806306.0                  0.000  0.008
# 1814389.0                 -0.008  0.000
# 1814401.0                  0.000 -0.008
# 1817951.0                  0.000  0.008
# 1818013.0                  0.008  0.000
# 1818814.0                  0.000  0.008
# 1818850.0                  0.000  0.008
# 1818858.0                  0.000  0.008
# 1820583.0                  0.000  0.008
# 1828749.0                  0.027  0.125
# 1828777.0                  0.000  0.008
# 1828793.0                  0.027  0.125
# 1828837.0                  0.000  0.008
# 1834360.0                  0.000  0.008
# 1834402.0                  0.027  0.125
# 1834474.0                 -0.064 -0.008
# 1834502.0                  0.000  0.008
# 1834589.0                  0.000  0.008
# 1846046.0                  0.000  0.008
# 1846094.0                  0.000  0.008
# 1846109.0                  0.000  0.008
# 1846121.0                  0.027  0.125
# 1846143.0                  0.027  0.125
# 1846149.0                  0.000  0.008
# 1846150.0                  0.027  0.125
# 1853573.0                  0.000  0.008
# 1853621.0                  0.000  0.008
# 1853636.0                  0.027  0.125
# 1853678.0                  0.000  0.008
# 1862240.0                  0.000  0.008
# 1862301.0                  0.125  0.027
# 1870649.0                  0.000  0.008
# 1870707.0                  0.000  0.008
# 1874852.0                  0.027  0.125
# 1875279.0                  0.000  0.008
# (243123, 916)
# (242999, 916)

# %%
#CHECKING TRAFFIC VARIANCE

traffic_cols = ['traff_m5', 'traff_m4', 'traff_m3','traff_m2','traff_m1']

traff_var = pd.DataFrame(data = data_train[traffic_cols].var(), columns = ['traff_var'])

# %%
traff_var.style.format("{:.10}")
# Out:
# <style  type="text/css" >
# </style><table id="T_0d32c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >traff_var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d32c_level0_row0" class="row_heading level0 row0" >traff_m5</th>
#                         <td id="T_0d32c_row0_col0" class="data row0 col0" >99.08881378</td>
#             </tr>
#             <tr>
#                         <th id="T_0d32c_level0_row1" class="row_heading level0 row1" >traff_m4</th>
#                         <td id="T_0d32c_row1_col0" class="data row1 col0" >79435032.0</td>
#             </tr>
#             <tr>
#                         <th id="T_0d32c_level0_row2" class="row_heading level0 row2" >traff_m3</th>
#                         <td id="T_0d32c_row2_col0" class="data row2 col0" >127.7479172</td>
#             </tr>
#             <tr>
#                         <th id="T_0d32c_level0_row3" class="row_heading level0 row3" >traff_m2</th>
#                         <td id="T_0d32c_row3_col0" class="data row3 col0" >125.2335205</td>
#             </tr>
#             <tr>
#                         <th id="T_0d32c_level0_row4" class="row_heading level0 row4" >traff_m1</th>
#                         <td id="T_0d32c_row4_col0" class="data row4 col0" >143.3793793</td>
#             </tr>
#     </tbody></table>

# %%
traffic_df_train = data_train[traffic_cols]
traffic_df_test = data_test[traffic_cols]

# %%
traffic_df_train.describe()

# %%
traffic_df_train.sort_values(by = 'traff_m4', ascending = False)

# %%
traffic_df_train.sort_values(by = 'traff_m3', ascending = False)

# %%
traffic_df_train = traffic_df_train.drop(219252)
traffic_df_train.describe()

# %%
traffic_df_train.describe().loc[['mean','25%', '50%', '75%']].plot()

# %%
traffic_df_test.describe().loc[['mean','25%', '50%', '75%']].plot()

# %%
data_train = data_train.drop(219252)
print(data_train.shape)
# del traff_var

# %%
X_train_full = data_train.drop('target', axis = 1)

y_train_full = data_train['target']

X_test_full = data_test.drop('target', axis = 1)

y_test_full = data_test['target']

model = ltb.LGBMRegressor(objective ='regression',
                          random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)
y_test_pred = model.predict(X_test_full)


print('RMSE train: {:.6f}, test: {:.6f}'.format(
        mean_squared_error(y_train_full, y_train_pred, squared = False),
        mean_squared_error(y_test_full, y_test_pred, squared = False)))
print('R^2 train: {:.6f}, test: {:.6f}'.format(
        r2_score(y_train_full, y_train_pred),
        r2_score(y_test_full, y_test_pred)))

# %%
def mark_outliers(df, outlier_coeff = 1.5): 
    
    outliers_mask = df.copy()
    counter = 1
    for col in df.columns:
        
        p75, p25 = df[col].quantile(0.75), df[col].quantile(0.25)
        IQR_col = p75 - p25
        upper, lower = p75 + outlier_coeff*IQR_col, p25 - outlier_coeff*IQR_col
        outliers_mask[col] = df[col].apply(lambda x: True if(x > upper or x < lower) else False)
        
        if (counter%100 == 0):
            print(counter)
        counter += 1
        
    return outliers_mask

# %%
#FUNCTION TO FIND CATEGORICAL COLUMNS

def find_cat_cols (df):
    
    cat_cols_list = pd.DataFrame(columns = ['col_name', 'if_cat'])
    
    df_length = df.shape[0]
    
    for col in df.columns:
        
        value_count_info = df[col].value_counts().sort_values(ascending = False)
        
        if (np.array_equal(value_count_info.index, [1,0]) or np.array_equal(value_count_info.index,[0,1])):
            if_cat = 1 
        else: 
            if_cat = 0
            
        cat_cols_list = cat_cols_list.append({'col_name': col, 'if_cat' : if_cat}, ignore_index=True)
        
    return cat_cols_list

# %%
# # CALCULATION OF TRAFFIC VARIANCE AND TRAFFIC COLS LIN.REGR. SLOPE FOR EACH OBSERVATION

data_train = data_train.assign(var = data_train[traffic_cols].apply(lambda x: x.var(), axis=1))
data_train = data_train.assign(var_quant = pd.qcut(data_train['var'], 10,labels = False))

data_test = data_test.assign(var = data_test[traffic_cols].apply(lambda x: x.var(), axis=1))
data_test = data_test.assign(var_quant = pd.qcut(data_test['var'], 10,labels = False))

enum = np.arange(1, len(traffic_cols)+1, 1)

data_train = data_train.assign(slope_traff = data_train.apply(lambda x: linregress(enum, x[traffic_cols]).slope, axis=1))

data_test = data_test.assign(slope_traff = data_test.apply(lambda x: linregress(enum, x[traffic_cols]).slope, axis=1))

# data_train = data_train.assign(interc_traff = data_train.apply(lambda x: linregress(enum, x[traffic_cols]).intercept, axis=1))

# data_test = data_test.assign(interc_traff = data_test.apply(lambda x: linregress(enum, x[traffic_cols]).intercept, axis=1))

# %%
data_train['slope_traff'].plot.hist(bins = 400,
                                    xlim = (-10,10),
                                    xticks = range(-10,10, 1),
                                    figsize = (9,3))

# %%
from scipy import stats

data_train = data_train.assign(z_score_slope = scipy.stats.zscore(data_train['slope_traff']))
                                                                
data_train = data_train.assign(big_slope = data_train['z_score_slope'].apply(lambda x: 1 if (np.abs(x) > 0.5) else 0))

data_test = data_test.assign(z_score_slope = scipy.stats.zscore(data_test['slope_traff']))
                                                                
data_test = data_test.assign(big_slope = data_test['z_score_slope'].apply(lambda x: 1 if (np.abs(x) > 0.5) else 0))

# %%
data_train[data_train['big_slope'] == 1].shape

# %%
X_train_full = data_train[data_train['big_slope'] == 0].drop('target', axis = 1)

y_train_full = data_train[data_train['big_slope'] == 0]['target']

X_test_full = data_test[data_test['big_slope'] == 0].drop('target', axis = 1)

y_test_full = data_test[data_test['big_slope'] == 0]['target']

model = ltb.LGBMRegressor(objective ='regression',
                          random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)
y_test_pred = model.predict(X_test_full)


print('RMSE train: {:.6f}, test: {:.6f}'.format(
        mean_squared_error(y_train_full, y_train_pred, squared = False),
        mean_squared_error(y_test_full, y_test_pred, squared = False)))
print('R^2 train: {:.6f}, test: {:.6f}'.format(
        r2_score(y_train_full, y_train_pred),
        r2_score(y_test_full, y_test_pred)))
# Out:
# RMSE train: 4.484354, test: 5.611657
# R^2 train: 0.595647, test: 0.428484

# %%
X_train_full = data_train[data_train['big_slope'] == 1].drop('target', axis = 1)

y_train_full = data_train[data_train['big_slope'] == 1]['target']

X_test_full = data_test[data_test['big_slope'] == 1].drop('target', axis = 1)

y_test_full = data_test[data_test['big_slope'] == 1]['target']

model = ltb.LGBMRegressor(objective ='regression',
                          random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)
y_test_pred = model.predict(X_test_full)


print('RMSE train: {:.6f}, test: {:.6f}'.format(
        mean_squared_error(y_train_full, y_train_pred, squared = False),
        mean_squared_error(y_test_full, y_test_pred, squared = False)))
print('R^2 train: {:.6f}, test: {:.6f}'.format(
        r2_score(y_train_full, y_train_pred),
        r2_score(y_test_full, y_test_pred)))

# %%
X_train_full = data_train.drop(traffic_cols + ['target', 'var', 'var_quant', 'slope_traff', 'z_score_slope', 'big_slope'], 
                               axis = 1)

y_train_full = data_train['big_slope']


model = ltb.LGBMClassifier(objective ='binary',
                           random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)

from sklearn.metrics import roc_auc_score

roc_auc_score(y_train_full, y_train_pred)
# Out:
# 0.8048735067702564

# %%
big_slope_features = pd.DataFrame(model.feature_importances_, X_train_full.columns, columns=['importance'])
big_slope_features = big_slope_features[big_slope_features['importance'] > 0].sort_values(by = 'importance', 
                                                                                          ascending=False)

big_slope_features = big_slope_features.sort_values(by='importance', ascending = False).\
                        assign(cum_sum = big_slope_features['importance'].cumsum())
big_slope_features['cum_sum']  = big_slope_features['cum_sum']/big_slope_features['importance'].sum()

print(big_slope_features.shape)
big_slope_features.style.format({'cum_sum': "{:.2%}"})
# Out:
# (513, 2)
# <style  type="text/css" >
# </style><table id="T_9a6ee_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >importance</th>        <th class="col_heading level0 col1" >cum_sum</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a6ee_level0_row0" class="row_heading level0 row0" >non_accum_internet_vol_td_mnt3</th>
#                         <td id="T_9a6ee_row0_col0" class="data row0 col0" >214</td>
#                         <td id="T_9a6ee_row0_col1" class="data row0 col1" >7.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row1" class="row_heading level0 row1" >dpi_download</th>
#                         <td id="T_9a6ee_row1_col0" class="data row1 col0" >129</td>
#                         <td id="T_9a6ee_row1_col1" class="data row1 col1" >11.43%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row2" class="row_heading level0 row2" >sum_paym_6_month</th>
#                         <td id="T_9a6ee_row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_9a6ee_row2_col1" class="data row2 col1" >15.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row3" class="row_heading level0 row3" >lt</th>
#                         <td id="T_9a6ee_row3_col0" class="data row3 col0" >106</td>
#                         <td id="T_9a6ee_row3_col1" class="data row3 col1" >18.53%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row4" class="row_heading level0 row4" >MV_ap_innet_out_v</th>
#                         <td id="T_9a6ee_row4_col0" class="data row4 col0" >90</td>
#                         <td id="T_9a6ee_row4_col1" class="data row4 col1" >21.53%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row5" class="row_heading level0 row5" >non_accum_internet_vol_std_mnt3</th>
#                         <td id="T_9a6ee_row5_col0" class="data row5 col0" >83</td>
#                         <td id="T_9a6ee_row5_col1" class="data row5 col1" >24.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row6" class="row_heading level0 row6" >non_accum_internet_vol_mea_wk1</th>
#                         <td id="T_9a6ee_row6_col0" class="data row6 col0" >71</td>
#                         <td id="T_9a6ee_row6_col1" class="data row6 col1" >26.67%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row7" class="row_heading level0 row7" >Internet</th>
#                         <td id="T_9a6ee_row7_col0" class="data row7 col0" >69</td>
#                         <td id="T_9a6ee_row7_col1" class="data row7 col1" >28.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row8" class="row_heading level0 row8" >non_accum_internet_vol_mea_mnt3</th>
#                         <td id="T_9a6ee_row8_col0" class="data row8 col0" >65</td>
#                         <td id="T_9a6ee_row8_col1" class="data row8 col1" >31.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row9" class="row_heading level0 row9" >bs_delte_mb_change_tp</th>
#                         <td id="T_9a6ee_row9_col0" class="data row9 col0" >52</td>
#                         <td id="T_9a6ee_row9_col1" class="data row9 col1" >32.87%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row10" class="row_heading level0 row10" >non_accum_internet_vol_mea_mnt1</th>
#                         <td id="T_9a6ee_row10_col0" class="data row10 col0" >51</td>
#                         <td id="T_9a6ee_row10_col1" class="data row10 col1" >34.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row11" class="row_heading level0 row11" >max_paym_6_month</th>
#                         <td id="T_9a6ee_row11_col0" class="data row11 col0" >51</td>
#                         <td id="T_9a6ee_row11_col1" class="data row11 col1" >36.27%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row12" class="row_heading level0 row12" >TM_ID</th>
#                         <td id="T_9a6ee_row12_col0" class="data row12 col0" >50</td>
#                         <td id="T_9a6ee_row12_col1" class="data row12 col1" >37.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row13" class="row_heading level0 row13" >device_days_usage</th>
#                         <td id="T_9a6ee_row13_col0" class="data row13 col0" >45</td>
#                         <td id="T_9a6ee_row13_col1" class="data row13 col1" >39.43%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row14" class="row_heading level0 row14" >myvf_day_usage</th>
#                         <td id="T_9a6ee_row14_col0" class="data row14 col0" >36</td>
#                         <td id="T_9a6ee_row14_col1" class="data row14 col1" >40.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row15" class="row_heading level0 row15" >MV_Traf_4G_d_Mb</th>
#                         <td id="T_9a6ee_row15_col0" class="data row15 col0" >35</td>
#                         <td id="T_9a6ee_row15_col1" class="data row15 col1" >41.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row16" class="row_heading level0 row16" >bs_delte_omo_change_tp</th>
#                         <td id="T_9a6ee_row16_col0" class="data row16 col0" >33</td>
#                         <td id="T_9a6ee_row16_col1" class="data row16 col1" >42.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row17" class="row_heading level0 row17" >days_of_end_last_ppm</th>
#                         <td id="T_9a6ee_row17_col0" class="data row17 col0" >31</td>
#                         <td id="T_9a6ee_row17_col1" class="data row17 col1" >43.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row18" class="row_heading level0 row18" >bs_ovrl_OMO_CNT_M3</th>
#                         <td id="T_9a6ee_row18_col0" class="data row18 col0" >30</td>
#                         <td id="T_9a6ee_row18_col1" class="data row18 col1" >44.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row19" class="row_heading level0 row19" >MV_ap_4G_d</th>
#                         <td id="T_9a6ee_row19_col0" class="data row19 col0" >30</td>
#                         <td id="T_9a6ee_row19_col1" class="data row19 col1" >45.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row20" class="row_heading level0 row20" >non_accum_internet_vol_max_mnt3</th>
#                         <td id="T_9a6ee_row20_col0" class="data row20 col0" >30</td>
#                         <td id="T_9a6ee_row20_col1" class="data row20 col1" >46.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row21" class="row_heading level0 row21" >dpi_events</th>
#                         <td id="T_9a6ee_row21_col0" class="data row21 col0" >28</td>
#                         <td id="T_9a6ee_row21_col1" class="data row21 col1" >47.87%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row22" class="row_heading level0 row22" >imei_mean_long_days_usage</th>
#                         <td id="T_9a6ee_row22_col0" class="data row22 col0" >28</td>
#                         <td id="T_9a6ee_row22_col1" class="data row22 col1" >48.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row23" class="row_heading level0 row23" >std_paym_6_month</th>
#                         <td id="T_9a6ee_row23_col0" class="data row23 col0" >27</td>
#                         <td id="T_9a6ee_row23_col1" class="data row23 col1" >49.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a6ee_level0_row24" class="row

# %%
data_descr = pd.read_csv((dir_path + 'data_descr.csv'), names=['feature', 'descr'])

big_slope_features = pd.merge(big_slope_features, data_descr, how='left', left_index=True, right_on='feature')

big_slope_features.loc[big_slope_features['descr'].isna(), 
                        'descr'] = big_slope_features.loc[big_slope_features['descr'].isna(), 'feature']

big_slope_features = big_slope_features.assign(feature_clear = big_slope_features['descr'])

expression = ' - стат.метрика'
escaped_expression = re.escape(expression)

big_slope_features['feature_clear'] = big_slope_features.feature_clear.apply(lambda x: re.sub(\
                                                                               escaped_expression, '', str(x)))

# %%
slope_cols_to_use = list(big_slope_features.groupby('feature_clear')['feature'].max('importance').values)

print(len(slope_cols_to_use))
# sorted(slope_cols_to_use)
# Out:
# 182

# %%
big_slope_features.sort_values(by='importance')

# %%
X_train_full = data_train[slope_cols_to_use]

y_train_full = data_train['big_slope']


model = ltb.LGBMClassifier(objective ='binary',
                           random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)

from sklearn.metrics import roc_auc_score

roc_auc_score(y_train_full, y_train_pred)
# Out:
# 0.8003802705179861

# %%
big_slope_features = pd.DataFrame(model.feature_importances_, X_train_full.columns, columns=['importance'])
big_slope_features = big_slope_features[big_slope_features['importance'] > 0].sort_values(by = 'importance', 
                                                                                          ascending=False)

# %%
print(big_slope_features.shape)
big_slope_features = big_slope_features.sort_values(by='importance', ascending = False).\
                        assign(cum_sum = big_slope_features['importance'].cumsum())
big_slope_features['cum_sum']  = big_slope_features['cum_sum']/big_slope_features['importance'].sum()
big_slope_features.style.format({'cum_sum': "{:.2%}"})
# Out:
# (171, 1)
# <style  type="text/css" >
# </style><table id="T_da9f7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >importance</th>        <th class="col_heading level0 col1" >cum_sum</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da9f7_level0_row0" class="row_heading level0 row0" >non_accum_internet_vol_td_mnt3</th>
#                         <td id="T_da9f7_row0_col0" class="data row0 col0" >387</td>
#                         <td id="T_da9f7_row0_col1" class="data row0 col1" >12.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row1" class="row_heading level0 row1" >dpi_download</th>
#                         <td id="T_da9f7_row1_col0" class="data row1 col0" >188</td>
#                         <td id="T_da9f7_row1_col1" class="data row1 col1" >19.17%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row2" class="row_heading level0 row2" >sum_paym_6_month</th>
#                         <td id="T_da9f7_row2_col0" class="data row2 col0" >160</td>
#                         <td id="T_da9f7_row2_col1" class="data row2 col1" >24.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row3" class="row_heading level0 row3" >MV_ap_innet_out_v</th>
#                         <td id="T_da9f7_row3_col0" class="data row3 col0" >104</td>
#                         <td id="T_da9f7_row3_col1" class="data row3 col1" >27.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row4" class="row_heading level0 row4" >lt</th>
#                         <td id="T_da9f7_row4_col0" class="data row4 col0" >98</td>
#                         <td id="T_da9f7_row4_col1" class="data row4 col1" >31.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row5" class="row_heading level0 row5" >Internet</th>
#                         <td id="T_da9f7_row5_col0" class="data row5 col0" >82</td>
#                         <td id="T_da9f7_row5_col1" class="data row5 col1" >33.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row6" class="row_heading level0 row6" >device_days_usage</th>
#                         <td id="T_da9f7_row6_col0" class="data row6 col0" >81</td>
#                         <td id="T_da9f7_row6_col1" class="data row6 col1" >36.67%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row7" class="row_heading level0 row7" >TM_ID</th>
#                         <td id="T_da9f7_row7_col0" class="data row7 col0" >80</td>
#                         <td id="T_da9f7_row7_col1" class="data row7 col1" >39.33%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row8" class="row_heading level0 row8" >bs_delte_mb_change_tp</th>
#                         <td id="T_da9f7_row8_col0" class="data row8 col0" >61</td>
#                         <td id="T_da9f7_row8_col1" class="data row8 col1" >41.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row9" class="row_heading level0 row9" >myvf_day_usage</th>
#                         <td id="T_da9f7_row9_col0" class="data row9 col0" >53</td>
#                         <td id="T_da9f7_row9_col1" class="data row9 col1" >43.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row10" class="row_heading level0 row10" >MV_ap_4G_d</th>
#                         <td id="T_da9f7_row10_col0" class="data row10 col0" >52</td>
#                         <td id="T_da9f7_row10_col1" class="data row10 col1" >44.87%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row11" class="row_heading level0 row11" >gprs_tar_vol_td_mnt3</th>
#                         <td id="T_da9f7_row11_col0" class="data row11 col0" >52</td>
#                         <td id="T_da9f7_row11_col1" class="data row11 col1" >46.60%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row12" class="row_heading level0 row12" >dpi_events</th>
#                         <td id="T_da9f7_row12_col0" class="data row12 col0" >51</td>
#                         <td id="T_da9f7_row12_col1" class="data row12 col1" >48.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row13" class="row_heading level0 row13" >days_of_end_last_ppm</th>
#                         <td id="T_da9f7_row13_col0" class="data row13 col0" >49</td>
#                         <td id="T_da9f7_row13_col1" class="data row13 col1" >49.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row14" class="row_heading level0 row14" >imei_mean_long_days_usage</th>
#                         <td id="T_da9f7_row14_col0" class="data row14 col0" >36</td>
#                         <td id="T_da9f7_row14_col1" class="data row14 col1" >51.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row15" class="row_heading level0 row15" >bs_ovrl_OMO_CNT_M3</th>
#                         <td id="T_da9f7_row15_col0" class="data row15 col0" >35</td>
#                         <td id="T_da9f7_row15_col1" class="data row15 col1" >52.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row16" class="row_heading level0 row16" >data_3g_tar_vol_td_mnt3</th>
#                         <td id="T_da9f7_row16_col0" class="data row16 col0" >35</td>
#                         <td id="T_da9f7_row16_col1" class="data row16 col1" >53.47%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row17" class="row_heading level0 row17" >bs_delte_ppm_change_tp</th>
#                         <td id="T_da9f7_row17_col0" class="data row17 col0" >32</td>
#                         <td id="T_da9f7_row17_col1" class="data row17 col1" >54.53%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row18" class="row_heading level0 row18" >bs_delte_omo_change_tp</th>
#                         <td id="T_da9f7_row18_col0" class="data row18 col0" >31</td>
#                         <td id="T_da9f7_row18_col1" class="data row18 col1" >55.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row19" class="row_heading level0 row19" >MV_dou_data</th>
#                         <td id="T_da9f7_row19_col0" class="data row19 col0" >30</td>
#                         <td id="T_da9f7_row19_col1" class="data row19 col1" >56.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row20" class="row_heading level0 row20" >bs_ovrl_OMO_SUM_M3</th>
#                         <td id="T_da9f7_row20_col0" class="data row20 col0" >30</td>
#                         <td id="T_da9f7_row20_col1" class="data row20 col1" >57.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row21" class="row_heading level0 row21" >MV_Traf_4G_d_Mb</th>
#                         <td id="T_da9f7_row21_col0" class="data row21 col0" >29</td>
#                         <td id="T_da9f7_row21_col1" class="data row21 col1" >58.53%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row22" class="row_heading level0 row22" >tsoa_call_cnt</th>
#                         <td id="T_da9f7_row22_col0" class="data row22 col0" >28</td>
#                         <td id="T_da9f7_row22_col1" class="data row22 col1" >59.47%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row23" class="row_heading level0 row23" >imei_mean_days_usage</th>
#                         <td id="T_da9f7_row23_col0" class="data row23 col0" >27</td>
#                         <td id="T_da9f7_row23_col1" class="data row23 col1" >60.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f7_level0_row24" class="row_heading level0 row24" >clc_no_vas_roam_td_mnt3</th>

# %%
X_train_full = data_train.drop(traffic_cols + ['target', 'var', 'var_quant', 'slope_traff', 'z_score_slope', 'big_slope'], 
                               axis = 1)

y_train_full = data_train['var_quant']


model = ltb.LGBMClassifier(objective ='multiclass',
                           random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)

# %%
from sklearn.metrics import roc_auc_score
enc = OneHotEncoder()
roc_auc_score(enc.fit_transform(y_train_full.values.reshape(-1, 1)).toarray(), 
              enc.fit_transform(y_train_pred.reshape(-1, 1)).toarray(), 
              multi_class = 'ovo')
# Out:
# 0.7745626611029411

# %%
var_quant_features = pd.DataFrame(model.feature_importances_, X_train_full.columns, columns=['importance'])
var_quant_features = var_quant_features[var_quant_features['importance'] > 0].sort_values(by = 'importance', 
                                                                                          ascending=False)


print(var_quant_features.shape)

var_quant_features = var_quant_features.sort_values(by='importance', ascending = False).\
                        assign(cum_sum = var_quant_features['importance'].cumsum())
var_quant_features['cum_sum']  = var_quant_features['cum_sum']/var_quant_features['importance'].sum()
var_quant_features.style.format({'cum_sum': "{:.2%}"})
# Out:
# (829, 1)
# <style  type="text/css" >
# </style><table id="T_6e38d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >importance</th>        <th class="col_heading level0 col1" >cum_sum</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e38d_level0_row0" class="row_heading level0 row0" >non_accum_internet_vol_td_mnt3</th>
#                         <td id="T_6e38d_row0_col0" class="data row0 col0" >2007</td>
#                         <td id="T_6e38d_row0_col1" class="data row0 col1" >6.69%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row1" class="row_heading level0 row1" >dpi_download</th>
#                         <td id="T_6e38d_row1_col0" class="data row1 col0" >1694</td>
#                         <td id="T_6e38d_row1_col1" class="data row1 col1" >12.34%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row2" class="row_heading level0 row2" >non_accum_internet_vol_std_mnt3</th>
#                         <td id="T_6e38d_row2_col0" class="data row2 col0" >1254</td>
#                         <td id="T_6e38d_row2_col1" class="data row2 col1" >16.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row3" class="row_heading level0 row3" >non_accum_internet_vol_mea_mnt3</th>
#                         <td id="T_6e38d_row3_col0" class="data row3 col0" >1020</td>
#                         <td id="T_6e38d_row3_col1" class="data row3 col1" >19.92%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row4" class="row_heading level0 row4" >MV_ap_innet_out_v</th>
#                         <td id="T_6e38d_row4_col0" class="data row4 col0" >541</td>
#                         <td id="T_6e38d_row4_col1" class="data row4 col1" >21.72%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row5" class="row_heading level0 row5" >non_accum_internet_vol_max_mnt3</th>
#                         <td id="T_6e38d_row5_col0" class="data row5 col0" >447</td>
#                         <td id="T_6e38d_row5_col1" class="data row5 col1" >23.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row6" class="row_heading level0 row6" >TM_ID</th>
#                         <td id="T_6e38d_row6_col0" class="data row6 col0" >430</td>
#                         <td id="T_6e38d_row6_col1" class="data row6 col1" >24.64%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row7" class="row_heading level0 row7" >non_accum_internet_vol_mea_wk1</th>
#                         <td id="T_6e38d_row7_col0" class="data row7 col0" >412</td>
#                         <td id="T_6e38d_row7_col1" class="data row7 col1" >26.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row8" class="row_heading level0 row8" >Internet</th>
#                         <td id="T_6e38d_row8_col0" class="data row8 col0" >354</td>
#                         <td id="T_6e38d_row8_col1" class="data row8 col1" >27.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row9" class="row_heading level0 row9" >device_days_usage</th>
#                         <td id="T_6e38d_row9_col0" class="data row9 col0" >324</td>
#                         <td id="T_6e38d_row9_col1" class="data row9 col1" >28.28%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row10" class="row_heading level0 row10" >dpi_upload</th>
#                         <td id="T_6e38d_row10_col0" class="data row10 col0" >262</td>
#                         <td id="T_6e38d_row10_col1" class="data row10 col1" >29.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row11" class="row_heading level0 row11" >lt</th>
#                         <td id="T_6e38d_row11_col0" class="data row11 col0" >250</td>
#                         <td id="T_6e38d_row11_col1" class="data row11 col1" >29.98%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row12" class="row_heading level0 row12" >max_paym_6_month</th>
#                         <td id="T_6e38d_row12_col0" class="data row12 col0" >246</td>
#                         <td id="T_6e38d_row12_col1" class="data row12 col1" >30.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row13" class="row_heading level0 row13" >myvf_day_usage</th>
#                         <td id="T_6e38d_row13_col0" class="data row13 col0" >229</td>
#                         <td id="T_6e38d_row13_col1" class="data row13 col1" >31.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row14" class="row_heading level0 row14" >imei_mean_long_days_usage</th>
#                         <td id="T_6e38d_row14_col0" class="data row14 col0" >224</td>
#                         <td id="T_6e38d_row14_col1" class="data row14 col1" >32.31%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row15" class="row_heading level0 row15" >sum_paym_6_month</th>
#                         <td id="T_6e38d_row15_col0" class="data row15 col0" >217</td>
#                         <td id="T_6e38d_row15_col1" class="data row15 col1" >33.04%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row16" class="row_heading level0 row16" >non_accum_internet_vol_std_mnt1</th>
#                         <td id="T_6e38d_row16_col0" class="data row16 col0" >212</td>
#                         <td id="T_6e38d_row16_col1" class="data row16 col1" >33.74%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row17" class="row_heading level0 row17" >imei_mean_days_usage</th>
#                         <td id="T_6e38d_row17_col0" class="data row17 col0" >199</td>
#                         <td id="T_6e38d_row17_col1" class="data row17 col1" >34.41%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row18" class="row_heading level0 row18" >non_accum_internet_vol_min_mnt3</th>
#                         <td id="T_6e38d_row18_col0" class="data row18 col0" >190</td>
#                         <td id="T_6e38d_row18_col1" class="data row18 col1" >35.04%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row19" class="row_heading level0 row19" >MV_Traf_4G_d_Mb</th>
#                         <td id="T_6e38d_row19_col0" class="data row19 col0" >190</td>
#                         <td id="T_6e38d_row19_col1" class="data row19 col1" >35.67%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row20" class="row_heading level0 row20" >non_accum_internet_vol_mea_mnt1</th>
#                         <td id="T_6e38d_row20_col0" class="data row20 col0" >175</td>
#                         <td id="T_6e38d_row20_col1" class="data row20 col1" >36.26%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row21" class="row_heading level0 row21" >std_paym_6_month</th>
#                         <td id="T_6e38d_row21_col0" class="data row21 col0" >171</td>
#                         <td id="T_6e38d_row21_col1" class="data row21 col1" >36.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row22" class="row_heading level0 row22" >days_of_end_last_ppm</th>
#                         <td id="T_6e38d_row22_col0" class="data row22 col0" >153</td>
#                         <td id="T_6e38d_row22_col1" class="data row22 col1" >37.34%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e38d_level0_row23" class="row_heading level0 row23" >clc_no_vas_roam_max_mnt3</th>
#                         <td id="T_6e38d_row23_col0" class="data row23 col0" >152</td>
#                         <td id="T_6e38d_row23_col1" class="data row23 col1" >37.84%</td>
#             </tr>
#             <tr>

# %%
var_quant_features = pd.DataFrame(model.feature_importances_, X_train_full.columns, columns=['importance'])
var_quant_features = var_quant_features[var_quant_features['importance'] > 0].sort_values(by = 'importance', 
                                                                                          ascending=False)


var_quant_features = pd.merge(var_quant_features, data_descr, how='left', left_index=True, right_on='feature')

var_quant_features.loc[var_quant_features['descr'].isna(), 
                        'descr'] = var_quant_features.loc[var_quant_features['descr'].isna(), 'feature']

var_quant_features = var_quant_features.assign(feature_clear = var_quant_features['descr'])

expression = ' - стат.метрика'
escaped_expression = re.escape(expression)

var_quant_features['feature_clear'] = var_quant_features.feature_clear.apply(lambda x: re.sub(\
                                                                               escaped_expression, '', str(x)))

var_quant_cols_to_use = list(var_quant_features.groupby('feature_clear')['feature'].max('importance').values)

# %%
X_train_full = data_train[var_quant_cols_to_use]

y_train_full = data_train['var_quant']


model = ltb.LGBMClassifier(objective ='multiclass',
                           random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)

# from sklearn.metrics import roc_auc_score
enc = OneHotEncoder()
roc_auc_score(enc.fit_transform(y_train_full.values.reshape(-1, 1)).toarray(), 
              enc.fit_transform(y_train_pred.reshape(-1, 1)).toarray(), 
              multi_class = 'ovo')
# Out:
# 0.755066075443757

# %%
var_quant_features = pd.DataFrame(model.feature_importances_, X_train_full.columns, columns=['importance'])
var_quant_features = var_quant_features[var_quant_features['importance'] > 0].sort_values(by = 'importance', 
                                                                                          ascending=False)
print(var_quant_features.shape)

var_quant_features = var_quant_features.sort_values(by='importance', ascending = False).\
                        assign(cum_sum = var_quant_features['importance'].cumsum())
var_quant_features['cum_sum']  = var_quant_features['cum_sum']/var_quant_features['importance'].sum()
var_quant_features.style.format({'cum_sum': "{:.2%}"})
# Out:
# (273, 1)
# <style  type="text/css" >
# </style><table id="T_de46f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >importance</th>        <th class="col_heading level0 col1" >cum_sum</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de46f_level0_row0" class="row_heading level0 row0" >non_accum_internet_vol_td_mnt3</th>
#                         <td id="T_de46f_row0_col0" class="data row0 col0" >3761</td>
#                         <td id="T_de46f_row0_col1" class="data row0 col1" >12.54%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row1" class="row_heading level0 row1" >dpi_download</th>
#                         <td id="T_de46f_row1_col0" class="data row1 col0" >2220</td>
#                         <td id="T_de46f_row1_col1" class="data row1 col1" >19.94%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row2" class="row_heading level0 row2" >MV_ap_innet_out_v</th>
#                         <td id="T_de46f_row2_col0" class="data row2 col0" >623</td>
#                         <td id="T_de46f_row2_col1" class="data row2 col1" >22.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row3" class="row_heading level0 row3" >data_3g_tar_vol_td_mnt3</th>
#                         <td id="T_de46f_row3_col0" class="data row3 col0" >586</td>
#                         <td id="T_de46f_row3_col1" class="data row3 col1" >23.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row4" class="row_heading level0 row4" >device_days_usage</th>
#                         <td id="T_de46f_row4_col0" class="data row4 col0" >582</td>
#                         <td id="T_de46f_row4_col1" class="data row4 col1" >25.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row5" class="row_heading level0 row5" >sum_paym_6_month</th>
#                         <td id="T_de46f_row5_col0" class="data row5 col0" >577</td>
#                         <td id="T_de46f_row5_col1" class="data row5 col1" >27.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row6" class="row_heading level0 row6" >TM_ID</th>
#                         <td id="T_de46f_row6_col0" class="data row6 col0" >545</td>
#                         <td id="T_de46f_row6_col1" class="data row6 col1" >29.65%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row7" class="row_heading level0 row7" >dpi_upload</th>
#                         <td id="T_de46f_row7_col0" class="data row7 col0" >524</td>
#                         <td id="T_de46f_row7_col1" class="data row7 col1" >31.39%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row8" class="row_heading level0 row8" >Internet</th>
#                         <td id="T_de46f_row8_col0" class="data row8 col0" >470</td>
#                         <td id="T_de46f_row8_col1" class="data row8 col1" >32.96%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row9" class="row_heading level0 row9" >MV_Traf_4G_d_Mb</th>
#                         <td id="T_de46f_row9_col0" class="data row9 col0" >390</td>
#                         <td id="T_de46f_row9_col1" class="data row9 col1" >34.26%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row10" class="row_heading level0 row10" >imei_mean_long_days_usage</th>
#                         <td id="T_de46f_row10_col0" class="data row10 col0" >381</td>
#                         <td id="T_de46f_row10_col1" class="data row10 col1" >35.53%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row11" class="row_heading level0 row11" >myvf_day_usage</th>
#                         <td id="T_de46f_row11_col0" class="data row11 col0" >367</td>
#                         <td id="T_de46f_row11_col1" class="data row11 col1" >36.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row12" class="row_heading level0 row12" >imei_mean_days_usage</th>
#                         <td id="T_de46f_row12_col0" class="data row12 col0" >362</td>
#                         <td id="T_de46f_row12_col1" class="data row12 col1" >37.96%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row13" class="row_heading level0 row13" >lt</th>
#                         <td id="T_de46f_row13_col0" class="data row13 col0" >354</td>
#                         <td id="T_de46f_row13_col1" class="data row13 col1" >39.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row14" class="row_heading level0 row14" >gprs_tar_vol_td_mnt3</th>
#                         <td id="T_de46f_row14_col0" class="data row14 col0" >315</td>
#                         <td id="T_de46f_row14_col1" class="data row14 col1" >40.19%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row15" class="row_heading level0 row15" >dpi_day_cnt</th>
#                         <td id="T_de46f_row15_col0" class="data row15 col0" >286</td>
#                         <td id="T_de46f_row15_col1" class="data row15 col1" >41.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row16" class="row_heading level0 row16" >dpi_events</th>
#                         <td id="T_de46f_row16_col0" class="data row16 col0" >278</td>
#                         <td id="T_de46f_row16_col1" class="data row16 col1" >42.07%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row17" class="row_heading level0 row17" >bs_succ_rate</th>
#                         <td id="T_de46f_row17_col0" class="data row17 col0" >278</td>
#                         <td id="T_de46f_row17_col1" class="data row17 col1" >43.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row18" class="row_heading level0 row18" >days_of_end_last_ppm</th>
#                         <td id="T_de46f_row18_col0" class="data row18 col0" >270</td>
#                         <td id="T_de46f_row18_col1" class="data row18 col1" >43.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row19" class="row_heading level0 row19" >Balance_uah</th>
#                         <td id="T_de46f_row19_col0" class="data row19 col0" >253</td>
#                         <td id="T_de46f_row19_col1" class="data row19 col1" >44.74%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row20" class="row_heading level0 row20" >MV_Traf_3G_d_Mb</th>
#                         <td id="T_de46f_row20_col0" class="data row20 col0" >250</td>
#                         <td id="T_de46f_row20_col1" class="data row20 col1" >45.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row21" class="row_heading level0 row21" >MV_ap_4G_d</th>
#                         <td id="T_de46f_row21_col0" class="data row21 col0" >248</td>
#                         <td id="T_de46f_row21_col1" class="data row21 col1" >46.40%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row22" class="row_heading level0 row22" >imei_mean_price</th>
#                         <td id="T_de46f_row22_col0" class="data row22 col0" >233</td>
#                         <td id="T_de46f_row22_col1" class="data row22 col1" >47.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row23" class="row_heading level0 row23" >dpi_duration</th>
#                         <td id="T_de46f_row23_col0" class="data row23 col0" >227</td>
#                         <td id="T_de46f_row23_col1" class="data row23 col1" >47.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_de46f_level0_row24" class="row_heading level0 row24" >MV_dou_2G_d</th>
#                         <td id="T_

# %%
data_train.groupby(by=['big_slope', 'var_quant'])['abon_id'].count()

# %%
data_train.columns
# Out:
# Index(['abon_id', 'Balance_uah', 'TM_ID', 'lt', 'CALCULATION_METHOD_ID',
#        'device_days_usage', 'device_brand_samsung', 'device_brand_nokia',
#        'device_brand_lenovo', 'device_brand_apple', 'device_brand_huawei',
#        'device_brand_lg', 'device_brand_xiaomi', 'device_brand_meizu',
#        'device_brand_prestigio', 'device_brand_sony', 'device_brand_nan',
#        'device_brand_other', 'device_android_version', 'device_ios_version',
#        'device_has_gprs', 'device_has_wifi', 'device_has_lte',
#        'device_width_mm', 'device_height_mm', 'device_type_modem',
#        'device_type_module', 'device_type_phone', 'device_type_smartphone',
#        'device_type_tablet', 'device_type_nan', 'device_type_rus_other',
#        'device_sim_count', 'device_price', 'loc_cnt_events',
#        'loc_is_obl_center', 'loc_lat', 'loc_lon', 'loc_market_share',
#        'bs_of_succ_but_drop_m1', 'bs_of_succ_m1',
#        'bs_of_unsucc_attemp_equip_m1', 'bs_of_unsucc_low_balance_m1',
#        'bs_of_attemps_all_m1', 'bs_of_recall_m1', 'bs_succ_rate',
#        'bs_drop_call_rate', 'bs_drop_rate', 'bs_recall_rate',
#        'serv_req_type_cnt', 'serv_cost_sum', 'serv_long_req_cnt',
#        'serv_act_days_count', 'serv_add_4or2GB', 'serv_quick_call',
#        'serv_VF_bonus', 'serv_protect_SIM', 'serv_CLIR', 'serv_add_10min',
#        'serv_share_net', 'serv_road_net', 'serv_VIO_PASS', 'serv_smart_1m',
#        'serv_year_nopay', 'serv_voice_post', 'serv_rome_weekend',
#        'serv_UAnoUA_30min', 'tsoa_call_cnt', 'tsoa_direct_cnt',
#        'tsoa_chat_cnt', 'SMS', 'Fax', 'tsoa_mail_cnt', 'cnt_sms_category_bank',
#        'cnt_sms_category_avto', 'cnt_sms_category_olx',
#        'cnt_sms_category_online_auth', 'cnt_sms_category_microcred',
#        'cnt_sms_category_shop', 'cnt_sms_category_poshta',
#        'cnt_sms_category_women', 'cnt_sms_category_taxi',
#        'cnt_sms_category_fest', 'cnt_sms_category_ticket',
#        'cnt_sms_category_collect', 'cnt_unq_category_bank',
#        'cnt_unq_category_avto', 'cnt_unq_category_olx',
#        'cnt_unq_category_online_auth', 'cnt_unq_category_microcred',
#        'cnt_unq_category_shop', 'cnt_unq_category_poshta',
#        'cnt_unq_category_women', 'cnt_unq_category_taxi',
#        'cnt_unq_category_fest', 'cnt_unq_category_ticket',
#        'cnt_unq_category_collect', 'cnt_bank_sms_category_privatbank',
#        'cnt_bank_sms_category_ukrgasbank', 'cnt_bank_sms_category_otpbank',
#        'cnt_bank_sms_category_alfabank', 'cnt_bank_sms_category_ukrsibbank',
#        'cnt_bank_sms_category_oschadbank', 'cnt_bank_sms_category_tascombank',
#        'cnt_bank_sms_category_awalbank', 'cnt_bank_sms_category_abank',
#        'cnt_bank_sms_category_mtbbank', 'cnt_bank_sms_category_pumbbank',
#        'cnt_bank_sms_category_agricoleba', 'cnt_bank_sms_category_sberbank',
#        'cnt_bank_sms_category_megabank', 'cnt_bank_sms_category_forwardban',
#        'cnt_bank_sms_category_monobank', 'cnt_bank_sms_category_vostokbank',
#        'cnt_bank_sms_category_pivdennyib', 'cnt_bank_sms_category_ideabank',
#        'cnt_bank_sms_category_globusbank', 'cnt_bank_sms_category_creditdnep',
#        'cnt_bank_sms_category_pravexbank', 'cnt_bank_sms_category_kredobank',
#        'cnt_bank_sms_category_bisbank', 'cnt_bank_sms_category_ukreximban',
#        'cnt_bank_sms_category_unexbank', 'cnt_bank_sms_category_accordbank',
#        'cnt_bank_sms_category_cominbank', 'cnt_bank_sms_category_radabank',
#        'DNZ_COUNT_closed_loan_year1', 'DNZ_MAX_days_closed_loan_year1',
#        'DNZ_MIN_days_closed_loan_year1', 'DNZ_MEAN_days_closed_loan_year1',
#        'DNZ_COUNT_open_loan_year1', 'DNZ_MEAN_days_open_loan_year1',
#        'DNZ_DAYS_from_last_year1', 'MV_Migr_To', 'MV_DOU_Neg_Bal',
#        'MV_DOU_PPM_VF', 'MV_SERV_RLH', 'MV_SERV_Y_WO_AF', 'MV_dou_net',
#        'MV_dou_data', 'MV_dou_2G_d', 'MV_dou_3G_d', 'MV_dou_4G_d',
#        'MV_dou_innet_out_v', 'MV_dou_omo_out_v', 'MV_dou_mn_out_v',
#        'MV_dou_out_s', 'MV_dou_Roam', 'MV_dou_Roam_d', 'MV_dou_Roam_v',
#        'MV_dou', 'MV_FRAUD_BLOCK', 'MV_VLR_Guest', 'MV_ARPU_2G_d_Traf',
#        'MV_Traf_2G_d_Mb', 'MV_ARPU_3G_d_Traf', 'MV_Traf_3G_d_Mb',
#        'MV_ARPU_4G_d_Traf', 'MV_Traf_4G_d_Mb', 'MV_Traf_ACCA_out_v_Min',
#        'MV_ARPU', 'MV_Traf_Cont_inc_s_Cnt', 'MV_Traf_Cont_inc_v_Min',
#        'MV_ARPU_Cont_out_s_Traf', 'MV_Traf_Cont_out_s_Cnt',
#        'MV_ARPU_Cont_out_v_Traf', 'MV_Traf_Cont_out_v_Min',
#        'MV_ARPU_Other_inc_v_Traf', 'MV_Traf_Other_inc_v_Min',
#        'MV_ARPU_Other_out_v_Traf', 'MV_Traf_Other_out_v_Min',
#        'MV_ARPU_R_inc_v_Traf', 'MV_Traf_R_inc_v_Min', 'MV_ARPU_R_out_s_Traf',
#        'MV_Traf_R_out_s_Cnt', 'MV_ARPU_R_out_v_Traf', 'MV_Traf_R_out_v_Min',
#        'MV_ARPU_Roam_d_Traf', 'MV_Traf_Roam_d_Mb', 'MV_ARPU_inc_s_Traf',
#        'MV_Traf_inc_s_Cnt', 'MV_ARPU_innet_inc_v_Traf',
#        'MV_Traf_innet_inc_v_Min', 'MV_ARPU_innet_out_s_Traf',
#        'MV_Traf_innet_out_s_Cnt', 'MV_ARPU_innet_out_v_Traf',
#        'MV_Traf_innet_out_v_Min', 'MV_Traf_mn_inc_v_Min',
#        'MV_ARPU_mn_out_s_Traf', 'MV_Traf_mn_out_s_Cnt',
#        'MV_ARPU_mn_out_v_Traf', 'MV_Traf_mn_out_v_Min',
#        'MV_Traf_omo_inc_v_Min', 'MV_ARPU_omo_out_s_Traf',
#        'MV_Traf_omo_out_s_Cnt', 'MV_ARPU_omo_out_v_Traf',
#        'MV_Traf_omo_out_v_Min', 'MV_Traf_pstn_inc_v_Min',
#        'MV_ARPU_pstn_out_v_Traf', 'MV_Traf_pstn_out_v_Min', 'MV_net_total',
#        'MV_ap_2G_d', 'MV_ap_3G_d', 'MV_ap_4G_d', 'MV_ap_Cont_v', 'MV_ap_Other',
#        'MV_ap_Roam_d', 'MV_ap_inc_v', 'MV_ap_innet_out_v', 'MV_ap_mn_out_v',
#        'MV_ap_omo_out_v', 'MV_ap_pstn_out_v', 'MV_ap_s', 'MV_DOU_AP',
#        'MV_AP_total', 'MV_ot_3G_d', 'MV_ot_4G_d', 'MV_ot_Cont_v',
#        'MV_ot_Other', 'MV_ot_R_sm', 'MV_ot_R_v', 'MV_ot_Roam_d', 'MV_ot_Unkn',
#        'MV_ot_inc_v', 'MV_ot_innet_out_v', 'MV_ot_mn_out_v', 'MV_ot_omo_out_v',
#        'MV_ot_pstn_out_v', 'MV_ot_s', 'MV_DOU_OT', 'MV_ot_total',
#        'bs_count_change_tp', 'bs_arpu_change_tp', 'bs_day_of_change_tp',
#        'bs_direct_change_tp', 'bs_delte_mb_change_tp',
#        'bs_delte_omo_change_tp', 'bs_delte_ppm_change_tp',
#        'bs_delte_ppd_change_tp', 'Good_deed', 'Internet', 'Minutes', 'Cars',
#        'Shops', 'AMA', 'entertainment', 'Food', 'days_of_last_ppm',
#        'days_of_end_last_ppm', 'active_ppm', 'bs_count_ppm_mn3', 'active_gba',
#        'day_end_gba', 'sum_paym_6_month', 'avg_paym_6_month',
#        'cnt_paym_6_month', 'max_paym_6_month', 'min_paym_6_month',
#        'std_paym_6_month', 'count_day_for_last_paym', 'is_max_paym',
#        'is_avg_paym', 'last_paym', 'BS_OVERBUNDLE_MB_CNT_M1',
#        'BS_OVERBUNDLE_MB_SUM_M1', 'BS_OVERBUNDLE_MB_CNT_M2',
#        'BS_OVERBUNDLE_MB_SUM_M2', 'BS_OVERBUNDLE_MB_CNT_M3',
#        'BS_OVERBUNDLE_MB_SUM_M3', 'bs_ovrl_OMO_CNT_M3', 'bs_ovrl_OMO_SUM_M3',
#        'bs_ovrl_OMO_CNT_M2', 'bs_ovrl_OMO_SUM_M2', 'bs_ovrl_OMO_CNT_M1',
#        'bs_ovrl_OMO_SUM_M1', 'voice_out_short_part_mea_wk1',
#        'voice_out_short_part_mea_mnt1', 'voice_out_short_part_max_mnt1',
#        'voice_out_short_part_min_mnt1', 'voice_out_short_part_std_mnt1',
#        'voice_out_short_part_mea_mnt3', 'voice_out_short_part_max_mnt3',
#        'voice_out_short_part_min_mnt3', 'voice_out_short_part_std_mnt3',
#        'voice_out_short_part_td_mnt3', 'voice_in_short_part_mea_wk1',
#        'voice_in_short_part_mea_mnt1', 'voice_in_short_part_max_mnt1',
#        'voice_in_short_part_min_mnt1', 'voice_in_short_part_std_mnt1',
#        'voice_in_short_part_mea_mnt3', 'voice_in_short_part_max_mnt3',
#        'voice_in_short_part_min_mnt3', 'voice_in_short_part_std_mnt3',
#        'voice_in_short_part_td_mnt3', 'voice_in_fix_tar_dur_mea_wk1',
#        'voice_in_fix_tar_dur_mea_mnt1', 'voice_in_fix_tar_dur_max_mnt1',
#        'voice_in_fix_tar_dur_min_mnt1', 'voice_in_fix_tar_dur_std_mnt1',
#        'voice_in_fix_tar_dur_mea_mnt3', 'voice_in_fix_tar_dur_max_mnt3',
#        'voice_in_fix_tar_dur_min_mnt3', 'voice_in_fix_tar_dur_std_mnt3',
#        'voice_in_fix_tar_dur_td_mnt3', 'voice_out_fix_tar_dur_mea_wk1',
#        'voice_out_fix_tar_dur_mea_mnt1', 'voice_out_fix_tar_dur_max_mnt1',
#        'voice_out_fix_tar_dur_min_mnt1', 'voice_out_fix_tar_dur_std_mnt1',
#        'voice_out_fix_tar_dur_mea_mnt3', 'voice_out_fix_tar_dur_max_mnt3',
#        'voice_out_fix_tar_dur_min_mnt3', 'voice_out_fix_tar_dur_std_mnt3',
#        'voice_out_fix_tar_dur_td_mnt3', 'voice_in_life_part_mea_wk1',
#        'voice_in_life_part_mea_mnt1', 'voice_in_life_part_max_mnt1',
#        'voice_in_life_part_min_mnt1', 'voice_in_life_part_std_mnt1',
#        'voice_in_life_part_mea_mnt3', 'voice_in_life_part_max_mnt3',
#        'voice_in_life_part_min_mnt3', 'voice_in_life_part_std_mnt3',
#        'voice_in_life_part_td_mnt3', 'voice_in_kievstar_part_mea_wk1',
#        'voice_in_kievstar_part_mea_mnt1', 'voice_in_kievstar_part_max_mnt1',
#        'voice_in_kievstar_part_min_mnt1', 'voice_in_kievstar_part_std_mnt1',
#        'voice_in_kievstar_part_mea_mnt3', 'voice_in_kievstar_part_max_mnt3',
#        'voice_in_kievstar_part_min_mnt3', 'voice_in_kievstar_part_std_mnt3',
#        'voice_in_kievstar_part_td_mnt3', 'voice_out_cmpttrs_avg_dumea_wk1',
#        'voice_out_cmpttrs_avg_dumea_mnt1', 'voice_out_cmpttrs_avg_dumax_mnt1',
#        'voice_out_cmpttrs_avg_dumin_mnt1', 'voice_out_cmpttrs_avg_dustd_mnt1',
#        'voice_out_cmpttrs_avg_dumea_mnt3', 'voice_out_cmpttrs_avg_dumax_mnt3',
#        'voice_out_cmpttrs_avg_dumin_mnt3', 'voice_out_cmpttrs_avg_dustd_mnt3',
#        'voice_out_cmpttrs_avg_dutd_mnt3', 'voice_in_cmpttrs_avg_durmea_wk1',
#        'voice_in_cmpttrs_avg_durmea_mnt1', 'voice_in_cmpttrs_avg_durmax_mnt1',
#        'voice_in_cmpttrs_avg_durmin_mnt1', 'voice_in_cmpttrs_avg_durstd_mnt1',
#        'voice_in_cmpttrs_avg_durmea_mnt3', 'voice_in_cmpttrs_avg_durmax_mnt3',
#        'voice_in_cmpttrs_avg_durmin_mnt3', 'voice_in_cmpttrs_avg_durstd_mnt3',
#        'voice_in_cmpttrs_avg_durtd_mnt3', 'voice_in_cmpttrs_td_cnt_mea_wk1',
#        'voice_in_cmpttrs_td_cnt_mea_mnt1', 'voice_in_cmpttrs_td_cnt_max_mnt1',
#        'voice_in_cmpttrs_td_cnt_min_mnt1', 'voice_in_cmpttrs_td_cnt_std_mnt1',
#        'voice_in_cmpttrs_td_cnt_mea_mnt3', 'voice_in_cmpttrs_td_cnt_max_mnt3',
#        'voice_in_cmpttrs_td_cnt_min_mnt3', 'voice_in_cmpttrs_td_cnt_std_mnt3',
#        'voice_in_cmpttrs_td_cnt_td_mnt3', 'voice_out_cmpttrs_td_cntmea_wk1',
#        'voice_out_cmpttrs_td_cntmea_mnt1', 'voice_out_cmpttrs_td_cntmax_mnt1',
#        'voice_out_cmpttrs_td_cntmin_mnt1', 'voice_out_cmpttrs_td_cntstd_mnt1',
#        'voice_out_cmpttrs_td_cntmea_mnt3', 'voice_out_cmpttrs_td_cntmax_mnt3',
#        'voice_out_cmpttrs_td_cntmin_mnt3', 'voice_out_cmpttrs_td_cntstd_mnt3',
#        'voice_out_cmpttrs_td_cnttd_mnt3', 'voice_in_mts_avg_dur_mea_wk1',
#        'voice_in_mts_avg_dur_mea_mnt1', 'voice_in_mts_avg_dur_max_mnt1',
#        'voice_in_mts_avg_dur_min_mnt1', 'voice_in_mts_avg_dur_std_mnt1',
#        'voice_in_mts_avg_dur_mea_mnt3', 'voice_in_mts_avg_dur_max_mnt3',
#        'voice_in_mts_avg_dur_min_mnt3', 'voice_in_mts_avg_dur_std_mnt3',
#        'voice_in_mts_avg_dur_td_mnt3', 'voice_mts_out_dwork_partmea_wk1',
#        'voice_mts_out_dwork_partmea_mnt1', 'voice_mts_out_dwork_partmax_mnt1',
#        'voice_mts_out_dwork_partmin_mnt1', 'voice_mts_out_dwork_partstd_mnt1',
#        'voice_mts_out_dwork_partmea_mnt3', 'voice_mts_out_dwork_partmax_mnt3',
#        'voice_mts_out_dwork_partmin_mnt3', 'voice_mts_out_dwork_partstd_mnt3',
#        'voice_mts_out_dwork_parttd_mnt3', 'voice_mts_in_dwork_part_mea_wk1',
#        'voice_mts_in_dwork_part_mea_mnt1', 'voice_mts_in_dwork_part_max_mnt1',
#        'voice_mts_in_dwork_part_min_mnt1', 'voice_mts_in_dwork_part_std_mnt1',
#        'voice_mts_in_dwork_part_mea_mnt3', 'voice_mts_in_dwork_part_max_mnt3',
#        'voice_mts_in_dwork_part_min_mnt3', 'voice_mts_in_dwork_part_std_mnt3',
#        'voice_mts_in_dwork_part_td_mnt3', 'voice_mts_in_nwork_part_mea_wk1',
#        'voice_mts_in_nwork_part_mea_mnt1', 'voice_mts_in_nwork_part_max_mnt1',
#        'voice_mts_in_nwork_part_min_mnt1', 'voice_mts_in_nwork_part_std_mnt1',
#        'voice_mts_in_nwork_part_mea_mnt3', 'voice_mts_in_nwork_part_max_mnt3',
#        'voice_mts_in_nwork_part_min_mnt3', 'voice_mts_in_nwork_part_std_mnt3',
#        'voice_mts_in_nwork_part_td_mnt3', 'voice_mts_out_nwork_partmea_wk1',
#        'voice_mts_out_nwork_partmea_mnt1', 'voice_mts_out_nwork_partmax_mnt1',
#        'voice_mts_out_nwork_partmin_mnt1', 'voice_mts_out_nwork_partstd_mnt1',
#        'voice_mts_out_nwork_partmea_mnt3', 'voice_mts_out_nwork_partmax_mnt3',
#        'voice_mts_out_nwork_partmin_mnt3', 'voice_mts_out_nwork_partstd_mnt3',
#        'voice_mts_out_nwork_parttd_mnt3', 'voice_mts_in_drest_part_mea_wk1',
#        'voice_mts_in_drest_part_mea_mnt1', 'voice_mts_in_drest_part_max_mnt1',
#        'voice_mts_in_drest_part_min_mnt1', 'voice_mts_in_drest_part_std_mnt1',
#        'voice_mts_in_drest_part_mea_mnt3', 'voice_mts_in_drest_part_max_mnt3',
#        'voice_mts_in_drest_part_min_mnt3', 'voice_mts_in_drest_part_std_mnt3',
#        'voice_mts_in_drest_part_td_mnt3', 'voice_mts_out_drest_partmea_wk1',
#        'voice_mts_out_drest_partmea_mnt1', 'voice_mts_out_drest_partmax_mnt1',
#        'voice_mts_out_drest_partmin_mnt1', 'voice_mts_out_drest_partstd_mnt1',
#        'voice_mts_out_drest_partmea_mnt3', 'voice_mts_out_drest_partmax_mnt3',
#        'voice_mts_out_drest_partmin_mnt3', 'voice_mts_out_drest_partstd_mnt3',
#        'voice_mts_out_drest_parttd_mnt3', 'voice_mts_in_nrest_part_mea_wk1',
#        'voice_mts_in_nrest_part_mea_mnt1', 'voice_mts_in_nrest_part_max_mnt1',
#        'voice_mts_in_nrest_part_min_mnt1', 'voice_mts_in_nrest_part_std_mnt1',
#        'voice_mts_in_nrest_part_mea_mnt3', 'voice_mts_in_nrest_part_max_mnt3',
#        'voice_mts_in_nrest_part_min_mnt3', 'voice_mts_in_nrest_part_std_mnt3',
#        'voice_mts_in_nrest_part_td_mnt3', 'voice_mts_out_nrest_partmea_wk1',
#        'voice_mts_out_nrest_partmea_mnt1', 'voice_mts_out_nrest_partmax_mnt1',
#        'voice_mts_out_nrest_partmin_mnt1', 'voice_mts_out_nrest_partstd_mnt1',
#        'voice_mts_out_nrest_partmea_mnt3', 'voice_mts_out_nrest_partmax_mnt3',
#        'voice_mts_out_nrest_partmin_mnt3', 'voice_mts_out_nrest_partstd_mnt3',
#        'voice_mts_out_nrest_parttd_mnt3', 'voice_out_tar_dur_mea_wk1',
#        'voice_out_tar_dur_mea_mnt1', 'voice_out_tar_dur_max_mnt1',
#        'voice_out_tar_dur_min_mnt1', 'voice_out_tar_dur_std_mnt1',
#        'voice_out_tar_dur_mea_mnt3', 'voice_out_tar_dur_max_mnt3',
#        'voice_out_tar_dur_min_mnt3', 'voice_out_tar_dur_std_mnt3',
#        'voice_out_tar_dur_td_mnt3', 'voice_in_td_cnt_mea_wk1',
#        'voice_in_td_cnt_mea_mnt1', 'voice_in_td_cnt_max_mnt1',
#        'voice_in_td_cnt_min_mnt1', 'voice_in_td_cnt_std_mnt1',
#        'voice_in_td_cnt_mea_mnt3', 'voice_in_td_cnt_max_mnt3',
#        'voice_in_td_cnt_min_mnt3', 'voice_in_td_cnt_std_mnt3',
#        'voice_in_td_cnt_td_mnt3', 'voice_in_tar_dur_mea_wk1',
#        'voice_in_tar_dur_mea_mnt1', 'voice_in_tar_dur_max_mnt1',
#        'voice_in_tar_dur_min_mnt1', 'voice_in_tar_dur_std_mnt1',
#        'voice_in_tar_dur_mea_mnt3', 'voice_in_tar_dur_max_mnt3',
#        'voice_in_tar_dur_min_mnt3', 'voice_in_tar_dur_std_mnt3',
#        'voice_in_tar_dur_td_mnt3', 'voice_out_td_cnt_mea_wk1',
#        'voice_out_td_cnt_mea_mnt1', 'voice_out_td_cnt_max_mnt1',
#        'voice_out_td_cnt_min_mnt1', 'voice_out_td_cnt_std_mnt1',
#        'voice_out_td_cnt_mea_mnt3', 'voice_out_td_cnt_max_mnt3',
#        'voice_out_td_cnt_min_mnt3', 'voice_out_td_cnt_std_mnt3',
#        'voice_out_td_cnt_td_mnt3', 'sms_in_cnt_mea_wk1', 'sms_in_cnt_mea_mnt1',
#        'sms_in_cnt_max_mnt1', 'sms_in_cnt_min_mnt1', 'sms_in_cnt_std_mnt1',
#        'sms_in_cnt_mea_mnt3', 'sms_in_cnt_max_mnt3', 'sms_in_cnt_min_mnt3',
#        'sms_in_cnt_std_mnt3', 'sms_in_cnt_td_mnt3', 'sms_out_cnt_mea_wk1',
#        'sms_out_cnt_mea_mnt1', 'sms_out_cnt_max_mnt1', 'sms_out_cnt_min_mnt1',
#        'sms_out_cnt_std_mnt1', 'sms_out_cnt_mea_mnt3', 'sms_out_cnt_max_mnt3',
#        'sms_out_cnt_min_mnt3', 'sms_out_cnt_std_mnt3', 'sms_out_cnt_td_mnt3',
#        'vas_clc_mea_wk1', 'vas_clc_mea_mnt1', 'vas_clc_max_mnt1',
#        'vas_clc_min_mnt1', 'vas_clc_std_mnt1', 'vas_clc_mea_mnt3',
#        'vas_clc_max_mnt3', 'vas_clc_min_mnt3', 'vas_clc_std_mnt3',
#        'vas_clc_td_mnt3', 'pay_p2p_in_sum_mea_wk1', 'pay_p2p_in_sum_mea_mnt1',
#        'pay_p2p_in_sum_max_mnt1', 'pay_p2p_in_sum_min_mnt1',
#        'pay_p2p_in_sum_std_mnt1', 'pay_p2p_in_sum_mea_mnt3',
#        'pay_p2p_in_sum_max_mnt3', 'pay_p2p_in_sum_min_mnt3',
#        'pay_p2p_in_sum_std_mnt3', 'pay_p2p_in_sum_td_mnt3',
#        'pay_p2p_out_sum_mea_wk1', 'pay_p2p_out_sum_mea_mnt1',
#        'pay_p2p_out_sum_max_mnt1', 'pay_p2p_out_sum_min_mnt1',
#        'pay_p2p_out_sum_std_mnt1', 'pay_p2p_out_sum_mea_mnt3',
#        'pay_p2p_out_sum_max_mnt3', 'pay_p2p_out_sum_min_mnt3',
#        'pay_p2p_out_sum_std_mnt3', 'pay_p2p_out_sum_td_mnt3',
#        'pay_avg_mea_wk1', 'pay_avg_mea_mnt1', 'pay_avg_max_mnt1',
#        'pay_avg_min_mnt1', 'pay_avg_std_mnt1', 'pay_avg_mea_mnt3',
#        'pay_avg_max_mnt3', 'pay_avg_min_mnt3', 'pay_avg_std_mnt3',
#        'pay_avg_td_mnt3', 'pay_max_mea_wk1', 'pay_max_mea_mnt1',
#        'pay_max_max_mnt1', 'pay_max_min_mnt1', 'pay_max_std_mnt1',
#        'pay_max_mea_mnt3', 'pay_max_max_mnt3', 'pay_max_min_mnt3',
#        'pay_max_std_mnt3', 'pay_max_td_mnt3', 'pay_sum_mea_wk1',
#        'pay_sum_mea_mnt1', 'pay_sum_max_mnt1', 'pay_sum_min_mnt1',
#        'pay_sum_std_mnt1', 'pay_sum_mea_mnt3', 'pay_sum_max_mnt3',
#        'pay_sum_min_mnt3', 'pay_sum_std_mnt3', 'pay_sum_td_mnt3',
#        'num_act_days_mea_wk1', 'num_act_days_mea_mnt1',
#        'num_act_days_max_mnt1', 'num_act_days_min_mnt1',
#        'num_act_days_std_mnt1', 'num_act_days_mea_mnt3',
#        'num_act_days_max_mnt3', 'num_act_days_min_mnt3',
#        'num_act_days_std_mnt3', 'num_act_days_td_mnt3',
#        'non_accum_internet_vol_mea_wk1', 'non_accum_internet_vol_mea_mnt1',
#        'non_accum_internet_vol_max_mnt1', 'non_accum_internet_vol_min_mnt1',
#        'non_accum_internet_vol_std_mnt1', 'non_accum_internet_vol_mea_mnt3',
#        'non_accum_internet_vol_max_mnt3', 'non_accum_internet_vol_min_mnt3',
#        'non_accum_internet_vol_std_mnt3', 'non_accum_internet_vol_td_mnt3',
#        'ks_num_part_mea_wk1', 'ks_num_part_mea_mnt1', 'ks_num_part_max_mnt1',
#        'ks_num_part_min_mnt1', 'ks_num_part_std_mnt1', 'ks_num_part_mea_mnt3',
#        'ks_num_part_max_mnt3', 'ks_num_part_min_mnt3', 'ks_num_part_std_mnt3',
#        'ks_num_part_td_mnt3', 'gprs_clc_mea_wk1', 'gprs_clc_mea_mnt1',
#        'gprs_clc_max_mnt1', 'gprs_clc_min_mnt1', 'gprs_clc_std_mnt1',
#        'gprs_clc_mea_mnt3', 'gprs_clc_max_mnt3', 'gprs_clc_min_mnt3',
#        'gprs_clc_std_mnt3', 'gprs_clc_td_mnt3', 'gprs_tar_vol_mea_wk1',
#        'gprs_tar_vol_mea_mnt1', 'gprs_tar_vol_max_mnt1',
#        'gprs_tar_vol_min_mnt1', 'gprs_tar_vol_std_mnt1',
#        'gprs_tar_vol_mea_mnt3', 'gprs_tar_vol_max_mnt3',
#        'gprs_tar_vol_min_mnt3', 'gprs_tar_vol_std_mnt3',
#        'gprs_tar_vol_td_mnt3', 'data_3g_dou_mea_wk1', 'data_3g_dou_mea_mnt1',
#        'data_3g_dou_max_mnt1', 'data_3g_dou_min_mnt1', 'data_3g_dou_std_mnt1',
#        'data_3g_dou_mea_mnt3', 'data_3g_dou_max_mnt3', 'data_3g_dou_min_mnt3',
#        'data_3g_dou_std_mnt3', 'data_3g_dou_td_mnt3',
#        'data_3g_tar_vol_mea_wk1', 'data_3g_tar_vol_mea_mnt1',
#        'data_3g_tar_vol_max_mnt1', 'data_3g_tar_vol_min_mnt1',
#        'data_3g_tar_vol_std_mnt1', 'data_3g_tar_vol_mea_mnt3',
#        'data_3g_tar_vol_max_mnt3', 'data_3g_tar_vol_min_mnt3',
#        'data_3g_tar_vol_std_mnt3', 'data_3g_tar_vol_td_mnt3',
#        'data_3g_tv_cnt_mea_wk1', 'data_3g_tv_cnt_mea_mnt1',
#        'data_3g_tv_cnt_max_mnt1', 'data_3g_tv_cnt_min_mnt1',
#        'data_3g_tv_cnt_std_mnt1', 'data_3g_tv_cnt_mea_mnt3',
#        'data_3g_tv_cnt_max_mnt3', 'data_3g_tv_cnt_min_mnt3',
#        'data_3g_tv_cnt_std_mnt3', 'data_3g_tv_cnt_td_mnt3',
#        'content_cnt_mea_wk1', 'content_cnt_mea_mnt1', 'content_cnt_max_mnt1',
#        'content_cnt_min_mnt1', 'content_cnt_std_mnt1', 'content_cnt_mea_mnt3',
#        'content_cnt_max_mnt3', 'content_cnt_min_mnt3', 'content_cnt_std_mnt3',
#        'content_cnt_td_mnt3', 'content_clc_mea_wk1', 'content_clc_mea_mnt1',
#        'content_clc_max_mnt1', 'content_clc_min_mnt1', 'content_clc_std_mnt1',
#        'content_clc_mea_mnt3', 'content_clc_max_mnt3', 'content_clc_min_mnt3',
#        'content_clc_std_mnt3', 'content_clc_td_mnt3',
#        'conn_out_uniq_cnt_mea_wk1', 'conn_out_uniq_cnt_mea_mnt1',
#        'conn_out_uniq_cnt_max_mnt1', 'conn_out_uniq_cnt_min_mnt1',
#        'conn_out_uniq_cnt_std_mnt1', 'conn_out_uniq_cnt_mea_mnt3',
#        'conn_out_uniq_cnt_max_mnt3', 'conn_out_uniq_cnt_min_mnt3',
#        'conn_out_uniq_cnt_std_mnt3', 'conn_out_uniq_cnt_td_mnt3',
#        'conn_in_uniq_cnt_mea_wk1', 'conn_in_uniq_cnt_mea_mnt1',
#        'conn_in_uniq_cnt_max_mnt1', 'conn_in_uniq_cnt_min_mnt1',
#        'conn_in_uniq_cnt_std_mnt1', 'conn_in_uniq_cnt_mea_mnt3',
#        'conn_in_uniq_cnt_max_mnt3', 'conn_in_uniq_cnt_min_mnt3',
#        'conn_in_uniq_cnt_std_mnt3', 'conn_in_uniq_cnt_td_mnt3',
#        'conn_com_part_mea_wk1', 'conn_com_part_mea_mnt1',
#        'conn_com_part_max_mnt1', 'conn_com_part_min_mnt1',
#        'conn_com_part_std_mnt1', 'conn_com_part_mea_mnt3',
#        'conn_com_part_max_mnt3', 'conn_com_part_min_mnt3',
#        'conn_com_part_std_mnt3', 'conn_com_part_td_mnt3',
#        'com_num_part_mea_wk1', 'com_num_part_mea_mnt1',
#        'com_num_part_max_mnt1', 'com_num_part_min_mnt1',
#        'com_num_part_std_mnt1', 'com_num_part_mea_mnt3',
#        'com_num_part_max_mnt3', 'com_num_part_min_mnt3',
#        'com_num_part_std_mnt3', 'com_num_part_td_mnt3',
#        'clc_no_vas_roam_mea_wk1', 'clc_no_vas_roam_mea_mnt1',
#        'clc_no_vas_roam_max_mnt1', 'clc_no_vas_roam_min_mnt1',
#        'clc_no_vas_roam_std_mnt1', 'clc_no_vas_roam_mea_mnt3',
#        'clc_no_vas_roam_max_mnt3', 'clc_no_vas_roam_min_mnt3',
#        'clc_no_vas_roam_std_mnt3', 'clc_no_vas_roam_td_mnt3',
#        'block_all_dur_mea_wk1', 'block_all_dur_mea_mnt1',
#        'block_all_dur_max_mnt1', 'block_all_dur_min_mnt1',
#        'block_all_dur_std_mnt1', 'block_all_dur_mea_mnt3',
#        'block_all_dur_max_mnt3', 'block_all_dur_min_mnt3',
#        'block_all_dur_std_mnt3', 'block_all_dur_td_mnt3',
#        'Ama_rchrgmnt_sum_mea_wk1', 'Ama_rchrgmnt_sum_mea_mnt1',
#        'Ama_rchrgmnt_sum_max_mnt1', 'Ama_rchrgmnt_sum_min_mnt1',
#        'Ama_rchrgmnt_sum_std_mnt1', 'Ama_rchrgmnt_sum_mea_mnt3',
#        'Ama_rchrgmnt_sum_max_mnt3', 'Ama_rchrgmnt_sum_min_mnt3',
#        'Ama_rchrgmnt_sum_std_mnt3', 'Ama_rchrgmnt_sum_td_mnt3',
#        'ama_volume_mea_wk1', 'ama_volume_mea_mnt1', 'ama_volume_max_mnt1',
#        'ama_volume_min_mnt1', 'ama_volume_std_mnt1', 'ama_volume_mea_mnt3',
#        'ama_volume_max_mnt3', 'ama_volume_min_mnt3', 'ama_volume_std_mnt3',
#        'ama_volume_td_mnt3', 'all_cnt_mea_wk1', 'all_cnt_mea_mnt1',
#        'all_cnt_max_mnt1', 'all_cnt_min_mnt1', 'all_cnt_std_mnt1',
#        'all_cnt_mea_mnt3', 'all_cnt_max_mnt3', 'all_cnt_min_mnt3',
#        'all_cnt_std_mnt3', 'all_cnt_td_mnt3', 'all_home_clc_mea_wk1',
#        'all_home_clc_mea_mnt1', 'all_home_clc_max_mnt1',
#        'all_home_clc_min_mnt1', 'all_home_clc_std_mnt1',
#        'all_home_clc_mea_mnt3', 'all_home_clc_max_mnt3',
#        'all_home_clc_min_mnt3', 'all_home_clc_std_mnt3',
#        'all_home_clc_td_mnt3', 'all_clc_mea_wk1', 'all_clc_mea_mnt1',
#        'all_clc_max_mnt1', 'all_clc_min_mnt1', 'all_clc_std_mnt1',
#        'all_clc_mea_mnt3', 'all_clc_max_mnt3', 'all_clc_min_mnt3',
#        'all_clc_std_mnt3', 'all_clc_td_mnt3', 'all_roam_clc_mea_wk1',
#        'all_roam_clc_mea_mnt1', 'all_roam_clc_max_mnt1',
#        'all_roam_clc_min_mnt1', 'all_roam_clc_std_mnt1',
#        'all_roam_clc_mea_mnt3', 'all_roam_clc_max_mnt3',
#        'all_roam_clc_min_mnt3', 'all_roam_clc_std_mnt3',
#        'all_roam_clc_td_mnt3', 'accum_oth_dur_mea_wk1',
#        'accum_oth_dur_mea_mnt1', 'accum_oth_dur_max_mnt1',
#        'accum_oth_dur_min_mnt1', 'accum_oth_dur_std_mnt1',
#        'accum_oth_dur_mea_mnt3', 'accum_oth_dur_max_mnt3',
#        'accum_oth_dur_min_mnt3', 'accum_oth_dur_std_mnt3',
#        'accum_oth_dur_td_mnt3', 'accum_mts_dur_mea_wk1',
#        'accum_mts_dur_mea_mnt1', 'accum_mts_dur_max_mnt1',
#        'accum_mts_dur_min_mnt1', 'accum_mts_dur_std_mnt1',
#        'accum_mts_dur_mea_mnt3', 'accum_mts_dur_max_mnt3',
#        'accum_mts_dur_min_mnt3', 'accum_mts_dur_std_mnt3',
#        'accum_mts_dur_td_mnt3', 'abon_part_mea_wk1', 'abon_part_mea_mnt1',
#        'abon_part_max_mnt1', 'abon_part_min_mnt1', 'abon_part_std_mnt1',
#        'abon_part_mea_mnt3', 'abon_part_max_mnt3', 'abon_part_min_mnt3',
#        'abon_part_std_mnt3', 'abon_part_td_mnt3', 'goodok_clc_mea_wk1',
#        'goodok_clc_mea_mnt1', 'goodok_clc_max_mnt1', 'goodok_clc_min_mnt1',
#        'goodok_clc_std_mnt1', 'goodok_clc_mea_mnt3', 'goodok_clc_max_mnt3',
#        'goodok_clc_min_mnt3', 'goodok_clc_std_mnt3', 'goodok_clc_td_mnt3',
#        'sms_clc_mea_wk1', 'sms_clc_mea_mnt1', 'sms_clc_max_mnt1',
#        'sms_clc_min_mnt1', 'sms_clc_std_mnt1', 'sms_clc_mea_mnt3',
#        'sms_clc_max_mnt3', 'sms_clc_min_mnt3', 'sms_clc_std_mnt3',
#        'sms_clc_td_mnt3', 'sms_roam_clc_mea_wk1', 'sms_roam_clc_mea_mnt1',
#        'sms_roam_clc_max_mnt1', 'sms_roam_clc_min_mnt1',
#        'sms_roam_clc_std_mnt1', 'sms_roam_clc_mea_mnt3',
#        'sms_roam_clc_max_mnt3', 'sms_roam_clc_min_mnt3',
#        'sms_roam_clc_std_mnt3', 'sms_roam_clc_td_mnt3',
#        'voice_in_roam_clc_mea_wk1', 'voice_in_roam_clc_mea_mnt1',
#        'voice_in_roam_clc_max_mnt1', 'voice_in_roam_clc_min_mnt1',
#        'voice_in_roam_clc_std_mnt1', 'voice_in_roam_clc_mea_mnt3',
#        'voice_in_roam_clc_max_mnt3', 'voice_in_roam_clc_min_mnt3',
#        'voice_in_roam_clc_std_mnt3', 'voice_in_roam_clc_td_mnt3',
#        'dpi_duration', 'dpi_upload', 'dpi_download', 'dpi_events',
#        'dpi_day_cnt', 'DNZ_COUNT_closed_loan_year2',
#        'DNZ_MAX_days_closed_loan_year2', 'DNZ_MIN_days_closed_loan_year2',
#        'DNZ_STD_days_closed_loan_year2', 'DNZ_MEAN_days_closed_loan_year2',
#        'DNZ_COUNT_open_loan_year2', 'DNZ_MEAN_days_open_loan_year2',
#        'DNZ_DAYS_from_last_year2', 'DNZ_COUNT_closed_loan_year5',
#        'DNZ_MAX_days_closed_loan_year5', 'DNZ_MIN_days_closed_loan_year5',
#        'DNZ_STD_days_closed_loan_year5', 'DNZ_MEAN_days_closed_loan_year5',
#        'DNZ_COUNT_open_loan_year5', 'DNZ_MEAN_days_open_loan_year5',
#        'DNZ_DAYS_from_last_year5', 'imei_mean_days_usage',
#        'imei_mean_long_days_usage', 'imei_mean_price', 'imei_max_price',
#        'imei_mean_day_announced', 'device_has_hardware_umts',
#        'device_has_LTE_BAND_3', 'myvf_day_usage', 'GBA_remain_days', 'target',
#        'traff_m5', 'traff_m4', 'traff_m3', 'traff_m2', 'traff_m1', 'var',
#        'var_quant', 'slope_traff', 'z_score_slope', 'big_slope'],
#       dtype='object')

# %%
data_train = data_train.assign(big_var = data_train.apply(lambda x: 0 if (x['var_quant'] < 8) else 1, axis =1))

# %%
X_train_full = data_train[var_quant_cols_to_use]

y_train_full = data_train['big_var']


model = ltb.LGBMClassifier(objective ='binary',
                           random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)

# from sklearn.metrics import roc_auc_score

roc_auc_score(y_train_full, y_train_pred)
# Out:
# 0.8837720423979892

# %%
big_var_features = pd.DataFrame(model.feature_importances_, X_train_full.columns, columns=['importance'])
big_var_features = big_var_features[big_var_features['importance'] > 0].sort_values(by = 'importance', 
                                                                                          ascending=False)
print(big_var_features.shape)

big_var_features = big_var_features.sort_values(by='importance', ascending = False).\
                        assign(cum_sum = big_var_features['importance'].cumsum())
big_var_features['cum_sum']  = big_var_features['cum_sum']/big_var_features['importance'].sum()
big_var_features.style.format({'cum_sum': "{:.2%}"})
# Out:
# (222, 1)
# <style  type="text/css" >
# </style><table id="T_bd97f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >importance</th>        <th class="col_heading level0 col1" >cum_sum</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd97f_level0_row0" class="row_heading level0 row0" >non_accum_internet_vol_td_mnt3</th>
#                         <td id="T_bd97f_row0_col0" class="data row0 col0" >450</td>
#                         <td id="T_bd97f_row0_col1" class="data row0 col1" >15.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row1" class="row_heading level0 row1" >dpi_download</th>
#                         <td id="T_bd97f_row1_col0" class="data row1 col0" >234</td>
#                         <td id="T_bd97f_row1_col1" class="data row1 col1" >22.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row2" class="row_heading level0 row2" >TM_ID</th>
#                         <td id="T_bd97f_row2_col0" class="data row2 col0" >115</td>
#                         <td id="T_bd97f_row2_col1" class="data row2 col1" >26.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row3" class="row_heading level0 row3" >MV_ap_innet_out_v</th>
#                         <td id="T_bd97f_row3_col0" class="data row3 col0" >106</td>
#                         <td id="T_bd97f_row3_col1" class="data row3 col1" >30.17%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row4" class="row_heading level0 row4" >sum_paym_6_month</th>
#                         <td id="T_bd97f_row4_col0" class="data row4 col0" >92</td>
#                         <td id="T_bd97f_row4_col1" class="data row4 col1" >33.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row5" class="row_heading level0 row5" >lt</th>
#                         <td id="T_bd97f_row5_col0" class="data row5 col0" >64</td>
#                         <td id="T_bd97f_row5_col1" class="data row5 col1" >35.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row6" class="row_heading level0 row6" >MV_dou_data</th>
#                         <td id="T_bd97f_row6_col0" class="data row6 col0" >60</td>
#                         <td id="T_bd97f_row6_col1" class="data row6 col1" >37.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row7" class="row_heading level0 row7" >gprs_tar_vol_td_mnt3</th>
#                         <td id="T_bd97f_row7_col0" class="data row7 col0" >57</td>
#                         <td id="T_bd97f_row7_col1" class="data row7 col1" >39.27%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row8" class="row_heading level0 row8" >data_3g_tar_vol_td_mnt3</th>
#                         <td id="T_bd97f_row8_col0" class="data row8 col0" >51</td>
#                         <td id="T_bd97f_row8_col1" class="data row8 col1" >40.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row9" class="row_heading level0 row9" >device_days_usage</th>
#                         <td id="T_bd97f_row9_col0" class="data row9 col0" >48</td>
#                         <td id="T_bd97f_row9_col1" class="data row9 col1" >42.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row10" class="row_heading level0 row10" >bs_delte_mb_change_tp</th>
#                         <td id="T_bd97f_row10_col0" class="data row10 col0" >45</td>
#                         <td id="T_bd97f_row10_col1" class="data row10 col1" >44.07%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row11" class="row_heading level0 row11" >imei_mean_long_days_usage</th>
#                         <td id="T_bd97f_row11_col0" class="data row11 col0" >45</td>
#                         <td id="T_bd97f_row11_col1" class="data row11 col1" >45.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row12" class="row_heading level0 row12" >dpi_upload</th>
#                         <td id="T_bd97f_row12_col0" class="data row12 col0" >45</td>
#                         <td id="T_bd97f_row12_col1" class="data row12 col1" >47.07%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row13" class="row_heading level0 row13" >MV_Traf_4G_d_Mb</th>
#                         <td id="T_bd97f_row13_col0" class="data row13 col0" >42</td>
#                         <td id="T_bd97f_row13_col1" class="data row13 col1" >48.47%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row14" class="row_heading level0 row14" >Internet</th>
#                         <td id="T_bd97f_row14_col0" class="data row14 col0" >41</td>
#                         <td id="T_bd97f_row14_col1" class="data row14 col1" >51.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row15" class="row_heading level0 row15" >bs_delte_omo_change_tp</th>
#                         <td id="T_bd97f_row15_col0" class="data row15 col0" >41</td>
#                         <td id="T_bd97f_row15_col1" class="data row15 col1" >49.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row16" class="row_heading level0 row16" >MV_ap_4G_d</th>
#                         <td id="T_bd97f_row16_col0" class="data row16 col0" >36</td>
#                         <td id="T_bd97f_row16_col1" class="data row16 col1" >52.40%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row17" class="row_heading level0 row17" >Balance_uah</th>
#                         <td id="T_bd97f_row17_col0" class="data row17 col0" >34</td>
#                         <td id="T_bd97f_row17_col1" class="data row17 col1" >53.53%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row18" class="row_heading level0 row18" >days_of_end_last_ppm</th>
#                         <td id="T_bd97f_row18_col0" class="data row18 col0" >34</td>
#                         <td id="T_bd97f_row18_col1" class="data row18 col1" >54.67%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row19" class="row_heading level0 row19" >dpi_events</th>
#                         <td id="T_bd97f_row19_col0" class="data row19 col0" >34</td>
#                         <td id="T_bd97f_row19_col1" class="data row19 col1" >55.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row20" class="row_heading level0 row20" >bs_succ_rate</th>
#                         <td id="T_bd97f_row20_col0" class="data row20 col0" >33</td>
#                         <td id="T_bd97f_row20_col1" class="data row20 col1" >56.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row21" class="row_heading level0 row21" >dpi_day_cnt</th>
#                         <td id="T_bd97f_row21_col0" class="data row21 col0" >33</td>
#                         <td id="T_bd97f_row21_col1" class="data row21 col1" >58.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row22" class="row_heading level0 row22" >myvf_day_usage</th>
#                         <td id="T_bd97f_row22_col0" class="data row22 col0" >32</td>
#                         <td id="T_bd97f_row22_col1" class="data row22 col1" >59.07%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row23" class="row_heading level0 row23" >clc_no_vas_roam_td_mnt3</th>
#                         <td id="T_bd97f_row23_col0" class="data row23 col0" >26</td>
#                         <td id="T_bd97f_row23_col1" class="data row23 col1" >59.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd97f_level0_row24" class="row_heading level0 row24" >last_paym</th>
#                         <td id="T_bd97f_row

# %%
big_slope_features.columns  = ['importance_bs', 'cum_sum_bs']
var_quant_features.columns = ['importance_vq', 'cum_sum_vq']
big_var_features.columns = ['importance_bv', 'cum_sum_bv']

total_features = big_slope_features.merge(var_quant_features,
                                          how = 'inner',
                                          left_index = True,
                                          right_index = True).merge(big_var_features,
                                                                   how = 'inner',
                                                                   left_index = True,
                                                                   right_index = True)
big_var_slope_features = list(total_features.index)

# %%
print(total_features.shape)
total_features.sort_values(by=['importance_bv', 'importance_bs'], ascending = False).\
    style.format({'cum_sum_bs': "{:.2%}", 'cum_sum_bv': "{:.2%}",'cum_sum_vq': "{:.2%}"})
# Out:
# (155, 6)
# <style  type="text/css" >
# </style><table id="T_2b44b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >importance_bs</th>        <th class="col_heading level0 col1" >cum_sum_bs</th>        <th class="col_heading level0 col2" >importance_vq</th>        <th class="col_heading level0 col3" >cum_sum_vq</th>        <th class="col_heading level0 col4" >importance_bv</th>        <th class="col_heading level0 col5" >cum_sum_bv</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b44b_level0_row0" class="row_heading level0 row0" >non_accum_internet_vol_td_mnt3</th>
#                         <td id="T_2b44b_row0_col0" class="data row0 col0" >387</td>
#                         <td id="T_2b44b_row0_col1" class="data row0 col1" >12.90%</td>
#                         <td id="T_2b44b_row0_col2" class="data row0 col2" >3761</td>
#                         <td id="T_2b44b_row0_col3" class="data row0 col3" >12.54%</td>
#                         <td id="T_2b44b_row0_col4" class="data row0 col4" >450</td>
#                         <td id="T_2b44b_row0_col5" class="data row0 col5" >15.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row1" class="row_heading level0 row1" >dpi_download</th>
#                         <td id="T_2b44b_row1_col0" class="data row1 col0" >188</td>
#                         <td id="T_2b44b_row1_col1" class="data row1 col1" >19.17%</td>
#                         <td id="T_2b44b_row1_col2" class="data row1 col2" >2220</td>
#                         <td id="T_2b44b_row1_col3" class="data row1 col3" >19.94%</td>
#                         <td id="T_2b44b_row1_col4" class="data row1 col4" >234</td>
#                         <td id="T_2b44b_row1_col5" class="data row1 col5" >22.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row2" class="row_heading level0 row2" >TM_ID</th>
#                         <td id="T_2b44b_row2_col0" class="data row2 col0" >80</td>
#                         <td id="T_2b44b_row2_col1" class="data row2 col1" >39.33%</td>
#                         <td id="T_2b44b_row2_col2" class="data row2 col2" >545</td>
#                         <td id="T_2b44b_row2_col3" class="data row2 col3" >29.65%</td>
#                         <td id="T_2b44b_row2_col4" class="data row2 col4" >115</td>
#                         <td id="T_2b44b_row2_col5" class="data row2 col5" >26.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row3" class="row_heading level0 row3" >MV_ap_innet_out_v</th>
#                         <td id="T_2b44b_row3_col0" class="data row3 col0" >104</td>
#                         <td id="T_2b44b_row3_col1" class="data row3 col1" >27.97%</td>
#                         <td id="T_2b44b_row3_col2" class="data row3 col2" >623</td>
#                         <td id="T_2b44b_row3_col3" class="data row3 col3" >22.01%</td>
#                         <td id="T_2b44b_row3_col4" class="data row3 col4" >106</td>
#                         <td id="T_2b44b_row3_col5" class="data row3 col5" >30.17%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row4" class="row_heading level0 row4" >sum_paym_6_month</th>
#                         <td id="T_2b44b_row4_col0" class="data row4 col0" >160</td>
#                         <td id="T_2b44b_row4_col1" class="data row4 col1" >24.50%</td>
#                         <td id="T_2b44b_row4_col2" class="data row4 col2" >577</td>
#                         <td id="T_2b44b_row4_col3" class="data row4 col3" >27.83%</td>
#                         <td id="T_2b44b_row4_col4" class="data row4 col4" >92</td>
#                         <td id="T_2b44b_row4_col5" class="data row4 col5" >33.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row5" class="row_heading level0 row5" >lt</th>
#                         <td id="T_2b44b_row5_col0" class="data row5 col0" >98</td>
#                         <td id="T_2b44b_row5_col1" class="data row5 col1" >31.23%</td>
#                         <td id="T_2b44b_row5_col2" class="data row5 col2" >354</td>
#                         <td id="T_2b44b_row5_col3" class="data row5 col3" >39.14%</td>
#                         <td id="T_2b44b_row5_col4" class="data row5 col4" >64</td>
#                         <td id="T_2b44b_row5_col5" class="data row5 col5" >35.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row6" class="row_heading level0 row6" >MV_dou_data</th>
#                         <td id="T_2b44b_row6_col0" class="data row6 col0" >30</td>
#                         <td id="T_2b44b_row6_col1" class="data row6 col1" >56.57%</td>
#                         <td id="T_2b44b_row6_col2" class="data row6 col2" >226</td>
#                         <td id="T_2b44b_row6_col3" class="data row6 col3" >49.44%</td>
#                         <td id="T_2b44b_row6_col4" class="data row6 col4" >60</td>
#                         <td id="T_2b44b_row6_col5" class="data row6 col5" >37.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row7" class="row_heading level0 row7" >gprs_tar_vol_td_mnt3</th>
#                         <td id="T_2b44b_row7_col0" class="data row7 col0" >52</td>
#                         <td id="T_2b44b_row7_col1" class="data row7 col1" >46.60%</td>
#                         <td id="T_2b44b_row7_col2" class="data row7 col2" >315</td>
#                         <td id="T_2b44b_row7_col3" class="data row7 col3" >40.19%</td>
#                         <td id="T_2b44b_row7_col4" class="data row7 col4" >57</td>
#                         <td id="T_2b44b_row7_col5" class="data row7 col5" >39.27%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row8" class="row_heading level0 row8" >data_3g_tar_vol_td_mnt3</th>
#                         <td id="T_2b44b_row8_col0" class="data row8 col0" >35</td>
#                         <td id="T_2b44b_row8_col1" class="data row8 col1" >53.47%</td>
#                         <td id="T_2b44b_row8_col2" class="data row8 col2" >586</td>
#                         <td id="T_2b44b_row8_col3" class="data row8 col3" >23.97%</td>
#                         <td id="T_2b44b_row8_col4" class="data row8 col4" >51</td>
#                         <td id="T_2b44b_row8_col5" class="data row8 col5" >40.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row9" class="row_heading level0 row9" >device_days_usage</th>
#                         <td id="T_2b44b_row9_col0" class="data row9 col0" >81</td>
#                         <td id="T_2b44b_row9_col1" class="data row9 col1" >36.67%</td>
#                         <td id="T_2b44b_row9_col2" class="data row9 col2" >582</td>
#                         <td id="T_2b44b_row9_col3" class="data row9 col3" >25.91%</td>
#                         <td id="T_2b44b_row9_col4" class="data row9 col4" >48</td>
#                         <td id="T_2b44b_row9_col5" class="data row9 col5" >42.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row10" class="row_heading level0 row10" >bs_delte_mb_change_tp</th>
#                         <td id="T_2b44b_row10_col0" class="data row10 col0" >61</td>
#                         <td id="T_2b44b_row10_col1" class="data row10 col1" >41.37%</td>
#                         <td id="T_2b44b_row10_col2" class="data row10 col2" >153</td>
#                         <td id="T_2b44b_row10_col3" class="data row10 col3" >61.49%</td>
#                         <td id="T_2b44b_row10_col4" class="data row10 col4" >45</td>
#                         <td id="T_2b44b_row10_col5" class="data row10 col5" >44.07%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b44b_level0_row11" class="row_heading level0 row11" >imei_mean_long_days_usage</th>
#                         <td id="T_2b44b_row11_col0" class="data row11 col0" >36</td>
#                         <td id="T_2b44b_row11_col1" cla

# %%
symlog = data_train['non_accum_internet_vol_td_mnt3'].apply(lambda x: -np.log10(-x) if x < 0 else np.log10(x) if x > 0 else 0)
data_train = data_train.assign(non_accum_internet_vol_td_mnt3_log = symlog)

symlog = data_test['non_accum_internet_vol_td_mnt3'].apply(lambda x: -np.log10(-x) if x < 0 else np.log10(x) if x > 0 else 0)
data_test = data_test.assign(non_accum_internet_vol_td_mnt3_log = symlog)

data_train = data_train.assign(non_accum_internet_vol_td_mnt3_log_bins = pd.cut(data_train['non_accum_internet_vol_td_mnt3_log'], 
                                                                                bins=range(-19, 19)))

data_test = data_test.assign(non_accum_internet_vol_td_mnt3_log_bins = pd.cut(data_test['non_accum_internet_vol_td_mnt3_log'], 
                                                                                bins=range(-19, 19)))

del symlog

# %%
 def ratio_diagram(df, values_col, index_col, columns_cols, comparison_names, agg_func = 'count') :
        
    pivot_df = pd.pivot_table(df, 
                              values=values_col,
                              index=index_col,
                              columns=columns_cols, 
                              aggfunc=agg_func)
    
    pivot_df.columns = comparison_names
    pivot_df = pivot_df.assign(ratio = pivot_df[comparison_names[1]]/pivot_df[comparison_names[0]])


    pivot_df.sort_values(by = 'ratio', ascending = False)

    ax1 = pivot_df.loc[:, comparison_names].plot(kind = 'bar',
                                                 figsize = (10,5),
                                                 rot = 90,
                                                 sharex = True)


    ax1 = pivot_df['ratio'].plot(secondary_y=True,
                                 colormap = 'ocean',
                                 rot = 90,
                                 legend = True,
                                 sharex = True);
    
    plt.show()
    
    return pivot_df

# %%
# temp = data_train.iloc[0:1000, :]
ratio_df = ratio_diagram(data_train, ['abon_id'], ['non_accum_internet_vol_td_mnt3_log_bins'], ['big_var'], ['small_var', 'big_var'])

# %%
sorted(big_var_slope_features)
# Out:
# ['BS_OVERBUNDLE_MB_CNT_M2',
#  'BS_OVERBUNDLE_MB_CNT_M3',
#  'BS_OVERBUNDLE_MB_SUM_M3',
#  'Balance_uah',
#  'DNZ_DAYS_from_last_year1',
#  'DNZ_MAX_days_closed_loan_year1',
#  'DNZ_MEAN_days_closed_loan_year1',
#  'DNZ_STD_days_closed_loan_year5',
#  'GBA_remain_days',
#  'Good_deed',
#  'Internet',
#  'MV_AP_total',
#  'MV_ARPU',
#  'MV_ARPU_2G_d_Traf',
#  'MV_ARPU_Cont_out_s_Traf',
#  'MV_ARPU_innet_out_v_Traf',
#  'MV_DOU_Neg_Bal',
#  'MV_DOU_OT',
#  'MV_Migr_To',
#  'MV_SERV_Y_WO_AF',
#  'MV_Traf_2G_d_Mb',
#  'MV_Traf_3G_d_Mb',
#  'MV_Traf_4G_d_Mb',
#  'MV_Traf_ACCA_out_v_Min',
#  'MV_Traf_Cont_inc_s_Cnt',
#  'MV_Traf_Cont_out_s_Cnt',
#  'MV_Traf_Cont_out_v_Min',
#  'MV_Traf_R_inc_v_Min',
#  'MV_Traf_innet_out_s_Cnt',
#  'MV_Traf_innet_out_v_Min',
#  'MV_Traf_omo_out_v_Min',
#  'MV_Traf_pstn_inc_v_Min',
#  'MV_Traf_pstn_out_v_Min',
#  'MV_ap_4G_d',
#  'MV_ap_innet_out_v',
#  'MV_ap_mn_out_v',
#  'MV_ap_omo_out_v',
#  'MV_ap_pstn_out_v',
#  'MV_ap_s',
#  'MV_dou',
#  'MV_dou_2G_d',
#  'MV_dou_3G_d',
#  'MV_dou_4G_d',
#  'MV_dou_Roam_d',
#  'MV_dou_data',
#  'MV_dou_innet_out_v',
#  'MV_dou_omo_out_v',
#  'MV_dou_out_s',
#  'MV_net_total',
#  'MV_ot_4G_d',
#  'MV_ot_Roam_d',
#  'MV_ot_innet_out_v',
#  'MV_ot_total',
#  'TM_ID',
#  'abon_id',
#  'abon_part_td_mnt3',
#  'accum_oth_dur_td_mnt3',
#  'all_clc_td_mnt3',
#  'all_cnt_td_mnt3',
#  'all_home_clc_td_mnt3',
#  'all_roam_clc_td_mnt3',
#  'block_all_dur_td_mnt3',
#  'bs_count_change_tp',
#  'bs_count_ppm_mn3',
#  'bs_day_of_change_tp',
#  'bs_delte_mb_change_tp',
#  'bs_delte_omo_change_tp',
#  'bs_delte_ppd_change_tp',
#  'bs_delte_ppm_change_tp',
#  'bs_drop_call_rate',
#  'bs_drop_rate',
#  'bs_of_recall_m1',
#  'bs_of_succ_but_drop_m1',
#  'bs_of_unsucc_attemp_equip_m1',
#  'bs_ovrl_OMO_CNT_M2',
#  'bs_ovrl_OMO_CNT_M3',
#  'bs_ovrl_OMO_SUM_M3',
#  'bs_recall_rate',
#  'bs_succ_rate',
#  'clc_no_vas_roam_td_mnt3',
#  'cnt_bank_sms_category_awalbank',
#  'cnt_bank_sms_category_forwardban',
#  'cnt_bank_sms_category_monobank',
#  'cnt_bank_sms_category_mtbbank',
#  'cnt_bank_sms_category_otpbank',
#  'cnt_bank_sms_category_privatbank',
#  'cnt_bank_sms_category_vostokbank',
#  'cnt_paym_6_month',
#  'cnt_sms_category_bank',
#  'cnt_sms_category_poshta',
#  'cnt_sms_category_shop',
#  'cnt_sms_category_women',
#  'cnt_unq_category_microcred',
#  'cnt_unq_category_online_auth',
#  'conn_in_uniq_cnt_td_mnt3',
#  'conn_out_uniq_cnt_td_mnt3',
#  'content_clc_td_mnt3',
#  'content_cnt_td_mnt3',
#  'count_day_for_last_paym',
#  'data_3g_dou_td_mnt3',
#  'data_3g_tar_vol_td_mnt3',
#  'data_3g_tv_cnt_td_mnt3',
#  'day_end_gba',
#  'days_of_end_last_ppm',
#  'days_of_last_ppm',
#  'device_days_usage',
#  'device_has_LTE_BAND_3',
#  'device_height_mm',
#  'device_ios_version',
#  'device_price',
#  'device_width_mm',
#  'dpi_download',
#  'dpi_duration',
#  'dpi_events',
#  'dpi_upload',
#  'gprs_clc_td_mnt3',
#  'gprs_tar_vol_td_mnt3',
#  'imei_max_price',
#  'imei_mean_day_announced',
#  'imei_mean_days_usage',
#  'imei_mean_long_days_usage',
#  'imei_mean_price',
#  'ks_num_part_td_mnt3',
#  'last_paym',
#  'loc_cnt_events',
#  'loc_lat',
#  'loc_lon',
#  'loc_market_share',
#  'lt',
#  'myvf_day_usage',
#  'non_accum_internet_vol_td_mnt3',
#  'num_act_days_td_mnt3',
#  'pay_max_td_mnt3',
#  'pay_sum_td_mnt3',
#  'sms_clc_td_mnt3',
#  'sms_in_cnt_td_mnt3',
#  'sms_out_cnt_td_mnt3',
#  'sms_roam_clc_td_mnt3',
#  'sum_paym_6_month',
#  'tsoa_call_cnt',
#  'tsoa_direct_cnt',
#  'vas_clc_td_mnt3',
#  'voice_in_kievstar_part_td_mnt3',
#  'voice_in_life_part_td_mnt3',
#  'voice_in_mts_avg_dur_td_mnt3',
#  'voice_in_short_part_td_mnt3',
#  'voice_in_tar_dur_td_mnt3',
#  'voice_in_td_cnt_td_mnt3',
#  'voice_mts_in_nwork_part_td_mnt3',
#  'voice_mts_out_nwork_parttd_mnt3',
#  'voice_out_cmpttrs_td_cnttd_mnt3',
#  'voice_out_fix_tar_dur_td_mnt3',
#  'voice_out_short_part_td_mnt3',
#  'voice_out_tar_dur_td_mnt3',
#  'voice_out_td_cnt_td_mnt3']

# %%
bins = data_train.non_accum_internet_vol_td_mnt3_log_bins.cat.categories[data_train.non_accum_internet_vol_td_mnt3_log_bins.cat.categories.isin(\
                                    data_train.non_accum_internet_vol_td_mnt3_log_bins.cat.categories[0:5])]

non_accum_big = data_train.loc[data_train['non_accum_internet_vol_td_mnt3_log_bins'].isin(bins)]
non_accum_big = non_accum_big.drop(['non_accum_internet_vol_td_mnt3_log_bins','dpi_download_log_bins'],
                                   axis = 1).fillna(0)
non_accum_big.isna().sum()
# Out:
# abon_id                               0
# Balance_uah                           0
# TM_ID                                 0
# lt                                    0
# CALCULATION_METHOD_ID                 0
# device_days_usage                     0
# device_brand_samsung                  0
# device_brand_nokia                    0
# device_brand_lenovo                   0
# device_brand_apple                    0
# device_brand_huawei                   0
# device_brand_lg                       0
# device_brand_xiaomi                   0
# device_brand_meizu                    0
# device_brand_prestigio                0
# device_brand_sony                     0
# device_brand_nan                      0
# device_brand_other                    0
# device_android_version                0
# device_ios_version                    0
# device_has_gprs                       0
# device_has_wifi                       0
# device_has_lte                        0
# device_width_mm                       0
# device_height_mm                      0
# device_type_modem                     0
# device_type_module                    0
# device_type_phone                     0
# device_type_smartphone                0
# device_type_tablet                    0
# device_type_nan                       0
# device_type_rus_other                 0
# device_sim_count                      0
# device_price                          0
# loc_cnt_events                        0
# loc_is_obl_center                     0
# loc_lat                               0
# loc_lon                               0
# loc_market_share                      0
# bs_of_succ_but_drop_m1                0
# bs_of_succ_m1                         0
# bs_of_unsucc_attemp_equip_m1          0
# bs_of_unsucc_low_balance_m1           0
# bs_of_attemps_all_m1                  0
# bs_of_recall_m1                       0
# bs_succ_rate                          0
# bs_drop_call_rate                     0
# bs_drop_rate                          0
# bs_recall_rate                        0
# serv_req_type_cnt                     0
# serv_cost_sum                         0
# serv_long_req_cnt                     0
# serv_act_days_count                   0
# serv_add_4or2GB                       0
# serv_quick_call                       0
# serv_VF_bonus                         0
# serv_protect_SIM                      0
# serv_CLIR                             0
# serv_add_10min                        0
# serv_share_net                        0
# serv_road_net                         0
# serv_VIO_PASS                         0
# serv_smart_1m                         0
# serv_year_nopay                       0
# serv_voice_post                       0
# serv_rome_weekend                     0
# serv_UAnoUA_30min                     0
# tsoa_call_cnt                         0
# tsoa_direct_cnt                       0
# tsoa_chat_cnt                         0
# SMS                                   0
# Fax                                   0
# tsoa_mail_cnt                         0
# cnt_sms_category_bank                 0
# cnt_sms_category_avto                 0
# cnt_sms_category_olx                  0
# cnt_sms_category_online_auth          0
# cnt_sms_category_microcred            0
# cnt_sms_category_shop                 0
# cnt_sms_category_poshta               0
# cnt_sms_category_women                0
# cnt_sms_category_taxi                 0
# cnt_sms_category_fest                 0
# cnt_sms_category_ticket               0
# cnt_sms_category_collect              0
# cnt_unq_category_bank                 0
# cnt_unq_category_avto                 0
# cnt_unq_category_olx                  0
# cnt_unq_category_online_auth          0
# cnt_unq_category_microcred            0
# cnt_unq_category_shop                 0
# cnt_unq_category_poshta               0
# cnt_unq_category_women                0
# cnt_unq_category_taxi                 0
# cnt_unq_category_fest                 0
# cnt_unq_category_ticket               0
# cnt_unq_category_collect              0
# cnt_bank_sms_category_privatbank      0
# cnt_bank_sms_category_ukrgasbank      0
# cnt_bank_sms_category_otpbank         0
# cnt_bank_sms_category_alfabank        0
# cnt_bank_sms_category_ukrsibbank      0
# cnt_bank_sms_category_oschadbank      0
# cnt_bank_sms_category_tascombank      0
# cnt_bank_sms_category_awalbank        0
# cnt_bank_sms_category_abank           0
# cnt_bank_sms_category_mtbbank         0
# cnt_bank_sms_category_pumbbank        0
# cnt_bank_sms_category_agricoleba      0
# cnt_bank_sms_category_sberbank        0
# cnt_bank_sms_category_megabank        0
# cnt_bank_sms_category_forwardban      0
# cnt_bank_sms_category_monobank        0
# cnt_bank_sms_category_vostokbank      0
# cnt_bank_sms_category_pivdennyib      0
# cnt_bank_sms_category_ideabank        0
# cnt_bank_sms_category_globusbank      0
# cnt_bank_sms_category_creditdnep      0
# cnt_bank_sms_category_pravexbank      0
# cnt_bank_sms_category_kredobank       0
# cnt_bank_sms_category_bisbank         0
# cnt_bank_sms_category_ukreximban      0
# cnt_bank_sms_category_unexbank        0
# cnt_bank_sms_category_accordbank      0
# cnt_bank_sms_category_cominbank       0
# cnt_bank_sms_category_radabank        0
# DNZ_COUNT_closed_loan_year1           0
# DNZ_MAX_days_closed_loan_year1        0
# DNZ_MIN_days_closed_loan_year1        0
# DNZ_MEAN_days_closed_loan_year1       0
# DNZ_COUNT_open_loan_year1             0
# DNZ_MEAN_days_open_loan_year1         0
# DNZ_DAYS_from_last_year1              0
# MV_Migr_To                            0
# MV_DOU_Neg_Bal                        0
# MV_DOU_PPM_VF                         0
# MV_SERV_RLH                           0
# MV_SERV_Y_WO_AF                       0
# MV_dou_net                            0
# MV_dou_data                           0
# MV_dou_2G_d                           0
# MV_dou_3G_d                           0
# MV_dou_4G_d                           0
# MV_dou_innet_out_v                    0
# MV_dou_omo_out_v                      0
# MV_dou_mn_out_v                       0
# MV_dou_out_s                          0
# MV_dou_Roam                           0
# MV_dou_Roam_d                         0
# MV_dou_Roam_v                         0
# MV_dou                                0
# MV_FRAUD_BLOCK                        0
# MV_VLR_Guest                          0
# MV_ARPU_2G_d_Traf                     0
# MV_Traf_2G_d_Mb                       0
# MV_ARPU_3G_d_Traf                     0
# MV_Traf_3G_d_Mb                       0
# MV_ARPU_4G_d_Traf                     0
# MV_Traf_4G_d_Mb                       0
# MV_Traf_ACCA_out_v_Min                0
# MV_ARPU                               0
# MV_Traf_Cont_inc_s_Cnt                0
# MV_Traf_Cont_inc_v_Min                0
# MV_ARPU_Cont_out_s_Traf               0
# MV_Traf_Cont_out_s_Cnt                0
# MV_ARPU_Cont_out_v_Traf               0
# MV_Traf_Cont_out_v_Min                0
# MV_ARPU_Other_inc_v_Traf              0
# MV_Traf_Other_inc_v_Min               0
# MV_ARPU_Other_out_v_Traf              0
# MV_Traf_Other_out_v_Min               0
# MV_ARPU_R_inc_v_Traf                  0
# MV_Traf_R_inc_v_Min                   0
# MV_ARPU_R_out_s_Traf                  0
# MV_Traf_R_out_s_Cnt                   0
# MV_ARPU_R_out_v_Traf                  0
# MV_Traf_R_out_v_Min                   0
# MV_ARPU_Roam_d_Traf                   0
# MV_Traf_Roam_d_Mb                     0
# MV_ARPU_inc_s_Traf                    0
# MV_Traf_inc_s_Cnt                     0
# MV_ARPU_innet_inc_v_Traf              0
# MV_Traf_innet_inc_v_Min               0
# MV_ARPU_innet_out_s_Traf              0
# MV_Traf_innet_out_s_Cnt               0
# MV_ARPU_innet_out_v_Traf              0
# MV_Traf_innet_out_v_Min               0
# MV_Traf_mn_inc_v_Min                  0
# MV_ARPU_mn_out_s_Traf                 0
# MV_Traf_mn_out_s_Cnt                  0
# MV_ARPU_mn_out_v_Traf                 0
# MV_Traf_mn_out_v_Min                  0
# MV_Traf_omo_inc_v_Min                 0
# MV_ARPU_omo_out_s_Traf                0
# MV_Traf_omo_out_s_Cnt                 0
# MV_ARPU_omo_out_v_Traf                0
# MV_Traf_omo_out_v_Min                 0
# MV_Traf_pstn_inc_v_Min                0
# MV_ARPU_pstn_out_v_Traf               0
# MV_Traf_pstn_out_v_Min                0
# MV_net_total                          0
# MV_ap_2G_d                            0
# MV_ap_3G_d                            0
# MV_ap_4G_d                            0
# MV_ap_Cont_v                          0
# MV_ap_Other                           0
# MV_ap_Roam_d                          0
# MV_ap_inc_v                           0
# MV_ap_innet_out_v                     0
# MV_ap_mn_out_v                        0
# MV_ap_omo_out_v                       0
# MV_ap_pstn_out_v                      0
# MV_ap_s                               0
# MV_DOU_AP                             0
# MV_AP_total                           0
# MV_ot_3G_d                            0
# MV_ot_4G_d                            0
# MV_ot_Cont_v                          0
# MV_ot_Other                           0
# MV_ot_R_sm                            0
# MV_ot_R_v                             0
# MV_ot_Roam_d                          0
# MV_ot_Unkn                            0
# MV_ot_inc_v                           0
# MV_ot_innet_out_v                     0
# MV_ot_mn_out_v                        0
# MV_ot_omo_out_v                       0
# MV_ot_pstn_out_v                      0
# MV_ot_s                               0
# MV_DOU_OT                             0
# MV_ot_total                           0
# bs_count_change_tp                    0
# bs_arpu_change_tp                     0
# bs_day_of_change_tp                   0
# bs_direct_change_tp                   0
# bs_delte_mb_change_tp                 0
# bs_delte_omo_change_tp                0
# bs_delte_ppm_change_tp                0
# bs_delte_ppd_change_tp                0
# Good_deed                             0
# Internet                              0
# Minutes                               0
# Cars                                  0
# Shops                                 0
# AMA                                   0
# entertainment                         0
# Food                                  0
# days_of_last_ppm                      0
# days_of_end_last_ppm                  0
# active_ppm                            0
# bs_count_ppm_mn3                      0
# active_gba                            0
# day_end_gba                           0
# sum_paym_6_month                      0
# avg_paym_6_month                      0
# cnt_paym_6_month                      0
# max_paym_6_month                      0
# min_paym_6_month                      0
# std_paym_6_month                      0
# count_day_for_last_paym               0
# is_max_paym                           0
# is_avg_paym                           0
# last_paym                             0
# BS_OVERBUNDLE_MB_CNT_M1               0
# BS_OVERBUNDLE_MB_SUM_M1               0
# BS_OVERBUNDLE_MB_CNT_M2               0
# BS_OVERBUNDLE_MB_SUM_M2               0
# BS_OVERBUNDLE_MB_CNT_M3               0
# BS_OVERBUNDLE_MB_SUM_M3               0
# bs_ovrl_OMO_CNT_M3                    0
# bs_ovrl_OMO_SUM_M3                    0
# bs_ovrl_OMO_CNT_M2                    0
# bs_ovrl_OMO_SUM_M2                    0
# bs_ovrl_OMO_CNT_M1                    0
# bs_ovrl_OMO_SUM_M1                    0
# voice_out_short_part_mea_wk1          0
# voice_out_short_part_mea_mnt1         0
# voice_out_short_part_max_mnt1         0
# voice_out_short_part_min_mnt1         0
# voice_out_short_part_std_mnt1         0
# voice_out_short_part_mea_mnt3         0
# voice_out_short_part_max_mnt3         0
# voice_out_short_part_min_mnt3         0
# voice_out_short_part_std_mnt3         0
# voice_out_short_part_td_mnt3          0
# voice_in_short_part_mea_wk1           0
# voice_in_short_part_mea_mnt1          0
# voice_in_short_part_max_mnt1          0
# voice_in_short_part_min_mnt1          0
# voice_in_short_part_std_mnt1          0
# voice_in_short_part_mea_mnt3          0
# voice_in_short_part_max_mnt3          0
# voice_in_short_part_min_mnt3          0
# voice_in_short_part_std_mnt3          0
# voice_in_short_part_td_mnt3           0
# voice_in_fix_tar_dur_mea_wk1          0
# voice_in_fix_tar_dur_mea_mnt1         0
# voice_in_fix_tar_dur_max_mnt1         0
# voice_in_fix_tar_dur_min_mnt1         0
# voice_in_fix_tar_dur_std_mnt1         0
# voice_in_fix_tar_dur_mea_mnt3         0
# voice_in_fix_tar_dur_max_mnt3         0
# voice_in_fix_tar_dur_min_mnt3         0
# voice_in_fix_tar_dur_std_mnt3         0
# voice_in_fix_tar_dur_td_mnt3          0
# voice_out_fix_tar_dur_mea_wk1         0
# voice_out_fix_tar_dur_mea_mnt1        0
# voice_out_fix_tar_dur_max_mnt1        0
# voice_out_fix_tar_dur_min_mnt1        0
# voice_out_fix_tar_dur_std_mnt1        0
# voice_out_fix_tar_dur_mea_mnt3        0
# voice_out_fix_tar_dur_max_mnt3        0
# voice_out_fix_tar_dur_min_mnt3        0
# voice_out_fix_tar_dur_std_mnt3        0
# voice_out_fix_tar_dur_td_mnt3         0
# voice_in_life_part_mea_wk1            0
# voice_in_life_part_mea_mnt1           0
# voice_in_life_part_max_mnt1           0
# voice_in_life_part_min_mnt1           0
# voice_in_life_part_std_mnt1           0
# voice_in_life_part_mea_mnt3           0
# voice_in_life_part_max_mnt3           0
# voice_in_life_part_min_mnt3           0
# voice_in_life_part_std_mnt3           0
# voice_in_life_part_td_mnt3            0
# voice_in_kievstar_part_mea_wk1        0
# voice_in_kievstar_part_mea_mnt1       0
# voice_in_kievstar_part_max_mnt1       0
# voice_in_kievstar_part_min_mnt1       0
# voice_in_kievstar_part_std_mnt1       0
# voice_in_kievstar_part_mea_mnt3       0
# voice_in_kievstar_part_max_mnt3       0
# voice_in_kievstar_part_min_mnt3       0
# voice_in_kievstar_part_std_mnt3       0
# voice_in_kievstar_part_td_mnt3        0
# voice_out_cmpttrs_avg_dumea_wk1       0
# voice_out_cmpttrs_avg_dumea_mnt1      0
# voice_out_cmpttrs_avg_dumax_mnt1      0
# voice_out_cmpttrs_avg_dumin_mnt1      0
# voice_out_cmpttrs_avg_dustd_mnt1      0
# voice_out_cmpttrs_avg_dumea_mnt3      0
# voice_out_cmpttrs_avg_dumax_mnt3      0
# voice_out_cmpttrs_avg_dumin_mnt3      0
# voice_out_cmpttrs_avg_dustd_mnt3      0
# voice_out_cmpttrs_avg_dutd_mnt3       0
# voice_in_cmpttrs_avg_durmea_wk1       0
# voice_in_cmpttrs_avg_durmea_mnt1      0
# voice_in_cmpttrs_avg_durmax_mnt1      0
# voice_in_cmpttrs_avg_durmin_mnt1      0
# voice_in_cmpttrs_avg_durstd_mnt1      0
# voice_in_cmpttrs_avg_durmea_mnt3      0
# voice_in_cmpttrs_avg_durmax_mnt3      0
# voice_in_cmpttrs_avg_durmin_mnt3      0
# voice_in_cmpttrs_avg_durstd_mnt3      0
# voice_in_cmpttrs_avg_durtd_mnt3       0
# voice_in_cmpttrs_td_cnt_mea_wk1       0
# voice_in_cmpttrs_td_cnt_mea_mnt1      0
# voice_in_cmpttrs_td_cnt_max_mnt1      0
# voice_in_cmpttrs_td_cnt_min_mnt1      0
# voice_in_cmpttrs_td_cnt_std_mnt1      0
# voice_in_cmpttrs_td_cnt_mea_mnt3      0
# voice_in_cmpttrs_td_cnt_max_mnt3      0
# voice_in_cmpttrs_td_cnt_min_mnt3      0
# voice_in_cmpttrs_td_cnt_std_mnt3      0
# voice_in_cmpttrs_td_cnt_td_mnt3       0
# voice_out_cmpttrs_td_cntmea_wk1       0
# voice_out_cmpttrs_td_cntmea_mnt1      0
# voice_out_cmpttrs_td_cntmax_mnt1      0
# voice_out_cmpttrs_td_cntmin_mnt1      0
# voice_out_cmpttrs_td_cntstd_mnt1      0
# voice_out_cmpttrs_td_cntmea_mnt3      0
# voice_out_cmpttrs_td_cntmax_mnt3      0
# voice_out_cmpttrs_td_cntmin_mnt3      0
# voice_out_cmpttrs_td_cntstd_mnt3      0
# voice_out_cmpttrs_td_cnttd_mnt3       0
# voice_in_mts_avg_dur_mea_wk1          0
# voice_in_mts_avg_dur_mea_mnt1         0
# voice_in_mts_avg_dur_max_mnt1         0
# voice_in_mts_avg_dur_min_mnt1         0
# voice_in_mts_avg_dur_std_mnt1         0
# voice_in_mts_avg_dur_mea_mnt3         0
# voice_in_mts_avg_dur_max_mnt3         0
# voice_in_mts_avg_dur_min_mnt3         0
# voice_in_mts_avg_dur_std_mnt3         0
# voice_in_mts_avg_dur_td_mnt3          0
# voice_mts_out_dwork_partmea_wk1       0
# voice_mts_out_dwork_partmea_mnt1      0
# voice_mts_out_dwork_partmax_mnt1      0
# voice_mts_out_dwork_partmin_mnt1      0
# voice_mts_out_dwork_partstd_mnt1      0
# voice_mts_out_dwork_partmea_mnt3      0
# voice_mts_out_dwork_partmax_mnt3      0
# voice_mts_out_dwork_partmin_mnt3      0
# voice_mts_out_dwork_partstd_mnt3      0
# voice_mts_out_dwork_parttd_mnt3       0
# voice_mts_in_dwork_part_mea_wk1       0
# voice_mts_in_dwork_part_mea_mnt1      0
# voice_mts_in_dwork_part_max_mnt1      0
# voice_mts_in_dwork_part_min_mnt1      0
# voice_mts_in_dwork_part_std_mnt1      0
# voice_mts_in_dwork_part_mea_mnt3      0
# voice_mts_in_dwork_part_max_mnt3      0
# voice_mts_in_dwork_part_min_mnt3      0
# voice_mts_in_dwork_part_std_mnt3      0
# voice_mts_in_dwork_part_td_mnt3       0
# voice_mts_in_nwork_part_mea_wk1       0
# voice_mts_in_nwork_part_mea_mnt1      0
# voice_mts_in_nwork_part_max_mnt1      0
# voice_mts_in_nwork_part_min_mnt1      0
# voice_mts_in_nwork_part_std_mnt1      0
# voice_mts_in_nwork_part_mea_mnt3      0
# voice_mts_in_nwork_part_max_mnt3      0
# voice_mts_in_nwork_part_min_mnt3      0
# voice_mts_in_nwork_part_std_mnt3      0
# voice_mts_in_nwork_part_td_mnt3       0
# voice_mts_out_nwork_partmea_wk1       0
# voice_mts_out_nwork_partmea_mnt1      0
# voice_mts_out_nwork_partmax_mnt1      0
# voice_mts_out_nwork_partmin_mnt1      0
# voice_mts_out_nwork_partstd_mnt1      0
# voice_mts_out_nwork_partmea_mnt3      0
# voice_mts_out_nwork_partmax_mnt3      0
# voice_mts_out_nwork_partmin_mnt3      0
# voice_mts_out_nwork_partstd_mnt3      0
# voice_mts_out_nwork_parttd_mnt3       0
# voice_mts_in_drest_part_mea_wk1       0
# voice_mts_in_drest_part_mea_mnt1      0
# voice_mts_in_drest_part_max_mnt1      0
# voice_mts_in_drest_part_min_mnt1      0
# voice_mts_in_drest_part_std_mnt1      0
# voice_mts_in_drest_part_mea_mnt3      0
# voice_mts_in_drest_part_max_mnt3      0
# voice_mts_in_drest_part_min_mnt3      0
# voice_mts_in_drest_part_std_mnt3      0
# voice_mts_in_drest_part_td_mnt3       0
# voice_mts_out_drest_partmea_wk1       0
# voice_mts_out_drest_partmea_mnt1      0
# voice_mts_out_drest_partmax_mnt1      0
# voice_mts_out_drest_partmin_mnt1      0
# voice_mts_out_drest_partstd_mnt1      0
# voice_mts_out_drest_partmea_mnt3      0
# voice_mts_out_drest_partmax_mnt3      0
# voice_mts_out_drest_partmin_mnt3      0
# voice_mts_out_drest_partstd_mnt3      0
# voice_mts_out_drest_parttd_mnt3       0
# voice_mts_in_nrest_part_mea_wk1       0
# voice_mts_in_nrest_part_mea_mnt1      0
# voice_mts_in_nrest_part_max_mnt1      0
# voice_mts_in_nrest_part_min_mnt1      0
# voice_mts_in_nrest_part_std_mnt1      0
# voice_mts_in_nrest_part_mea_mnt3      0
# voice_mts_in_nrest_part_max_mnt3      0
# voice_mts_in_nrest_part_min_mnt3      0
# voice_mts_in_nrest_part_std_mnt3      0
# voice_mts_in_nrest_part_td_mnt3       0
# voice_mts_out_nrest_partmea_wk1       0
# voice_mts_out_nrest_partmea_mnt1      0
# voice_mts_out_nrest_partmax_mnt1      0
# voice_mts_out_nrest_partmin_mnt1      0
# voice_mts_out_nrest_partstd_mnt1      0
# voice_mts_out_nrest_partmea_mnt3      0
# voice_mts_out_nrest_partmax_mnt3      0
# voice_mts_out_nrest_partmin_mnt3      0
# voice_mts_out_nrest_partstd_mnt3      0
# voice_mts_out_nrest_parttd_mnt3       0
# voice_out_tar_dur_mea_wk1             0
# voice_out_tar_dur_mea_mnt1            0
# voice_out_tar_dur_max_mnt1            0
# voice_out_tar_dur_min_mnt1            0
# voice_out_tar_dur_std_mnt1            0
# voice_out_tar_dur_mea_mnt3            0
# voice_out_tar_dur_max_mnt3            0
# voice_out_tar_dur_min_mnt3            0
# voice_out_tar_dur_std_mnt3            0
# voice_out_tar_dur_td_mnt3             0
# voice_in_td_cnt_mea_wk1               0
# voice_in_td_cnt_mea_mnt1              0
# voice_in_td_cnt_max_mnt1              0
# voice_in_td_cnt_min_mnt1              0
# voice_in_td_cnt_std_mnt1              0
# voice_in_td_cnt_mea_mnt3              0
# voice_in_td_cnt_max_mnt3              0
# voice_in_td_cnt_min_mnt3              0
# voice_in_td_cnt_std_mnt3              0
# voice_in_td_cnt_td_mnt3               0
# voice_in_tar_dur_mea_wk1              0
# voice_in_tar_dur_mea_mnt1             0
# voice_in_tar_dur_max_mnt1             0
# voice_in_tar_dur_min_mnt1             0
# voice_in_tar_dur_std_mnt1             0
# voice_in_tar_dur_mea_mnt3             0
# voice_in_tar_dur_max_mnt3             0
# voice_in_tar_dur_min_mnt3             0
# voice_in_tar_dur_std_mnt3             0
# voice_in_tar_dur_td_mnt3              0
# voice_out_td_cnt_mea_wk1              0
# voice_out_td_cnt_mea_mnt1             0
# voice_out_td_cnt_max_mnt1             0
# voice_out_td_cnt_min_mnt1             0
# voice_out_td_cnt_std_mnt1             0
# voice_out_td_cnt_mea_mnt3             0
# voice_out_td_cnt_max_mnt3             0
# voice_out_td_cnt_min_mnt3             0
# voice_out_td_cnt_std_mnt3             0
# voice_out_td_cnt_td_mnt3              0
# sms_in_cnt_mea_wk1                    0
# sms_in_cnt_mea_mnt1                   0
# sms_in_cnt_max_mnt1                   0
# sms_in_cnt_min_mnt1                   0
# sms_in_cnt_std_mnt1                   0
# sms_in_cnt_mea_mnt3                   0
# sms_in_cnt_max_mnt3                   0
# sms_in_cnt_min_mnt3                   0
# sms_in_cnt_std_mnt3                   0
# sms_in_cnt_td_mnt3                    0
# sms_out_cnt_mea_wk1                   0
# sms_out_cnt_mea_mnt1                  0
# sms_out_cnt_max_mnt1                  0
# sms_out_cnt_min_mnt1                  0
# sms_out_cnt_std_mnt1                  0
# sms_out_cnt_mea_mnt3                  0
# sms_out_cnt_max_mnt3                  0
# sms_out_cnt_min_mnt3                  0
# sms_out_cnt_std_mnt3                  0
# sms_out_cnt_td_mnt3                   0
# vas_clc_mea_wk1                       0
# vas_clc_mea_mnt1                      0
# vas_clc_max_mnt1                      0
# vas_clc_min_mnt1                      0
# vas_clc_std_mnt1                      0
# vas_clc_mea_mnt3                      0
# vas_clc_max_mnt3                      0
# vas_clc_min_mnt3                      0
# vas_clc_std_mnt3                      0
# vas_clc_td_mnt3                       0
# pay_p2p_in_sum_mea_wk1                0
# pay_p2p_in_sum_mea_mnt1               0
# pay_p2p_in_sum_max_mnt1               0
# pay_p2p_in_sum_min_mnt1               0
# pay_p2p_in_sum_std_mnt1               0
# pay_p2p_in_sum_mea_mnt3               0
# pay_p2p_in_sum_max_mnt3               0
# pay_p2p_in_sum_min_mnt3               0
# pay_p2p_in_sum_std_mnt3               0
# pay_p2p_in_sum_td_mnt3                0
# pay_p2p_out_sum_mea_wk1               0
# pay_p2p_out_sum_mea_mnt1              0
# pay_p2p_out_sum_max_mnt1              0
# pay_p2p_out_sum_min_mnt1              0
# pay_p2p_out_sum_std_mnt1              0
# pay_p2p_out_sum_mea_mnt3              0
# pay_p2p_out_sum_max_mnt3              0
# pay_p2p_out_sum_min_mnt3              0
# pay_p2p_out_sum_std_mnt3              0
# pay_p2p_out_sum_td_mnt3               0
# pay_avg_mea_wk1                       0
# pay_avg_mea_mnt1                      0
# pay_avg_max_mnt1                      0
# pay_avg_min_mnt1                      0
# pay_avg_std_mnt1                      0
# pay_avg_mea_mnt3                      0
# pay_avg_max_mnt3                      0
# pay_avg_min_mnt3                      0
# pay_avg_std_mnt3                      0
# pay_avg_td_mnt3                       0
# pay_max_mea_wk1                       0
# pay_max_mea_mnt1                      0
# pay_max_max_mnt1                      0
# pay_max_min_mnt1                      0
# pay_max_std_mnt1                      0
# pay_max_mea_mnt3                      0
# pay_max_max_mnt3                      0
# pay_max_min_mnt3                      0
# pay_max_std_mnt3                      0
# pay_max_td_mnt3                       0
# pay_sum_mea_wk1                       0
# pay_sum_mea_mnt1                      0
# pay_sum_max_mnt1                      0
# pay_sum_min_mnt1                      0
# pay_sum_std_mnt1                      0
# pay_sum_mea_mnt3                      0
# pay_sum_max_mnt3                      0
# pay_sum_min_mnt3                      0
# pay_sum_std_mnt3                      0
# pay_sum_td_mnt3                       0
# num_act_days_mea_wk1                  0
# num_act_days_mea_mnt1                 0
# num_act_days_max_mnt1                 0
# num_act_days_min_mnt1                 0
# num_act_days_std_mnt1                 0
# num_act_days_mea_mnt3                 0
# num_act_days_max_mnt3                 0
# num_act_days_min_mnt3                 0
# num_act_days_std_mnt3                 0
# num_act_days_td_mnt3                  0
# non_accum_internet_vol_mea_wk1        0
# non_accum_internet_vol_mea_mnt1       0
# non_accum_internet_vol_max_mnt1       0
# non_accum_internet_vol_min_mnt1       0
# non_accum_internet_vol_std_mnt1       0
# non_accum_internet_vol_mea_mnt3       0
# non_accum_internet_vol_max_mnt3       0
# non_accum_internet_vol_min_mnt3       0
# non_accum_internet_vol_std_mnt3       0
# non_accum_internet_vol_td_mnt3        0
# ks_num_part_mea_wk1                   0
# ks_num_part_mea_mnt1                  0
# ks_num_part_max_mnt1                  0
# ks_num_part_min_mnt1                  0
# ks_num_part_std_mnt1                  0
# ks_num_part_mea_mnt3                  0
# ks_num_part_max_mnt3                  0
# ks_num_part_min_mnt3                  0
# ks_num_part_std_mnt3                  0
# ks_num_part_td_mnt3                   0
# gprs_clc_mea_wk1                      0
# gprs_clc_mea_mnt1                     0
# gprs_clc_max_mnt1                     0
# gprs_clc_min_mnt1                     0
# gprs_clc_std_mnt1                     0
# gprs_clc_mea_mnt3                     0
# gprs_clc_max_mnt3                     0
# gprs_clc_min_mnt3                     0
# gprs_clc_std_mnt3                     0
# gprs_clc_td_mnt3                      0
# gprs_tar_vol_mea_wk1                  0
# gprs_tar_vol_mea_mnt1                 0
# gprs_tar_vol_max_mnt1                 0
# gprs_tar_vol_min_mnt1                 0
# gprs_tar_vol_std_mnt1                 0
# gprs_tar_vol_mea_mnt3                 0
# gprs_tar_vol_max_mnt3                 0
# gprs_tar_vol_min_mnt3                 0
# gprs_tar_vol_std_mnt3                 0
# gprs_tar_vol_td_mnt3                  0
# data_3g_dou_mea_wk1                   0
# data_3g_dou_mea_mnt1                  0
# data_3g_dou_max_mnt1                  0
# data_3g_dou_min_mnt1                  0
# data_3g_dou_std_mnt1                  0
# data_3g_dou_mea_mnt3                  0
# data_3g_dou_max_mnt3                  0
# data_3g_dou_min_mnt3                  0
# data_3g_dou_std_mnt3                  0
# data_3g_dou_td_mnt3                   0
# data_3g_tar_vol_mea_wk1               0
# data_3g_tar_vol_mea_mnt1              0
# data_3g_tar_vol_max_mnt1              0
# data_3g_tar_vol_min_mnt1              0
# data_3g_tar_vol_std_mnt1              0
# data_3g_tar_vol_mea_mnt3              0
# data_3g_tar_vol_max_mnt3              0
# data_3g_tar_vol_min_mnt3              0
# data_3g_tar_vol_std_mnt3              0
# data_3g_tar_vol_td_mnt3               0
# data_3g_tv_cnt_mea_wk1                0
# data_3g_tv_cnt_mea_mnt1               0
# data_3g_tv_cnt_max_mnt1               0
# data_3g_tv_cnt_min_mnt1               0
# data_3g_tv_cnt_std_mnt1               0
# data_3g_tv_cnt_mea_mnt3               0
# data_3g_tv_cnt_max_mnt3               0
# data_3g_tv_cnt_min_mnt3               0
# data_3g_tv_cnt_std_mnt3               0
# data_3g_tv_cnt_td_mnt3                0
# content_cnt_mea_wk1                   0
# content_cnt_mea_mnt1                  0
# content_cnt_max_mnt1                  0
# content_cnt_min_mnt1                  0
# content_cnt_std_mnt1                  0
# content_cnt_mea_mnt3                  0
# content_cnt_max_mnt3                  0
# content_cnt_min_mnt3                  0
# content_cnt_std_mnt3                  0
# content_cnt_td_mnt3                   0
# content_clc_mea_wk1                   0
# content_clc_mea_mnt1                  0
# content_clc_max_mnt1                  0
# content_clc_min_mnt1                  0
# content_clc_std_mnt1                  0
# content_clc_mea_mnt3                  0
# content_clc_max_mnt3                  0
# content_clc_min_mnt3                  0
# content_clc_std_mnt3                  0
# content_clc_td_mnt3                   0
# conn_out_uniq_cnt_mea_wk1             0
# conn_out_uniq_cnt_mea_mnt1            0
# conn_out_uniq_cnt_max_mnt1            0
# conn_out_uniq_cnt_min_mnt1            0
# conn_out_uniq_cnt_std_mnt1            0
# conn_out_uniq_cnt_mea_mnt3            0
# conn_out_uniq_cnt_max_mnt3            0
# conn_out_uniq_cnt_min_mnt3            0
# conn_out_uniq_cnt_std_mnt3            0
# conn_out_uniq_cnt_td_mnt3             0
# conn_in_uniq_cnt_mea_wk1              0
# conn_in_uniq_cnt_mea_mnt1             0
# conn_in_uniq_cnt_max_mnt1             0
# conn_in_uniq_cnt_min_mnt1             0
# conn_in_uniq_cnt_std_mnt1             0
# conn_in_uniq_cnt_mea_mnt3             0
# conn_in_uniq_cnt_max_mnt3             0
# conn_in_uniq_cnt_min_mnt3             0
# conn_in_uniq_cnt_std_mnt3             0
# conn_in_uniq_cnt_td_mnt3              0
# conn_com_part_mea_wk1                 0
# conn_com_part_mea_mnt1                0
# conn_com_part_max_mnt1                0
# conn_com_part_min_mnt1                0
# conn_com_part_std_mnt1                0
# conn_com_part_mea_mnt3                0
# conn_com_part_max_mnt3                0
# conn_com_part_min_mnt3                0
# conn_com_part_std_mnt3                0
# conn_com_part_td_mnt3                 0
# com_num_part_mea_wk1                  0
# com_num_part_mea_mnt1                 0
# com_num_part_max_mnt1                 0
# com_num_part_min_mnt1                 0
# com_num_part_std_mnt1                 0
# com_num_part_mea_mnt3                 0
# com_num_part_max_mnt3                 0
# com_num_part_min_mnt3                 0
# com_num_part_std_mnt3                 0
# com_num_part_td_mnt3                  0
# clc_no_vas_roam_mea_wk1               0
# clc_no_vas_roam_mea_mnt1              0
# clc_no_vas_roam_max_mnt1              0
# clc_no_vas_roam_min_mnt1              0
# clc_no_vas_roam_std_mnt1              0
# clc_no_vas_roam_mea_mnt3              0
# clc_no_vas_roam_max_mnt3              0
# clc_no_vas_roam_min_mnt3              0
# clc_no_vas_roam_std_mnt3              0
# clc_no_vas_roam_td_mnt3               0
# block_all_dur_mea_wk1                 0
# block_all_dur_mea_mnt1                0
# block_all_dur_max_mnt1                0
# block_all_dur_min_mnt1                0
# block_all_dur_std_mnt1                0
# block_all_dur_mea_mnt3                0
# block_all_dur_max_mnt3                0
# block_all_dur_min_mnt3                0
# block_all_dur_std_mnt3                0
# block_all_dur_td_mnt3                 0
# Ama_rchrgmnt_sum_mea_wk1              0
# Ama_rchrgmnt_sum_mea_mnt1             0
# Ama_rchrgmnt_sum_max_mnt1             0
# Ama_rchrgmnt_sum_min_mnt1             0
# Ama_rchrgmnt_sum_std_mnt1             0
# Ama_rchrgmnt_sum_mea_mnt3             0
# Ama_rchrgmnt_sum_max_mnt3             0
# Ama_rchrgmnt_sum_min_mnt3             0
# Ama_rchrgmnt_sum_std_mnt3             0
# Ama_rchrgmnt_sum_td_mnt3              0
# ama_volume_mea_wk1                    0
# ama_volume_mea_mnt1                   0
# ama_volume_max_mnt1                   0
# ama_volume_min_mnt1                   0
# ama_volume_std_mnt1                   0
# ama_volume_mea_mnt3                   0
# ama_volume_max_mnt3                   0
# ama_volume_min_mnt3                   0
# ama_volume_std_mnt3                   0
# ama_volume_td_mnt3                    0
# all_cnt_mea_wk1                       0
# all_cnt_mea_mnt1                      0
# all_cnt_max_mnt1                      0
# all_cnt_min_mnt1                      0
# all_cnt_std_mnt1                      0
# all_cnt_mea_mnt3                      0
# all_cnt_max_mnt3                      0
# all_cnt_min_mnt3                      0
# all_cnt_std_mnt3                      0
# all_cnt_td_mnt3                       0
# all_home_clc_mea_wk1                  0
# all_home_clc_mea_mnt1                 0
# all_home_clc_max_mnt1                 0
# all_home_clc_min_mnt1                 0
# all_home_clc_std_mnt1                 0
# all_home_clc_mea_mnt3                 0
# all_home_clc_max_mnt3                 0
# all_home_clc_min_mnt3                 0
# all_home_clc_std_mnt3                 0
# all_home_clc_td_mnt3                  0
# all_clc_mea_wk1                       0
# all_clc_mea_mnt1                      0
# all_clc_max_mnt1                      0
# all_clc_min_mnt1                      0
# all_clc_std_mnt1                      0
# all_clc_mea_mnt3                      0
# all_clc_max_mnt3                      0
# all_clc_min_mnt3                      0
# all_clc_std_mnt3                      0
# all_clc_td_mnt3                       0
# all_roam_clc_mea_wk1                  0
# all_roam_clc_mea_mnt1                 0
# all_roam_clc_max_mnt1                 0
# all_roam_clc_min_mnt1                 0
# all_roam_clc_std_mnt1                 0
# all_roam_clc_mea_mnt3                 0
# all_roam_clc_max_mnt3                 0
# all_roam_clc_min_mnt3                 0
# all_roam_clc_std_mnt3                 0
# all_roam_clc_td_mnt3                  0
# accum_oth_dur_mea_wk1                 0
# accum_oth_dur_mea_mnt1                0
# accum_oth_dur_max_mnt1                0
# accum_oth_dur_min_mnt1                0
# accum_oth_dur_std_mnt1                0
# accum_oth_dur_mea_mnt3                0
# accum_oth_dur_max_mnt3                0
# accum_oth_dur_min_mnt3                0
# accum_oth_dur_std_mnt3                0
# accum_oth_dur_td_mnt3                 0
# accum_mts_dur_mea_wk1                 0
# accum_mts_dur_mea_mnt1                0
# accum_mts_dur_max_mnt1                0
# accum_mts_dur_min_mnt1                0
# accum_mts_dur_std_mnt1                0
# accum_mts_dur_mea_mnt3                0
# accum_mts_dur_max_mnt3                0
# accum_mts_dur_min_mnt3                0
# accum_mts_dur_std_mnt3                0
# accum_mts_dur_td_mnt3                 0
# abon_part_mea_wk1                     0
# abon_part_mea_mnt1                    0
# abon_part_max_mnt1                    0
# abon_part_min_mnt1                    0
# abon_part_std_mnt1                    0
# abon_part_mea_mnt3                    0
# abon_part_max_mnt3                    0
# abon_part_min_mnt3                    0
# abon_part_std_mnt3                    0
# abon_part_td_mnt3                     0
# goodok_clc_mea_wk1                    0
# goodok_clc_mea_mnt1                   0
# goodok_clc_max_mnt1                   0
# goodok_clc_min_mnt1                   0
# goodok_clc_std_mnt1                   0
# goodok_clc_mea_mnt3                   0
# goodok_clc_max_mnt3                   0
# goodok_clc_min_mnt3                   0
# goodok_clc_std_mnt3                   0
# goodok_clc_td_mnt3                    0
# sms_clc_mea_wk1                       0
# sms_clc_mea_mnt1                      0
# sms_clc_max_mnt1                      0
# sms_clc_min_mnt1                      0
# sms_clc_std_mnt1                      0
# sms_clc_mea_mnt3                      0
# sms_clc_max_mnt3                      0
# sms_clc_min_mnt3                      0
# sms_clc_std_mnt3                      0
# sms_clc_td_mnt3                       0
# sms_roam_clc_mea_wk1                  0
# sms_roam_clc_mea_mnt1                 0
# sms_roam_clc_max_mnt1                 0
# sms_roam_clc_min_mnt1                 0
# sms_roam_clc_std_mnt1                 0
# sms_roam_clc_mea_mnt3                 0
# sms_roam_clc_max_mnt3                 0
# sms_roam_clc_min_mnt3                 0
# sms_roam_clc_std_mnt3                 0
# sms_roam_clc_td_mnt3                  0
# voice_in_roam_clc_mea_wk1             0
# voice_in_roam_clc_mea_mnt1            0
# voice_in_roam_clc_max_mnt1            0
# voice_in_roam_clc_min_mnt1            0
# voice_in_roam_clc_std_mnt1            0
# voice_in_roam_clc_mea_mnt3            0
# voice_in_roam_clc_max_mnt3            0
# voice_in_roam_clc_min_mnt3            0
# voice_in_roam_clc_std_mnt3            0
# voice_in_roam_clc_td_mnt3             0
# dpi_duration                          0
# dpi_upload                            0
# dpi_download                          0
# dpi_events                            0
# dpi_day_cnt                           0
# DNZ_COUNT_closed_loan_year2           0
# DNZ_MAX_days_closed_loan_year2        0
# DNZ_MIN_days_closed_loan_year2        0
# DNZ_STD_days_closed_loan_year2        0
# DNZ_MEAN_days_closed_loan_year2       0
# DNZ_COUNT_open_loan_year2             0
# DNZ_MEAN_days_open_loan_year2         0
# DNZ_DAYS_from_last_year2              0
# DNZ_COUNT_closed_loan_year5           0
# DNZ_MAX_days_closed_loan_year5        0
# DNZ_MIN_days_closed_loan_year5        0
# DNZ_STD_days_closed_loan_year5        0
# DNZ_MEAN_days_closed_loan_year5       0
# DNZ_COUNT_open_loan_year5             0
# DNZ_MEAN_days_open_loan_year5         0
# DNZ_DAYS_from_last_year5              0
# imei_mean_days_usage                  0
# imei_mean_long_days_usage             0
# imei_mean_price                       0
# imei_max_price                        0
# imei_mean_day_announced               0
# device_has_hardware_umts              0
# device_has_LTE_BAND_3                 0
# myvf_day_usage                        0
# GBA_remain_days                       0
# target                                0
# traff_m5                              0
# traff_m4                              0
# traff_m3                              0
# traff_m2                              0
# traff_m1                              0
# var                                   0
# var_quant                             0
# slope_traff                           0
# z_score_slope                         0
# big_slope                             0
# big_var                               0
# non_accum_internet_vol_td_mnt3_log    0
# dpi_download_log                      0
# dtype: int64

# %%
labels = non_accum_big['big_slope']

fig = plt.figure()
    
ax = fig.add_subplot(1, 1, 1, projection='3d')

ax.scatter(non_accum_big['non_accum_internet_vol_td_mnt3_log'],
           non_accum_big['dpi_download_log'], 
           non_accum_big['target'], 
           zdir='z', s=20, c = labels, cmap='coolwarm', depthshade=True)

plt.show()

# %%
symlog = data_train['dpi_download'].apply(lambda x: -np.log10(-x) if x < 0 else np.log10(x) if x > 0 else 0)
data_train = data_train.assign(dpi_download_log = symlog)

symlog = data_test['dpi_download'].apply(lambda x: -np.log10(-x) if x < 0 else np.log10(x) if x > 0 else 0)
data_test = data_test.assign(dpi_download_log = symlog)

data_train = data_train.assign(dpi_download_log_bins = pd.cut(data_train['dpi_download_log'], 
                                                                                bins=range(-19, 19)))

data_test = data_test.assign(dpi_download_log_bins = pd.cut(data_test['dpi_download_log'], 
                                                                                bins=range(-19, 19)))

del symlog

# %%
# temp = data_train.iloc[0:1000, :]
ratio_df = ratio_diagram(data_train, ['abon_id'], ['dpi_download_log_bins'], ['big_var'], ['small_var', 'big_var'])

# %%
ratio_df = ratio_diagram(data_train, ['abon_id'], ['TM_ID'], ['big_var'], ['small_var', 'big_var'])

# %%
TM_ID_big_var = ratio_df[ratio_df['ratio'] > 1].index
TM_ID_big_var
# Out:
# Float64Index([60.53311538696289, 72.03165435791016, 72.03514862060547,
#               72.21271514892578, 72.22657012939453],
#              dtype='float64', name='TM_ID')

# %%
data_train['MV_ap_innet_out_v'].unique()
# Out:
# array([0.6714777 , 0.31014866, 0.26148185, ..., 0.07310907, 0.01980476,
#        0.0326895 ], dtype=float32)

# %%
ratio_df = ratio_diagram(data_train, ['abon_id'], ['MV_ap_innet_out_v'], ['big_var'], ['small_var', 'big_var'])

# %%
fig = sns.scatterplot(x=data_train['var'], y=data_train['MV_ap_innet_out_v'], hue=data_train['big_var'])
fig.set(xlim = (-100,10000))

# %%
fig = sns.scatterplot(x=data_train['var'], y=data_train['sum_paym_6_month'], hue=data_train['big_var'])
fig.set(xlim = (-100,10000))

# %%
# X_train_full = data_train[big_slope_important_ft]
X_train_full = data_train.drop(traffic_cols + ['target', 'var', 'var_quant', 'slope_traff', 'z_score_slope', 'big_slope'], 
                               axis = 1)

y_train_full = data_train['var']


model = ltb.LGBMRegressor(objective ='regression',
                           random_state = 0)


model.fit(X_train_full,y_train_full)

y_train_pred = model.predict(X_train_full)

print('RMSE train: {:.6f}'.format(
        mean_squared_error(y_train_full, y_train_pred, squared = False)))
print('R^2 train: {:.6f}'.format(
        r2_score(y_train_full, y_train_pred)))

# %%
var_features = pd.DataFrame(model.feature_importances_, X_train_full.columns, columns=['importance'])
var_features[var_features['importance'] > 0].sort_values(by = 'importance', ascending=False)

# %%
var_features = pd.DataFrame(model.feature_importances_, X_train_full.columns, columns=['importance'])
var_features[var_features['importance'] > 0].sort_values(by = 'importance', ascending=False)

# %%
def find_outliers_z_score(col, threshhold = 3): 
    col_mean = col.mean()
    col_std = col.std(ddof = 0)
    c_zscore = (col - col_mean)/col_std
    indx_outliers = np.where (c_zscore.abs() > threshhold, True, False)
    return indx_outliers

# %%
data_train.iloc[~find_outliers_z_score(data_train['non_accum_internet_vol_td_mnt3'])]['non_accum_internet_vol_td_mnt3'].\
                    hist(bins = 200)

# %%
symlog = data_train['non_accum_internet_vol_td_mnt3'].apply(lambda x: -np.log10(-x) if x < 0 else np.log10(x) if x > 0 else 0)
data_train = data_train.assign(non_accum_internet_vol_td_mnt3_log = symlog)

symlog = data_test['non_accum_internet_vol_td_mnt3'].apply(lambda x: -np.log10(-x) if x < 0 else np.log10(x) if x > 0 else 0)
data_test = data_test.assign(non_accum_internet_vol_td_mnt3_log = symlog)

data_train = data_train.assign(non_accum_internet_vol_td_mnt3_log_bins = pd.cut(data_train['non_accum_internet_vol_td_mnt3_log'], 
                                                                                bins=range(-19, 19)))

data_test = data_test.assign(non_accum_internet_vol_td_mnt3_log_bins = pd.cut(data_test['non_accum_internet_vol_td_mnt3_log'], 
                                                                                bins=range(-19, 19)))

del symlog

# %%
sns.scatterplot(x=data_train['non_accum_internet_vol_td_mnt3_log'],
                y=data_train['slope_traff'], hue=data_train['big_slope'])

# %%
data_train.groupby(by = ['non_accum_internet_vol_td_mnt3_log_bins']).aggregate({'slope_traff': ['mean', 'median']}).plot()

# %%
big_slope_by_non_accum = pd.pivot_table(data_train, 
                                        values='abon_id', 
                                        index='non_accum_internet_vol_td_mnt3_log_bins',
                                        columns='big_slope', aggfunc='count')
big_slope_by_non_accum.columns = ['small_slope', 'big_slope']
big_slope_by_non_accum = big_slope_by_non_accum.\
                            assign(small_to_big_ratio = big_slope_by_non_accum.small_slope/big_slope_by_non_accum.big_slope)


# big_slope_by_non_accum.sort_values(by = 'small_to_big_ratio', ascending = False)

ax1 = big_slope_by_non_accum.loc[:, ['small_slope', 'big_slope']].plot(kind = 'bar',
                                                                       figsize = (10,5),
                                                                       rot = 90,
                                                                       sharex = True)


ax1 = big_slope_by_non_accum['small_to_big_ratio'].plot(secondary_y=True,
                                                                colormap = 'ocean',
                                                                rot = 90, 
                                                                legend = True,
                                                                sharex = True);

# %%
data_test[data_test['target'] >= 1]['traff_m1'].plot.hist(bins = 200)

# %%
cat_num_col_list = find_cat_cols(data_train)
cat_col_list = list(cat_num_col_list[cat_num_col_list['if_cat'] == 1]['col_name'].values)
num_col_list = list(cat_num_col_list[cat_num_col_list['if_cat'] == 0]['col_name'].values)
print(len(cat_col_list))
print(len(num_col_list))
# Out:
# 34
# 887

# %%
data_train_num = data_train[num_col_list]
data_test_num = data_test[num_col_list]
# data_train_num_outliers_mask = mark_outliers(data_train_num)

# %%
# # READING TRAIN AND TEST DATA NUMERICAL FEAUTURES ONLY WITH VARIANCE QUANTILES AND SLOPE FROM PARQUET

data_train_num = pd.read_parquet(dir_path + 'model2_parquet/data_train_num.parquet.gzip')
data_test_num = pd.read_parquet(dir_path + 'model2_parquet/data_test_num.parquet.gzip')

# %%
# FUNCTION TO MARK UNIVALUE COLUMNS, OUTLIERS, MISSING VALUES

def df_info (df, outliers_mask_df):
    
    df_info = pd.DataFrame(columns=['col', '%of_fr_univalue', '%of_unfr_univalue','freq_value', '%outliers', '%nans'])
    
    df_length = df.shape[0]
    
    for col in df.columns:
        
        value_count_info = df[col].value_counts().sort_values(ascending = False)
        
        freq_value = value_count_info.index[0]
        freq_value_count = value_count_info.iloc[0]/df_length
        #print(freq_value_count)
        try:
            unfreq_value_count = value_count_info.iloc[1]/df_length
        except:
            unfreq_value_count = np.nan
        #print(unfreq_value_count)
        perc_outl = outliers_mask_df[col].sum()/df_length
        perc_nans = df[col].isnull().sum()/df_length
        
        #print(freq_count)
        df_info = df_info.append({'col': col, 
                                  '%of_fr_univalue': freq_value_count,
                                  '%of_unfr_univalue': unfreq_value_count,
                                  '%outliers': perc_outl,
                                  '%nans': perc_nans,
                                  'freq_value': freq_value}, 
                                 ignore_index=True)
        
    return df_info.sort_values(by = ['%of_fr_univalue', '%outliers','%nans'], ascending=False)

# %%
data_train_num_info = df_info(data_train_num, data_train_num_outliers_mask)
del data_train_num_outliers_mask

# %%
data_train_num_corr = data_train_num.corr()

# %%
# # WRITING AND READING DATA_TRAIN_INFO DF TO PARQUET

# # data_train_num_info.to_parquet((dir_path + 'data_train_num_info.parquet.gzip'),compression='gzip')

data_train_num_info = pd.read_parquet(dir_path +'data_train_num_info.parquet.gzip')

# %%
# # WRITING AND READING DATA_TRAIN TARGET CORRELATION DF TO PARQUET

# # data_train_num_corr.to_parquet((dir_path + 'data_train_num_corr.parquet.gzip'),compression='gzip')

data_train_num_corr = pd.read_parquet(dir_path +'data_train_num_corr.parquet.gzip')

# %%
# ADDING TARGET CORR TO THE INFO DF
data_train_num_info = data_train_num_info.merge(data_train_num_corr['target'], left_on='col', right_index=True)

# %%
del data_train_num_corr

# %%
# HIGHLIGHT DESIRED PERCENTILE IN A SERIES

def highlight_perc(s, q):
    
    is_max = s >= s.quantile(q)
    
    return ['background-color: salmon' if v else '' for v in is_max]

# %%
#PRINTING INFO DF WITH CONDITIONAL FORMATTING
data_train_num_info_style = data_train_num_info.sort_values(by = '%nans', 
                                                            ascending=False).\
                                                style.apply(highlight_perc,
                                                            subset=['%outliers', '%nans'],
                                                            **{'q': 0.75}).\
                                                format({'%of_fr_univalue': "{:.2%}",
                                                        '%of_unfr_univalue': "{:.2%}",
                                                        '%outliers': "{:.2%}",
                                                        '%nans': "{:.2%}",
                                                        'target': "{:.2f}"})
data_train_num_info_style

# %%
print('low target corr features number:')
print(data_train_num_info[data_train_num_info['target'].abs() < 0.2].shape[0])


#PRINTING INFO DF FOR LOW TARGET CORR FEATURES WITH CONDITIONAL FORMATTING

data_train_num_info_style = data_train_num_info[data_train_num_info['target'].abs() < 0.2].\
                            sort_values(by = 'target', ascending=False).\
                            style.apply(highlight_perc,
                                        subset=['%outliers', '%nans'],
                                        **{'q': 0.75}).\
                                        format({'%of_fr_univalue': "{:.2%}",
                                                '%of_unfr_univalue': "{:.2%}",
                                                '%outliers': "{:.2%}",
                                                '%nans': "{:.2%}",
                                                'target': "{:.2f}"})
data_train_num_info_style
# Out:
# low target corr features number:
# 801
# <style  type="text/css" >
# #T_a8dbe_row0_col5,#T_a8dbe_row1_col5,#T_a8dbe_row2_col5,#T_a8dbe_row3_col5,#T_a8dbe_row5_col5,#T_a8dbe_row6_col5,#T_a8dbe_row7_col5,#T_a8dbe_row8_col4,#T_a8dbe_row8_col5,#T_a8dbe_row9_col5,#T_a8dbe_row10_col5,#T_a8dbe_row11_col5,#T_a8dbe_row12_col5,#T_a8dbe_row13_col5,#T_a8dbe_row14_col5,#T_a8dbe_row15_col5,#T_a8dbe_row16_col4,#T_a8dbe_row17_col5,#T_a8dbe_row18_col5,#T_a8dbe_row19_col5,#T_a8dbe_row20_col5,#T_a8dbe_row21_col4,#T_a8dbe_row21_col5,#T_a8dbe_row22_col4,#T_a8dbe_row22_col5,#T_a8dbe_row23_col5,#T_a8dbe_row24_col5,#T_a8dbe_row26_col4,#T_a8dbe_row26_col5,#T_a8dbe_row27_col5,#T_a8dbe_row28_col5,#T_a8dbe_row29_col5,#T_a8dbe_row30_col5,#T_a8dbe_row31_col5,#T_a8dbe_row34_col5,#T_a8dbe_row35_col5,#T_a8dbe_row36_col5,#T_a8dbe_row37_col5,#T_a8dbe_row38_col5,#T_a8dbe_row39_col5,#T_a8dbe_row40_col5,#T_a8dbe_row41_col5,#T_a8dbe_row42_col5,#T_a8dbe_row43_col5,#T_a8dbe_row45_col5,#T_a8dbe_row46_col5,#T_a8dbe_row47_col5,#T_a8dbe_row48_col5,#T_a8dbe_row49_col5,#T_a8dbe_row50_col4,#T_a8dbe_row50_col5,#T_a8dbe_row51_col5,#T_a8dbe_row52_col5,#T_a8dbe_row53_col5,#T_a8dbe_row54_col5,#T_a8dbe_row55_col5,#T_a8dbe_row57_col5,#T_a8dbe_row58_col5,#T_a8dbe_row59_col5,#T_a8dbe_row60_col5,#T_a8dbe_row62_col4,#T_a8dbe_row62_col5,#T_a8dbe_row63_col4,#T_a8dbe_row63_col5,#T_a8dbe_row64_col5,#T_a8dbe_row65_col5,#T_a8dbe_row66_col5,#T_a8dbe_row67_col5,#T_a8dbe_row68_col5,#T_a8dbe_row69_col5,#T_a8dbe_row70_col5,#T_a8dbe_row71_col5,#T_a8dbe_row72_col5,#T_a8dbe_row73_col5,#T_a8dbe_row74_col4,#T_a8dbe_row74_col5,#T_a8dbe_row75_col5,#T_a8dbe_row76_col5,#T_a8dbe_row77_col4,#T_a8dbe_row77_col5,#T_a8dbe_row78_col4,#T_a8dbe_row78_col5,#T_a8dbe_row79_col5,#T_a8dbe_row80_col5,#T_a8dbe_row81_col5,#T_a8dbe_row82_col5,#T_a8dbe_row83_col5,#T_a8dbe_row84_col5,#T_a8dbe_row85_col5,#T_a8dbe_row86_col4,#T_a8dbe_row86_col5,#T_a8dbe_row87_col5,#T_a8dbe_row90_col4,#T_a8dbe_row90_col5,#T_a8dbe_row91_col5,#T_a8dbe_row92_col5,#T_a8dbe_row93_col5,#T_a8dbe_row94_col5,#T_a8dbe_row95_col5,#T_a8dbe_row96_col4,#T_a8dbe_row96_col5,#T_a8dbe_row97_col5,#T_a8dbe_row98_col5,#T_a8dbe_row99_col5,#T_a8dbe_row100_col4,#T_a8dbe_row100_col5,#T_a8dbe_row101_col4,#T_a8dbe_row101_col5,#T_a8dbe_row102_col5,#T_a8dbe_row103_col5,#T_a8dbe_row104_col5,#T_a8dbe_row105_col5,#T_a8dbe_row106_col5,#T_a8dbe_row107_col4,#T_a8dbe_row107_col5,#T_a8dbe_row108_col4,#T_a8dbe_row108_col5,#T_a8dbe_row109_col5,#T_a8dbe_row110_col5,#T_a8dbe_row111_col5,#T_a8dbe_row112_col5,#T_a8dbe_row113_col4,#T_a8dbe_row113_col5,#T_a8dbe_row114_col5,#T_a8dbe_row115_col5,#T_a8dbe_row116_col4,#T_a8dbe_row116_col5,#T_a8dbe_row117_col5,#T_a8dbe_row118_col5,#T_a8dbe_row119_col5,#T_a8dbe_row120_col4,#T_a8dbe_row120_col5,#T_a8dbe_row121_col4,#T_a8dbe_row121_col5,#T_a8dbe_row122_col5,#T_a8dbe_row123_col5,#T_a8dbe_row124_col4,#T_a8dbe_row124_col5,#T_a8dbe_row125_col5,#T_a8dbe_row126_col4,#T_a8dbe_row126_col5,#T_a8dbe_row127_col5,#T_a8dbe_row128_col4,#T_a8dbe_row128_col5,#T_a8dbe_row129_col5,#T_a8dbe_row130_col5,#T_a8dbe_row131_col5,#T_a8dbe_row132_col5,#T_a8dbe_row133_col5,#T_a8dbe_row134_col5,#T_a8dbe_row135_col4,#T_a8dbe_row135_col5,#T_a8dbe_row136_col5,#T_a8dbe_row137_col5,#T_a8dbe_row138_col5,#T_a8dbe_row139_col4,#T_a8dbe_row140_col4,#T_a8dbe_row140_col5,#T_a8dbe_row141_col5,#T_a8dbe_row142_col5,#T_a8dbe_row143_col5,#T_a8dbe_row144_col5,#T_a8dbe_row145_col4,#T_a8dbe_row146_col5,#T_a8dbe_row147_col5,#T_a8dbe_row148_col5,#T_a8dbe_row149_col5,#T_a8dbe_row150_col5,#T_a8dbe_row151_col5,#T_a8dbe_row152_col5,#T_a8dbe_row153_col5,#T_a8dbe_row154_col4,#T_a8dbe_row154_col5,#T_a8dbe_row155_col5,#T_a8dbe_row156_col4,#T_a8dbe_row156_col5,#T_a8dbe_row157_col5,#T_a8dbe_row158_col5,#T_a8dbe_row159_col5,#T_a8dbe_row160_col5,#T_a8dbe_row161_col4,#T_a8dbe_row161_col5,#T_a8dbe_row162_col5,#T_a8dbe_row163_col4,#T_a8dbe_row163_col5,#T_a8dbe_row164_col5,#T_a8dbe_row165_col5,#T_a8dbe_row166_col5,#T_a8dbe_row167_col5,#T_a8dbe_row168_col5,#T_a8dbe_row169_col5,#T_a8dbe_row170_col5,#T_a8dbe_row171_col5,#T_a8dbe_row172_col5,#T_a8dbe_row173_col5,#T_a8dbe_row174_col ...

# %%
print('high target corr features number:')
print(data_train_num_info[data_train_num_info['target'].abs() >= 0.2].shape[0])

#PRINTING INFO DF FOR HIGH TARGET CORR FEATURES WITH CONDITIONAL FORMATTING

data_train_num_info_style = data_train_num_info[data_train_num_info['target'].abs() >= 0.2].\
                            sort_values(by = '%nans', ascending=False).\
                            style.apply(highlight_perc,
                                        subset=['%outliers', '%nans'],
                                        **{'q': 0.75}).\
                                        format({'%of_fr_univalue': "{:.2%}",
                                                '%of_unfr_univalue': "{:.2%}",
                                                '%outliers': "{:.2%}",
                                                '%nans': "{:.2%}",
                                                'target': "{:.2f}"})
data_train_num_info_style
# Out:
# high target corr features number:
# 58
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-256-3464f5a804e7> in <module>
#       6 data_train_num_info_style = data_train_num_info[data_train_num_info['target'].abs() >= 0.2].\
#       7                             sort_values(by = '%nans', ascending=False).\
# ----> 8                             style.apply(highlight_perc,
#       9                                         subset=['%outliers', '%nans'],
#      10                                         **{'q': 0.75}).\
#
# NameError: name 'highlight_perc' is not defined

# %%
#CHOOSING THE FEATURES WITH AT LEAST 0.2 CORRELATION COEFF WITH THE TARGET
# AND LESS THAN 60% OF MISSINGS

num_cols_to_use = data_train_num_info[(data_train_num_info['target'].abs() >= 0.2) &\
                                      (data_train_num_info['target'].abs() < 1) &\
                                      (data_train_num_info['%nans'] < 0.6)]['col'].to_list()
len(num_cols_to_use)
# Out:
# 55

# %%
sorted(num_cols_to_use)

# %%
# MERGING INFO DF WITH FEAUTURES DESCRIPTION AND CHOOSING MAX TARGET CORRELATED STAT METRIC FEAUTURES
data_descr = pd.read_csv((dir_path + 'data_descr.csv'), names=['feature', 'descr'])

data_train_num_info = pd.merge(data_train_num_info, data_descr, how='left', left_on='col', right_on='feature')
data_train_num_info.loc[data_train_num_info['descr'].isna(), 
                        'descr'] = data_train_num_info.loc[data_train_num_info['descr'].isna(), 'col']

data_train_num_info = data_train_num_info.assign(feature_clear = data_train_num_info['descr'])

expression = ' - стат.метрика'
escaped_expression = re.escape(expression)

data_train_num_info['feature_clear'] = data_train_num_info.feature_clear.apply(lambda x: re.sub(\
                                                                               escaped_expression, '', str(x)))

data_train_num_info = data_train_num_info.drop('feature', axis =1)

# %%
num_cols_to_use = list(data_train_num_info.loc[data_train_num_info['col'].isin(num_cols_to_use)].\
                                       groupby('feature_clear')['col'].max('target').values)

len(num_cols_to_use)
# Out:
# 26

# %%
len(big_var_slope_features)
# Out:
# 155

# %%
num_big_var_slope_features = [x for x in big_var_slope_features if x in num_col_list]
len(num_big_var_slope_features)
# Out:
# 153

# %%
full_cols_to_use = list(set(num_cols_to_use + num_big_var_slope_features))

# %%
print(len(num_cols_to_use))
num_cols_to_use
# Out:
# 168
# ['imei_mean_days_usage',
#  'imei_max_price',
#  'Internet',
#  'device_height_mm',
#  'data_3g_tar_vol_td_mnt3',
#  'content_cnt_td_mnt3',
#  'dpi_upload',
#  'sum_paym_6_month',
#  'DNZ_STD_days_closed_loan_year5',
#  'voice_out_tar_dur_td_mnt3',
#  'dpi_duration',
#  'data_3g_tv_cnt_td_mnt3',
#  'days_of_end_last_ppm',
#  'DNZ_MEAN_days_closed_loan_year1',
#  'cnt_bank_sms_category_forwardban',
#  'MV_Traf_pstn_inc_v_Min',
#  'num_act_days_td_mnt3',
#  'MV_ot_4G_d',
#  'DNZ_DAYS_from_last_year1',
#  'bs_count_change_tp',
#  'voice_mts_out_nwork_parttd_mnt3',
#  'MV_dou_2G_d',
#  'imei_mean_day_announced',
#  'sms_out_cnt_td_mnt3',
#  'cnt_bank_sms_category_awalbank',
#  'MV_DOU_Neg_Bal',
#  'data_3g_dou_td_mnt3',
#  'MV_ot_Roam_d',
#  'MV_ap_mn_out_v',
#  'cnt_sms_category_bank',
#  'cnt_sms_category_shop',
#  'cnt_bank_sms_category_mtbbank',
#  'MV_dou_out_s',
#  'gprs_tar_vol_std_mnt3',
#  'bs_of_recall_m1',
#  'MV_ap_innet_out_v',
#  'voice_out_cmpttrs_td_cnttd_mnt3',
#  'non_accum_internet_vol_td_mnt3',
#  'var_quant',
#  'ks_num_part_td_mnt3',
#  'all_clc_td_mnt3',
#  'MV_Traf_ACCA_out_v_Min',
#  'bs_drop_rate',
#  'loc_lon',
#  'BS_OVERBUNDLE_MB_CNT_M3',
#  'bs_ovrl_OMO_SUM_M3',
#  'voice_out_td_cnt_td_mnt3',
#  'Good_deed',
#  'MV_ap_s',
#  'MV_AP_total',
#  'bs_count_ppm_mn3',
#  'cnt_sms_category_women',
#  'dpi_events',
#  'slope_traff',
#  'cnt_sms_category_poshta',
#  'bs_of_unsucc_attemp_equip_m1',
#  'bs_recall_rate',
#  'voice_in_td_cnt_td_mnt3',
#  'MV_Traf_innet_out_s_Cnt',
#  'MV_dou',
#  'cnt_bank_sms_category_monobank',
#  'block_all_dur_td_mnt3',
#  'all_clc_std_mnt3',
#  'bs_ovrl_OMO_CNT_M3',
#  'all_roam_clc_td_mnt3',
#  'traff_m1',
#  'cnt_bank_sms_category_vostokbank',
#  'myvf_day_usage',
#  'bs_succ_rate',
#  'MV_net_total',
#  'all_home_clc_td_mnt3',
#  'lt',
#  'BS_OVERBUNDLE_MB_SUM_M3',
#  'DNZ_MAX_days_closed_loan_year1',
#  'BS_OVERBUNDLE_MB_CNT_M2',
#  'bs_of_succ_but_drop_m1',
#  'bs_day_of_change_tp',
#  'bs_delte_mb_change_tp',
#  'last_paym',
#  'voice_in_short_part_td_mnt3',
#  'bs_delte_omo_change_tp',
#  'MV_ap_omo_out_v',
#  'MV_Traf_R_inc_v_Min',
#  'voice_in_kievstar_part_td_mnt3',
#  'voice_mts_in_nwork_part_td_mnt3',
#  'MV_ARPU_innet_out_v_Traf',
#  'clc_no_vas_roam_std_mnt3',
#  'sms_roam_clc_td_mnt3',
#  'bs_delte_ppd_change_tp',
#  'MV_ap_pstn_out_v',
#  'all_cnt_td_mnt3',
#  'gprs_clc_td_mnt3',
#  'traff_m5',
#  'traff_m2',
#  'content_cnt_mea_mnt3',
#  'voice_in_tar_dur_td_mnt3',
#  'voice_out_fix_tar_dur_td_mnt3',
#  'sms_in_cnt_td_mnt3',
#  'device_days_usage',
#  'voice_in_life_part_td_mnt3',
#  'device_width_mm',
#  'MV_DOU_OT',
#  'MV_Traf_omo_out_v_Min',
#  'MV_ap_4G_d',
#  'cnt_paym_6_month',
#  'tsoa_direct_cnt',
#  'data_3g_tar_vol_std_mnt3',
#  'dpi_download',
#  'day_end_gba',
#  'MV_ARPU',
#  'GBA_remain_days',
#  'MV_ot_total',
#  'conn_out_uniq_cnt_td_mnt3',
#  'loc_cnt_events',
#  'cnt_bank_sms_category_otpbank',
#  'count_day_for_last_paym',
#  'voice_in_mts_avg_dur_td_mnt3',
#  'MV_dou_4G_d',
#  'abon_part_td_mnt3',
#  'MV_Traf_Cont_out_s_Cnt',
#  'imei_mean_long_days_usage',
#  'MV_Traf_3G_d_Mb',
#  'all_cnt_mea_mnt3',
#  'non_accum_internet_vol_std_mnt3',
#  'pay_sum_td_mnt3',
#  'accum_oth_dur_td_mnt3',
#  'MV_ARPU_Cont_out_s_Traf',
#  'bs_ovrl_OMO_CNT_M2',
#  'gprs_tar_vol_td_mnt3',
#  'bs_delte_ppm_change_tp',
#  'conn_in_uniq_cnt_td_mnt3',
#  'MV_Traf_Cont_inc_s_Cnt',
#  'pay_max_td_mnt3',
#  'MV_dou_innet_out_v',
#  'loc_lat',
#  'MV_Traf_2G_d_Mb',
#  'clc_no_vas_roam_td_mnt3',
#  'vas_clc_td_mnt3',
#  'tsoa_call_cnt',
#  'imei_mean_price',
#  'abon_id',
#  'data_3g_tv_cnt_std_mnt1',
#  'cnt_unq_category_online_auth',
#  'MV_ARPU_2G_d_Traf',
#  'voice_out_short_part_td_mnt3',
#  'bs_drop_call_rate',
#  'traff_m3',
#  'Balance_uah',
#  'TM_ID',
#  'loc_market_share',
#  'MV_dou_Roam_d',
#  'cnt_unq_category_microcred',
#  'MV_ot_innet_out_v',
#  'days_of_last_ppm',
#  'MV_dou_omo_out_v',
#  'MV_dou_3G_d',
#  'MV_Traf_4G_d_Mb',
#  'MV_Traf_pstn_out_v_Min',
#  'dpi_day_cnt',
#  'cnt_bank_sms_category_privatbank',
#  'MV_Traf_Cont_out_v_Min',
#  'MV_SERV_Y_WO_AF',
#  'device_ios_version',
#  'MV_dou_data',
#  'device_price',
#  'MV_Traf_innet_out_v_Min',
#  'sms_clc_td_mnt3',
#  'content_clc_td_mnt3']

# %%
data_test_num = data_test[num_col_list]

data_train_num_filtered = data_train_num[num_cols_to_use + ['target']]
data_test_num_filtered = data_test_num[num_cols_to_use + ['target']]


print(data_train_num_filtered.shape)
print(data_test_num_filtered.shape)
# Out:
# (250016, 169)
# (243123, 169)

# %%
cat_col_list
# Out:
# ['device_brand_samsung',
#  'device_brand_nokia',
#  'device_brand_lenovo',
#  'device_brand_apple',
#  'device_brand_huawei',
#  'device_brand_lg',
#  'device_brand_xiaomi',
#  'device_brand_meizu',
#  'device_brand_prestigio',
#  'device_brand_sony',
#  'device_brand_nan',
#  'device_brand_other',
#  'device_has_gprs',
#  'device_has_wifi',
#  'device_has_lte',
#  'device_type_modem',
#  'device_type_module',
#  'device_type_phone',
#  'device_type_smartphone',
#  'device_type_tablet',
#  'device_type_nan',
#  'device_type_rus_other',
#  'loc_is_obl_center',
#  'serv_long_req_cnt',
#  'serv_VF_bonus',
#  'serv_smart_1m',
#  'serv_year_nopay',
#  'DNZ_COUNT_open_loan_year1',
#  'MV_Migr_To',
#  'active_ppm',
#  'device_has_hardware_umts',
#  'device_has_LTE_BAND_3',
#  'big_slope']

# %%
#FILTERING CATEGORICAL COLUMNS INTO SEPARATE DF 

data_train_cat = data_train[cat_col_list]

data_test_cat = data_test[cat_col_list]

# %%
#FILTERING COLUMNS WITH BIGGEST TRAFFIC VAR INTO SEPARATE DF 

big_var_df_train = data_train_num_filtered[data_train_num_filtered['var_quant'] >= 8]
big_var_df_test = data_test_num_filtered[data_test_num_filtered['var_quant'] >= 8]

big_var_df_train = big_var_df_train.merge(data_train_cat, how  = 'left', left_index = True, right_index = True)
big_var_df_test = big_var_df_test.merge(data_test_cat, how  = 'left', left_index = True, right_index = True)

# %%
#FILTERING COLUMNS WITH BIGGEST TRAFFIC VAR INTO SEPARATE DF 

small_var_df_train = data_train_num_filtered[data_train_num_filtered['var_quant'] < 8]
small_var_df_test = data_test_num_filtered[data_test_num_filtered['var_quant'] < 8]

small_var_df_train = small_var_df_train.merge(data_train_cat, how  = 'left', left_index = True, right_index = True)
small_var_df_test = small_var_df_test.merge(data_test_cat, how  = 'left', left_index = True, right_index = True)

# %%
# VISUALZING TARGET DIFFERENCE RATE FOR CATEGORICAL COLUMNS

target_by_cat_cols = pd.DataFrame(index=cat_col_list, 
                                  columns=['0_bv', '1_bv', '1_to_0_rate_bv','0_sv', '1_sv', '1_to_0_rate_sv'])

for col in cat_col_list:
    temp = big_var_df_train.pivot_table(columns=col,values='target', aggfunc='median').fillna(0).applymap(float)
#     print(temp)
#     print(temp.values[0][1])
    target_by_cat_cols.loc[col]['0_bv'] = temp[0].values[0]
    try:
        target_by_cat_cols.loc[col]['1_bv'] = temp[1].values[0]
        target_by_cat_cols.loc[col]['1_to_0_rate_bv'] = temp[1].values[0]/temp[0].values[0]
    except:
        target_by_cat_cols.loc[col]['1_bv'] = np.nan
        target_by_cat_cols.loc[col]['1_to_0_rate_bv'] = np.nan
        
    temp = small_var_df_train.pivot_table(columns=col,values='target', aggfunc='median').fillna(0).applymap(float)
#     print(temp)
#     print(temp.values[0][1])
    target_by_cat_cols.loc[col]['0_sv'] = temp[0].values[0]
    try:
        target_by_cat_cols.loc[col]['1_sv'] = temp[1].values[0]
        target_by_cat_cols.loc[col]['1_to_0_rate_sv'] = temp[1].values[0]/temp[0].values[0]
    except:
        target_by_cat_cols.loc[col]['1_sv'] = np.nan
        target_by_cat_cols.loc[col]['1_to_0_rate_sv'] = np.nan


ax1 = target_by_cat_cols.sort_index().loc[:, ['0_bv', '1_bv']].plot(kind = 'bar',
                                                                       figsize = (10,5),
                                                                       rot = 90,
                                                                       sharex = True)


ax1 = target_by_cat_cols.sort_index()['1_to_0_rate_bv'].plot(secondary_y=True,
                                                                colormap = 'ocean',
                                                                rot = 90, 
                                                                legend = True,
                                                                sharex = True);

ax1.set_title('big_var')
    
ax2 = target_by_cat_cols.sort_index().loc[:, ['0_sv', '1_sv']].plot(kind = 'bar',
                                                                    figsize = (10,5),
                                                                    rot = 90,
                                                                    sharex = True);

ax2 = target_by_cat_cols.sort_index()['1_to_0_rate_sv'].plot(secondary_y=True,
                                                             colormap = 'ocean',
                                                             rot = 90,
                                                             legend = True,
                                                             sharex = True);

ax2.set_title('small_var')

# %%
# from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans

X_train_big_var = big_var_df_train.fillna(0)

plot_n_clusters = 20
sse = []
for k in range(1, plot_n_clusters+1):
    
        kmeans_batch = MiniBatchKMeans(n_clusters=k, 
                 init='k-means++', 
                 n_init=10, 
                 max_iter=300, 
                 random_state=1)
        
        kmeans_batch.fit(X_train_big_var)
        sse.append(kmeans_batch.inertia_)
        
plt.style.use("fivethirtyeight")
plt.plot(range(1, plot_n_clusters+1), sse)
plt.xticks(range(1, plot_n_clusters+1))
plt.xlabel("Number of Clusters")
plt.ylabel("Sum of squared error")
plt.show()

# %%
from sklearn.cluster import MiniBatchKMeans

X_train_big_var = big_var_df_train.fillna(0).astype('float32')
X_test_big_var = big_var_df_test.fillna(0).astype('float32')

kmeans_batch = MiniBatchKMeans(n_clusters=4, 
            init='k-means++', 
            n_init=10,
            max_iter=300, 
            tol=1e-04,
            random_state=1)


y_kmeans_batch_train = kmeans_batch.fit_predict(X_train_big_var)

y_kmeans_batch_test = kmeans_batch.predict(X_test_big_var)


big_var_df_train = big_var_df_train.assign(cluster = y_kmeans_batch_train)

big_var_df_test = big_var_df_test.assign(cluster = y_kmeans_batch_test)

# %%
# CHECKING MULTICOLLENEARITY IN DATA

def highlight_corr_06_plus(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_high = s >= 0.6
    return ['background-color: red' if v else '' for v in is_high]

collinear_cols_style = data_train_num_corr.loc[num_cols_to_use, num_cols_to_use].\
                                           style.apply(highlight_corr_06_plus).format("{:.2%}")


collinear_cols_style

# %%
data_train_num_corr.loc[num_cols_to_use, num_cols_to_use]['dpi_duration'].sort_values()

# %%
data_train_num_corr.loc[num_cols_to_use, num_cols_to_use]['MV_ARPU'].sort_values()

# %%
totals_for_pca = ['MV_ARPU', 'MV_ap_4G_d', 'MV_AP_total','all_clc_std_mnt3', 'clc_no_vas_roam_std_mnt3']
dpi_for_pca = ['dpi_duration', 'dpi_upload', 'dpi_download', 'dpi_events']

# %%
traffic_cols.sort()
traffic_cols_plus_target = ['traff_m5', 'traff_m3','traff_m2','traff_m1', 'target']
traffic_cols_plus_target.sort()

# %%
# DIMETIONALITY REDUCTION BY PCA FOR MULTICOLLINEAR COLUMNS

data_train_num_filtered = data_train_num_filtered.fillna(0)
data_test_num_filtered = data_test_num_filtered.fillna(0)

# %%
sc_x_traf = StandardScaler()

X_train_std = sc_x_traf.fit_transform(data_train_num_filtered[totals_for_pca])
X_test_std = sc_x_traf.fit_transform(data_test_num_filtered[totals_for_pca])

pca_train = PCA(random_state=3)
pca_test = PCA(random_state=3)

X_train_pca_totals = pca_train.fit_transform(X_train_std)
X_test_pca_totals = pca_test.fit_transform(X_train_std)

pd.DataFrame(pca_train.explained_variance_ratio_).style.format("{:.2%}")
# Out:
# <style  type="text/css" >
# </style><table id="T_a3fa8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3fa8_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a3fa8_row0_col0" class="data row0 col0" >82.47%</td>
#             </tr>
#             <tr>
#                         <th id="T_a3fa8_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a3fa8_row1_col0" class="data row1 col0" >11.53%</td>
#             </tr>
#             <tr>
#                         <th id="T_a3fa8_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a3fa8_row2_col0" class="data row2 col0" >4.10%</td>
#             </tr>
#             <tr>
#                         <th id="T_a3fa8_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a3fa8_row3_col0" class="data row3 col0" >1.85%</td>
#             </tr>
#             <tr>
#                         <th id="T_a3fa8_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a3fa8_row4_col0" class="data row4 col0" >0.05%</td>
#             </tr>
#     </tbody></table>

# %%
sc_x_traf = StandardScaler()

X_train_std = sc_x_traf.fit_transform(data_train_num_filtered[dpi_for_pca])
X_test_std = sc_x_traf.fit_transform(data_test_num_filtered[dpi_for_pca])

pca_train = PCA(random_state=3)
pca_test = PCA(random_state=3)

X_train_pca_dpi = pca_train.fit_transform(X_train_std)
X_test_pca_dpi = pca_test.fit_transform(X_train_std)

pd.DataFrame(pca_train.explained_variance_ratio_).style.format("{:.2%}")
# Out:
# <style  type="text/css" >
# </style><table id="T_128fe_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_128fe_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_128fe_row0_col0" class="data row0 col0" >68.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_128fe_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_128fe_row1_col0" class="data row1 col0" >16.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_128fe_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_128fe_row2_col0" class="data row2 col0" >8.45%</td>
#             </tr>
#             <tr>
#                         <th id="T_128fe_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_128fe_row3_col0" class="data row3 col0" >6.40%</td>
#             </tr>
#     </tbody></table>

# %%
sc_x_traf = StandardScaler()

X_train_std = sc_x_traf.fit_transform(data_train_num_filtered[totals_for_pca])
X_test_std = sc_x_traf.fit_transform(data_test_num_filtered[totals_for_pca])

pca_train = PCA(n_components = 1, random_state=3)
pca_test = PCA(n_components = 1, random_state=3)

X_train_pca_totals = pca_train.fit_transform(X_train_std)
X_test_pca_totals = pca_test.fit_transform(X_test_std)



sc_x_traf = StandardScaler()

X_train_std = sc_x_traf.fit_transform(data_train_num_filtered[dpi_for_pca])
X_test_std = sc_x_traf.fit_transform(data_test_num_filtered[dpi_for_pca])

pca_train = PCA(n_components = 2, random_state=3)
pca_test = PCA(n_components = 2, random_state=3)

X_train_pca_dpi = pca_train.fit_transform(X_train_std)
X_test_pca_dpi = pca_test.fit_transform(X_test_std)


del(X_train_std, X_test_std)

# %%
del data_test_num, data_train_num, data_train_cat, data_test_cat

# %%
num_cols_to_use
# Out:
# ['slope_traff',
#  'traff_m1',
#  'traff_m2',
#  'traff_m3',
#  'traff_m5',
#  'var_quant',
#  'dpi_duration',
#  'clc_no_vas_roam_std_mnt3',
#  'dpi_events',
#  'dpi_day_cnt',
#  'content_cnt_mea_mnt3',
#  'data_3g_tv_cnt_std_mnt1',
#  'all_cnt_mea_mnt3',
#  'all_clc_std_mnt3',
#  'MV_ARPU',
#  'dpi_download',
#  'dpi_upload',
#  'data_3g_tar_vol_std_mnt3',
#  'non_accum_internet_vol_std_mnt3',
#  'gprs_tar_vol_std_mnt3',
#  'MV_ap_4G_d',
#  'MV_ap_innet_out_v',
#  'MV_AP_total',
#  'MV_Traf_2G_d_Mb',
#  'MV_Traf_3G_d_Mb',
#  'MV_Traf_4G_d_Mb']

# %%
# PREPARING DATA FOR MODELS

# data_train_model = pd.read_parquet(dir_path + 'train/data_train.parquet.gzip').fillna(0)
# temp_train = data_train_num_filtered.copy()

data_train_num_filtered = temp_train[num_cols_to_use +['target']]

data_train_model = data_train_num_filtered.drop(totals_for_pca, axis=1).fillna(0)
data_train_model = data_train_model.drop(dpi_for_pca, axis=1)
data_train_model = data_train_model.assign(pca1=X_train_pca_totals[:, 0],
                                           pca2=X_train_pca_dpi[:, 0],
                                           pca3=X_train_pca_dpi[:, 1])

data_train_model_varQ90 = data_train_model[data_train_model['var_quant'] >= 8]
data_train_model_varQ90 = data_train_model_varQ90.merge(big_var_df_train['cluster'], how='left',
                                                       left_index = True, right_index = True)

data_train_model_full = data_train_model
data_train_model = data_train_model[~data_train_model['var_quant'].isin([8,9])]

data_train_model_varQ90 = data_train_model_varQ90.fillna(0)

# %%
# data_test_model = pd.read_parquet(dir_path + 'test/data_test.parquet.gzip').fillna(0)
# temp_test = data_test_num_filtered.copy()
data_test_num_filtered = temp_test[num_cols_to_use +['target']]

data_test_model = data_test_num_filtered.drop(totals_for_pca, axis=1).fillna(0)
data_test_model = data_test_model.drop(dpi_for_pca, axis=1)
data_test_model = data_test_model.assign(pca1=X_test_pca_totals[:, 0],
                                         pca2=X_test_pca_dpi[:, 0],
                                         pca3=X_test_pca_dpi[:, 1])

data_test_model_varQ90 = data_test_model[data_test_model['var_quant'] >= 8]
data_test_model_varQ90 = data_test_model_varQ90.merge(big_var_df_train['cluster'], how='left',
                                                      left_index = True, right_index = True)

data_test_model_full = data_test_model
data_test_model = data_test_model[~data_test_model['var_quant'].isin([8,9])]

data_test_model_varQ90 = data_test_model_varQ90.fillna(0)

# %%
data_train_model.columns

# %%
def df_normalization(df, cols_to_exclude = []):
    
    
    cols_to_use = list(df.columns)
   
    for col in cols_to_exclude:
        cols_to_use.remove(col)
        
    df_norm = df.copy()
    
    for column in cols_to_use: 
        df_norm[column] = (df_norm[column] - df_norm[column].min()) /(df_norm[column].max() - df_norm[column].min()) 

    return df_norm

# %%
X, y = data_train_model.loc[:, data_train_model.columns != 'target'], data_train_model.target

# X = df_normalization(X, ['var_quant'])

X = df_normalization(X, [])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state = 17)

X_full, y_full = data_test_model_full.loc[:, data_test_model_full.columns != 'target'], data_test_model_full.target

X_full = df_normalization(X_full, ['var_quant'])

X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(X_full, y_full, test_size=0.30, random_state = 17)

X_varQ90 = data_train_model_varQ90.loc[:, data_train_model_varQ90.columns != 'target']
y_varQ90 = data_train_model_varQ90.target

X_varQ90 = df_normalization(X_varQ90, ['var_quant'])

X_train_varQ90, X_test_varQ90, y_train_varQ90, y_test_varQ90 = train_test_split(X_varQ90, y_varQ90, 
                                                                                test_size=0.30, random_state = 17)

# %%
X_test_test, y_test_test = data_test_model.loc[:, data_test_model.columns != 'target'], data_test_model.target

# X_test_test = df_normalization(X_test_test, ['var_quant'])
X_test_test = df_normalization(X_test_test, [])

X_test_test_full = data_test_model_full.loc[:, data_test_model_full.columns != 'target']
X_test_test_full = df_normalization(X_test_test_full, ['var_quant'])
y_test_test_full = data_test_model_full.target

X_test_test_varQ90 = data_test_model_varQ90.loc[:, data_test_model_varQ90.columns != 'target']
X_test_test_varQ90 = df_normalization(X_test_test_varQ90, ['var_quant'])
y_test__test_varQ90 = data_test_model_varQ90.target

# %% [markdown]
# ### MODELS

# %%
X_train_full = X_train_full.drop('var_quant', axis = 1)
X_test_full = X_test_full.drop('var_quant', axis = 1)
X_test_test_full = X_test_test_full.drop('var_quant', axis = 1)

# %%
model = ltb.LGBMRegressor(objective ='regression',
                          random_state = 0)


model.fit(X_train_full,y_train_full)
y_train_pred = model.predict(X_train_full)
y_test_pred = model.predict(X_test_full)
y_test_test_pred = model.predict(X_test_test_full)

print('RMSE train: {:.6f}, test: {:.6f}, test_test: {:.6f}'.format(
        mean_squared_error(y_train_full, y_train_pred, squared = False),
        mean_squared_error(y_test_full, y_test_pred, squared = False), 
        mean_squared_error(y_test_test_full, y_test_test_pred, squared = False)))
print('R^2 train: {:.6f}, test: {:.6f}, test_test:{:.6f}'.format(
        r2_score(y_train_full, y_train_pred),
        r2_score(y_test_full, y_test_pred),
        r2_score(y_test_test_full, y_test_test_pred)))
# Out:
# RMSE train: 7.976912, test: 8.592163, test_test: 8.166356
# R^2 train: 0.530978, test: 0.452321, test_test:0.507487

# %%
n_folds = 5

from sklearn.metrics import make_scorer
from sklearn.model_selection import KFold

scoring = make_scorer(mean_squared_error, squared = False,greater_is_better=False)

kf = KFold(n_folds, shuffle=True, random_state=42)

parameters = {'learning_rate': [0.05, 0.15, 0.20],
              'n_estimators': [100, 200, 300, 400],
              'reg_alpha':[0.05, 0.7, 0.8]}


lgbm = LGBMRegressor(silent=True, random_state= 3)

grid_search = GridSearchCV(lgbm, parameters, scoring=scoring, n_jobs=-1, cv=kf, verbose = True)
res = grid_search.fit(X_train_full, y_train_full)


res
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   59.9s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  6.9min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=LGBMRegressor(random_state=3), n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.15, 0.2],
#                          'n_estimators': [100, 200, 300, 400],
#                          'reg_alpha': [0.05, 0.7, 0.8]},
#              scoring=make_scorer(mean_squared_error, greater_is_better=False, squared=False),
#              verbose=True)

# %%
print(f'Best score: {grid_search.best_score_}', '\n') 
print('Best parameters set:')

best_parameters = grid_search.best_estimator_.get_params()

for param_name in sorted(parameters.keys()):
    print(f'\t{param_name}:  {best_parameters[param_name]}')
# Out:
# Best score: -8.593911959919021
#
# Best parameters set:
# 	learning_rate:  0.05
# 	n_estimators:  200
# 	reg_alpha:  0.7

# %%
grid_search.cv_results_.get('mean_test_score')
# Out:
# array([-8.59943981, -8.60492098, -8.60274466, -8.59996368, -8.59391196,
#        -8.59640193, -8.60467089, -8.59830939, -8.59607914, -8.60930284,
#        -8.60219828, -8.60264911, -8.65982663, -8.65547941, -8.65658734,
#        -8.69754348, -8.68914235, -8.69969081, -8.72672067, -8.72101464,
#        -8.7246924 , -8.7530199 , -8.74423118, -8.75467936, -8.69920713,
#        -8.70752549, -8.70819707, -8.75226992, -8.76430121, -8.76494779,
#        -8.79543949, -8.80888212, -8.81308064, -8.83065351, -8.84461699,
#        -8.85115937])

# %%
grid_search.cv_results_.get('params')[35]
# Out:
# {'learning_rate': 0.2, 'n_estimators': 400, 'reg_alpha': 0.8}

# %%
model = ltb.LGBMRegressor(objective ='regression',
                          random_state = 0,
                          learning_rate = 0.05,
                          n_estimators = 200, 
                          reg_alpha = 0.7)


model.fit(X_train_full,y_train_full)
y_train_pred = model.predict(X_train_full)
y_test_pred = model.predict(X_test_full)
y_test_test_pred = model.predict(X_test_test_full)

print('RMSE train: {:.6f}, test: {:.6f}, test_test: {:.6f}'.format(
        mean_squared_error(y_train_full, y_train_pred, squared = False),
        mean_squared_error(y_test_full, y_test_pred, squared = False), 
        mean_squared_error(y_test_test_full, y_test_test_pred, squared = False)))
print('R^2 train: {:.6f}, test: {:.6f}, test_test:{:.6f}'.format(
        r2_score(y_train_full, y_train_pred),
        r2_score(y_test_full, y_test_pred),
        r2_score(y_test_test_full, y_test_test_pred)))
# Out:
# RMSE train: 7.977181, test: 8.568982, test_test: 8.159230
# R^2 train: 0.530946, test: 0.455272, test_test:0.508347

# %%
RMSE train: 7.706064, test: 8.513880, test_test: 7.957025
R^2 train: 0.562287, test: 0.462255, test_test:0.532413
